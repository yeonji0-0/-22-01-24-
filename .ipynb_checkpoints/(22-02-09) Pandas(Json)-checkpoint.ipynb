# %% [markdown]
# # Pandas

# %% [markdown]
# ### JSON

# %%
import json

# %%
#json 양식 예제
json_data1 = """{
        "color":"red",
        "value":"#f00"
}"""
json_data1
# Out:
# '{\n        "color":"red",\n        "value":"#f00"\n}'

# %%
result = json.loads(json_data1)
result
# Out:
# {'color': 'red', 'value': '#f00'}

# %%
result["color"]
# Out:
# 'red'

# %%
json_data2 = """{
    "id" : "0001",
    "type" : "donut",
    "name" : "Cake",
    "ppu" : 0.55,
    "groups" : { 
        "group" : [ 
                    {"id":"1001", "type":"Regular"},
                    {"id":"1002", "type":"Choco"},
                    {"id":"1003", "type":"Cream"}
                ]
    },
    "topping" : [
        {"id":"5001", "type":"None"},
        {"id":"5002", "type":"Sugar"},
        {"id":"5003", "type":"Choco"}
    ]

}
"""

# %%
j_data = json.loads(json_data2)
j_data
# Out:
# {'id': '0001',
#  'type': 'donut',
#  'name': 'Cake',
#  'ppu': 0.55,
#  'groups': {'group': [{'id': '1001', 'type': 'Regular'},
#    {'id': '1002', 'type': 'Choco'},
#    {'id': '1003', 'type': 'Cream'}]},
#  'topping': [{'id': '5001', 'type': 'None'},
#   {'id': '5002', 'type': 'Sugar'},
#   {'id': '5003', 'type': 'Choco'}]}

# %%
j_data["id"]
# Out:
# '0001'

# %%
j_data["name"]
# Out:
# 'Cake'

# %%
j_data["topping"][0]["id"]
# Out:
# '5001'

# %%
j_data["group"]
# -> key라고 바로 가는 것이 아니다
# depth별로 순차적으로 접근을 해야한다
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_415068/238747499.py in <module>
# ----> 1 j_data["group"]
#       2 # -> key라고 바로 가는 것이 아니다
#       3 # depth별로 순차적으로 접근을 해야한다
#
# KeyError: 'group'

# %%
j_data["groups"]["group"][1]["type"]
# Out:
# 'Choco'

# %% [markdown]
# ### Kobis api_json

# %% [markdown]
# > api_key :  955ef5d888fc11ea84bbe892453318e3

# %%
#1. 요청 인터페이ㅣ스를 참조해서 내가 필요한 정보를 요청할 주소 완성
#2.그 주소에 대해서 실행 (http통신)

# %%
#필요한 패키지들
import pandas as pd
import urllib.request # urllib.requests
import json

# %%
#내가 요청할 url을 문자열로 완성 -> 브라우저에서 그 주소가 맞는지 확인하면 됨
url = "https://kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key=955ef5d888fc11ea84bbe892453318e3&itemPerPage=20"
movie_page = urllib.request.urlopen(url)
# Out:
# {'movieListResult': {'totCnt': 86448,
#   'source': '영화진흥위원회',
#   'movieList': [{'movieCd': '20223827',
#     'movieNm': '살아오름: 천년의 동행',
#     'movieNmEn': 'A Thousand Years Together',
#     'prdtYear': '2022',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '후반작업',
#     'nationAlt': '한국',
#     'genreAlt': '애니메이션,드라마',
#     'repNationNm': '한국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '안재훈'}],
#     'companys': [{'companyCd': '20030116', 'companyNm': '(주)연필로명상하기'}]},
#    {'movieCd': '20212836',
#     'movieNm': '355',
#     'movieNmEn': 'The 355',
#     'prdtYear': '2021',
#     'openDt': '20220209',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '미국',
#     'genreAlt': '액션',
#     'repNationNm': '미국',
#     'repGenreNm': '액션',
#     'directors': [{'peopleNm': '사이먼 킨버그'}],
#     'companys': []},
#    {'movieCd': '20201965',
#     'movieNm': '해적: 도깨비 깃발',
#     'movieNmEn': 'The Pirates : The Last Royal Treasure',
#     'prdtYear': '2020',
#     'openDt': '20220126',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '어드벤처,액션,코미디',
#     'repNationNm': '한국',
#     'repGenreNm': '어드벤처',
#     'directors': [{'peopleNm': '김정훈'}],
#     'companys': [{'companyCd': '20169190', 'companyNm': '(주)어뉴'},
#      {'companyCd': '20205861', 'companyNm': '오스카10스튜디오'}]},
#    {'movieCd': '20223793',
#     'movieNm': '서유기: 손오공 홍해아 대전',
#     'movieNmEn': 'The Journey to the West: Red Boy',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉예정',
#     'nationAlt': '중국',
#     'genreAlt': '액션',
#     'repNationNm': '중국',
#     'repGenreNm': '액션',
#     'directors': [],
#     'companys': []},
#    {'movieCd': '20223266',
#     'movieNm': '애니멀 체인지',
#     'movieNmEn': 'The Wild Life',
#     'prdtYear': '2020',
#     'openDt': '20220209',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '중국',
#     'genreAlt': '애니메이션,판타지,어드벤처',
#     'repNationNm': '중국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '정량'}],
#     'companys': []},
#    {'movieCd': '20219245',
#     'movieNm': '만년이 지나도 변하지 않는 게 있어',
#     'movieNmEn': 'Till We Meet Again',
#     'prdtYear': '2021',
#     'openDt': '20220209',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '대만',
#     'genreAlt': '멜로/로맨스,액션,공포(호러),코미디,판타지',
#     'repNationNm': '대만',
#     'repGenreNm': '멜로/로맨스',
#     'directors': [{'peopleNm': '구파도'}],
#     'companys': []},
#    {'movieCd': '20205443',
#     'movieNm': '나일 강의 죽음',
#     'movieNmEn': 'Death on the Nile',
#     'prdtYear': '2021',
#     'openDt': '20220209',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '미국',
#     'genreAlt': '범죄,드라마,미스터리',
#     'repNationNm': '미국',
#     'repGenreNm': '범죄',
#     'directors': [{'peopleNm': '케네스 브래너'}],
#     'companys': []},
#    {'movieCd': '20212871',
#     'movieNm': '가슴이 떨리는 건 너 때문',
#     'movieNmEn': '',
#     'prdtYear': '2021',
#     'openDt': '20220209',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '일본',
#     'genreAlt': '멜로/로맨스',
#     'repNationNm': '일본',
#     'repGenreNm': '멜로/로맨스',
#     'directors': [],
#     'companys': []},
#    {'movieCd': '20223691',
#     'movieNm': '퇴폐의 온상 은밀한 만남',
#     'movieNmEn': '',
#     'prdtYear': '2021',
#     'openDt': '20220208',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '성인물(에로)',
#     'repNationNm': '한국',
#     'repGenreNm': '성인물(에로)',
#     'directors': [{'peopleNm': '강현성'}],
#     'companys': [{'companyCd': '20217881', 'companyNm': '(주)샤이커뮤니케이션즈'}]},
#    {'movieCd': '20223724',
#     'movieNm': '몸으로 대출 갚는 유부녀',
#     'movieNmEn': '',
#     'prdtYear': '2021',
#     'openDt': '20220208',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '성인물(에로)',
#     'repNationNm': '한국',
#     'repGenreNm': '성인물(에로)',
#     'directors': [{'peopleNm': '제너럴리스트'}],
#     'companys': [{'companyCd': '20141911', 'companyNm': '(주)뮤직엔닷컴'}]},
#    {'movieCd': '20223808',
#     'movieNm': '레트로 6969',
#     'movieNmEn': '',
#     'prdtYear': '2021',
#     'openDt': '20220208',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '멜로/로맨스,성인물(에로),드라마',
#     'repNationNm': '한국',
#     'repGenreNm': '멜로/로맨스',
#     'directors': [{'peopleNm': '김기환'}],
#     'companys': [{'companyCd': '20157008', 'companyNm': '(주)픽쳐레스크'}]},
#    {'movieCd': '20223725',
#     'movieNm': '남편이 데려온 나를 괴롭히는 남자',
#     'movieNmEn': '',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '기타',
#     'nationAlt': '일본',
#     'genreAlt': '성인물(에로)',
#     'repNationNm': '일본',
#     'repGenreNm': '성인물(에로)',
#     'directors': [],
#     'companys': []},
#    {'movieCd': '20223674',
#     'movieNm': '그녀의 육체 앞에 무너진 이성',
#     'movieNmEn': '',
#     'prdtYear': '2021',
#     'openDt': '20220208',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '성인물(에로)',
#     'repNationNm': '한국',
#     'repGenreNm': '성인물(에로)',
#     'directors': [{'peopleNm': '강현성'}],
#     'companys': [{'companyCd': '20217881', 'companyNm': '(주)샤이커뮤니케이션즈'}]},
#    {'movieCd': '20212569',
#     'movieNm': '거북이와 여자들',
#     'movieNmEn': 'Transmigration: the Turtle and the Women',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '기타',
#     'repNationNm': '한국',
#     'repGenreNm': '기타',
#     'directors': [{'peopleNm': '한선희'}],
#     'companys': []},
#    {'movieCd': '20212570',
#     'movieNm': '내일의 연인들',
#     'movieNmEn': 'tomorrow’s lovers',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '기타',
#     'repNationNm': '한국',
#     'repGenreNm': '기타',
#     'directors': [{'peopleNm': '김양희'}],
#     'companys': []},
#    {'movieCd': '20212572',
#     'movieNm': '바다 위의 별',
#     'movieNmEn': 'Stars on the Sea',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '애니메이션',
#     'repNationNm': '한국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '장승욱'}],
#     'companys': []},
#    {'movieCd': '20212585',
#     'movieNm': '평화가 사람 속을 걸어다니네',
#     'movieNmEn': 'Peace is Walking through The People',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '다큐멘터리',
#     'repNationNm': '한국',
#     'repGenreNm': '다큐멘터리',
#     'directors': [{'peopleNm': '함유선'}],
#     'companys': []},
#    {'movieCd': '20223826',
#     'movieNm': '애완거미',
#     'movieNmEn': 'Pet Spider',
#     'prdtYear': '2020',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '기타',
#     'repNationNm': '한국',
#     'repGenreNm': '기타',
#     'directors': [{'peopleNm': '구소정'}],
#     'companys': []},
#    {'movieCd': '20223832',
#     'movieNm': '소녀,안녕',
#     'movieNmEn': 'Farewell, Girl',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '기타',
#     'repNationNm': '한국',
#     'repGenreNm': '기타',
#     'directors': [{'peopleNm': '최윤호'}],
#     'companys': []},
#    {'movieCd': '20212064',
#     'movieNm': '여기, 나의 정원',
#     'movieNmEn': 'Here, My Garden',
#     'prdtYear': '2021',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '다큐멘터리',
#     'repNationNm': '한국',
#     'repGenreNm': '다큐멘터리',
#     'directors': [{'peopleNm': '김지곤'}],
#     'companys': []}]}}

# %%
temp = movie_page.read().decode("utf-8")
temp
# Out:
# '{"movieListResult":{"totCnt":86448,"source":"영화진흥위원회","movieList":[{"movieCd":"20223827","movieNm":"살아오름: 천년의 동행","movieNmEn":"A Thousand Years Together","prdtYear":"2022","openDt":"","typeNm":"장편","prdtStatNm":"후반작업","nationAlt":"한국","genreAlt":"애니메이션,드라마","repNationNm":"한국","repGenreNm":"애니메이션","directors":[{"peopleNm":"안재훈"}],"companys":[{"companyCd":"20030116","companyNm":"(주)연필로명상하기"}]},{"movieCd":"20212836","movieNm":"355","movieNmEn":"The 355","prdtYear":"2021","openDt":"20220209","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"미국","genreAlt":"액션","repNationNm":"미국","repGenreNm":"액션","directors":[{"peopleNm":"사이먼 킨버그"}],"companys":[]},{"movieCd":"20201965","movieNm":"해적: 도깨비 깃발","movieNmEn":"The Pirates : The Last Royal Treasure","prdtYear":"2020","openDt":"20220126","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"어드벤처,액션,코미디","repNationNm":"한국","repGenreNm":"어드벤처","directors":[{"peopleNm":"김정훈"}],"companys":[{"companyCd":"20169190","companyNm":"(주)어뉴"},{"companyCd":"20205861","companyNm":"오스카10스튜디오"}]},{"movieCd":"20223793","movieNm":"서유기: 손오공 홍해아 대전","movieNmEn":"The Journey to the West: Red Boy","prdtYear":"2021","openDt":"","typeNm":"장편","prdtStatNm":"개봉예정","nationAlt":"중국","genreAlt":"액션","repNationNm":"중국","repGenreNm":"액션","directors":[],"companys":[]},{"movieCd":"20223266","movieNm":"애니멀 체인지","movieNmEn":"The Wild Life","prdtYear":"2020","openDt":"20220209","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"중국","genreAlt":"애니메이션,판타지,어드벤처","repNationNm":"중국","repGenreNm":"애니메이션","directors":[{"peopleNm":"정량"}],"companys":[]},{"movieCd":"20219245","movieNm":"만년이 지나도 변하지 않는 게 있어","movieNmEn":"Till We Meet Again","prdtYear":"2021","openDt":"20220209","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"대만","genreAlt":"멜로/로맨스,액션,공포(호러),코미디,판타지","repNationNm":"대만","repGenreNm":"멜로/로맨스","directors":[{"peopleNm":"구파도"}],"companys":[]},{"movieCd":"20205443","movieNm":"나일 강의 죽음","movieNmEn":"Death on the Nile","prdtYear":"2021","openDt":"20220209","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"미국","genreAlt":"범죄,드라마,미스터리","repNationNm":"미국","repGenreNm":"범죄","directors":[{"peopleNm":"케네스 브래너"}],"companys":[]},{"movieCd":"20212871","movieNm":"가슴이 떨리는 건 너 때문","movieNmEn":"","prdtYear":"2021","openDt":"20220209","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"일본","genreAlt":"멜로/로맨스","repNationNm":"일본","repGenreNm":"멜로/로맨스","directors":[],"companys":[]},{"movieCd":"20223691","movieNm":"퇴폐의 온상 은밀한 만남","movieNmEn":"","prdtYear":"2021","openDt":"20220208","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"성인물(에로)","repNationNm":"한국","repGenreNm":"성인물(에로)","directors":[{"peopleNm":"강현성"}],"companys":[{"companyCd":"20217881","companyNm":"(주)샤이커뮤니케이션즈"}]},{"movieCd":"20223724","movieNm":"몸으로 대출 갚는 유부녀","movieNmEn":"","prdtYear":"2021","openDt":"20220208","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"성인물(에로)","repNationNm":"한국","repGenreNm":"성인물(에로)","directors":[{"peopleNm":"제너럴리스트"}],"companys":[{"companyCd":"20141911","companyNm":"(주)뮤직엔닷컴"}]},{"movieCd":"20223808","movieNm":"레트로 6969","movieNmEn":"","prdtYear":"2021","openDt":"20220208","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"멜로/로맨스,성인물(에로),드라마","repNationNm":"한국","repGenreNm":"멜로/로맨스","directors":[{"peopleNm":"김기환"}],"companys":[{"companyCd":"20157008","companyNm":"(주)픽쳐레스크"}]},{"movieCd":"20223725","movieNm":"남편이 데려온 나를 괴롭히는 남자","movieNmEn":"","prdtYear":"2021","openDt":"","typeNm":"장편","prdtStatNm":"기타","nationAlt":"일본","genreAlt":"성인물(에로)","repNationNm":"일본","repGenreNm":"성인물(에로)","directors":[],"companys":[]},{"movieCd":"20223674","movieNm":"그녀의 육체 앞에 무너진 이성","movieNmEn":"","prdtYear":"2021","openDt":"20220208","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"성인물(에로)","repNationNm":"한국","repGenreNm":"성인물(에로)","directors":[{"peopleNm":"강현성"}],"companys":[{"companyCd":"20217881","companyNm":"(주)샤이커뮤니케이션즈"}]},{"movieCd":"20212569","movieNm":"거북이와 여자들","movieNmEn":"Transmigration: the Turtle and the Women","prdtYear":"2021","ope ...

# %%
temp["movieListResult"] #문자열이지 키값이 아님
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_415068/2831141544.py in <module>
# ----> 1 temp["movieListResult"]
#
# TypeError: string indices must be integers

# %%
movie_data = json.loads(movie_page.read().decode("utf-8"))
movie_data

# %%
movie_data["movieListResult"] #json패키지가 파이썬의 딕션어리, 리스트로 바꿔주었기 때문에 가능
# Out:
# {'totCnt': 86448,
#  'source': '영화진흥위원회',
#  'movieList': [{'movieCd': '20223827',
#    'movieNm': '살아오름: 천년의 동행',
#    'movieNmEn': 'A Thousand Years Together',
#    'prdtYear': '2022',
#    'openDt': '',
#    'typeNm': '장편',
#    'prdtStatNm': '후반작업',
#    'nationAlt': '한국',
#    'genreAlt': '애니메이션,드라마',
#    'repNationNm': '한국',
#    'repGenreNm': '애니메이션',
#    'directors': [{'peopleNm': '안재훈'}],
#    'companys': [{'companyCd': '20030116', 'companyNm': '(주)연필로명상하기'}]},
#   {'movieCd': '20212836',
#    'movieNm': '355',
#    'movieNmEn': 'The 355',
#    'prdtYear': '2021',
#    'openDt': '20220209',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '미국',
#    'genreAlt': '액션',
#    'repNationNm': '미국',
#    'repGenreNm': '액션',
#    'directors': [{'peopleNm': '사이먼 킨버그'}],
#    'companys': []},
#   {'movieCd': '20201965',
#    'movieNm': '해적: 도깨비 깃발',
#    'movieNmEn': 'The Pirates : The Last Royal Treasure',
#    'prdtYear': '2020',
#    'openDt': '20220126',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '한국',
#    'genreAlt': '어드벤처,액션,코미디',
#    'repNationNm': '한국',
#    'repGenreNm': '어드벤처',
#    'directors': [{'peopleNm': '김정훈'}],
#    'companys': [{'companyCd': '20169190', 'companyNm': '(주)어뉴'},
#     {'companyCd': '20205861', 'companyNm': '오스카10스튜디오'}]},
#   {'movieCd': '20223793',
#    'movieNm': '서유기: 손오공 홍해아 대전',
#    'movieNmEn': 'The Journey to the West: Red Boy',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉예정',
#    'nationAlt': '중국',
#    'genreAlt': '액션',
#    'repNationNm': '중국',
#    'repGenreNm': '액션',
#    'directors': [],
#    'companys': []},
#   {'movieCd': '20223266',
#    'movieNm': '애니멀 체인지',
#    'movieNmEn': 'The Wild Life',
#    'prdtYear': '2020',
#    'openDt': '20220209',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '중국',
#    'genreAlt': '애니메이션,판타지,어드벤처',
#    'repNationNm': '중국',
#    'repGenreNm': '애니메이션',
#    'directors': [{'peopleNm': '정량'}],
#    'companys': []},
#   {'movieCd': '20219245',
#    'movieNm': '만년이 지나도 변하지 않는 게 있어',
#    'movieNmEn': 'Till We Meet Again',
#    'prdtYear': '2021',
#    'openDt': '20220209',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '대만',
#    'genreAlt': '멜로/로맨스,액션,공포(호러),코미디,판타지',
#    'repNationNm': '대만',
#    'repGenreNm': '멜로/로맨스',
#    'directors': [{'peopleNm': '구파도'}],
#    'companys': []},
#   {'movieCd': '20205443',
#    'movieNm': '나일 강의 죽음',
#    'movieNmEn': 'Death on the Nile',
#    'prdtYear': '2021',
#    'openDt': '20220209',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '미국',
#    'genreAlt': '범죄,드라마,미스터리',
#    'repNationNm': '미국',
#    'repGenreNm': '범죄',
#    'directors': [{'peopleNm': '케네스 브래너'}],
#    'companys': []},
#   {'movieCd': '20212871',
#    'movieNm': '가슴이 떨리는 건 너 때문',
#    'movieNmEn': '',
#    'prdtYear': '2021',
#    'openDt': '20220209',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '일본',
#    'genreAlt': '멜로/로맨스',
#    'repNationNm': '일본',
#    'repGenreNm': '멜로/로맨스',
#    'directors': [],
#    'companys': []},
#   {'movieCd': '20223691',
#    'movieNm': '퇴폐의 온상 은밀한 만남',
#    'movieNmEn': '',
#    'prdtYear': '2021',
#    'openDt': '20220208',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '한국',
#    'genreAlt': '성인물(에로)',
#    'repNationNm': '한국',
#    'repGenreNm': '성인물(에로)',
#    'directors': [{'peopleNm': '강현성'}],
#    'companys': [{'companyCd': '20217881', 'companyNm': '(주)샤이커뮤니케이션즈'}]},
#   {'movieCd': '20223724',
#    'movieNm': '몸으로 대출 갚는 유부녀',
#    'movieNmEn': '',
#    'prdtYear': '2021',
#    'openDt': '20220208',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '한국',
#    'genreAlt': '성인물(에로)',
#    'repNationNm': '한국',
#    'repGenreNm': '성인물(에로)',
#    'directors': [{'peopleNm': '제너럴리스트'}],
#    'companys': [{'companyCd': '20141911', 'companyNm': '(주)뮤직엔닷컴'}]},
#   {'movieCd': '20223808',
#    'movieNm': '레트로 6969',
#    'movieNmEn': '',
#    'prdtYear': '2021',
#    'openDt': '20220208',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '한국',
#    'genreAlt': '멜로/로맨스,성인물(에로),드라마',
#    'repNationNm': '한국',
#    'repGenreNm': '멜로/로맨스',
#    'directors': [{'peopleNm': '김기환'}],
#    'companys': [{'companyCd': '20157008', 'companyNm': '(주)픽쳐레스크'}]},
#   {'movieCd': '20223725',
#    'movieNm': '남편이 데려온 나를 괴롭히는 남자',
#    'movieNmEn': '',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '장편',
#    'prdtStatNm': '기타',
#    'nationAlt': '일본',
#    'genreAlt': '성인물(에로)',
#    'repNationNm': '일본',
#    'repGenreNm': '성인물(에로)',
#    'directors': [],
#    'companys': []},
#   {'movieCd': '20223674',
#    'movieNm': '그녀의 육체 앞에 무너진 이성',
#    'movieNmEn': '',
#    'prdtYear': '2021',
#    'openDt': '20220208',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '한국',
#    'genreAlt': '성인물(에로)',
#    'repNationNm': '한국',
#    'repGenreNm': '성인물(에로)',
#    'directors': [{'peopleNm': '강현성'}],
#    'companys': [{'companyCd': '20217881', 'companyNm': '(주)샤이커뮤니케이션즈'}]},
#   {'movieCd': '20212569',
#    'movieNm': '거북이와 여자들',
#    'movieNmEn': 'Transmigration: the Turtle and the Women',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '기타',
#    'repNationNm': '한국',
#    'repGenreNm': '기타',
#    'directors': [{'peopleNm': '한선희'}],
#    'companys': []},
#   {'movieCd': '20212570',
#    'movieNm': '내일의 연인들',
#    'movieNmEn': 'tomorrow’s lovers',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '기타',
#    'repNationNm': '한국',
#    'repGenreNm': '기타',
#    'directors': [{'peopleNm': '김양희'}],
#    'companys': []},
#   {'movieCd': '20212572',
#    'movieNm': '바다 위의 별',
#    'movieNmEn': 'Stars on the Sea',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '애니메이션',
#    'repNationNm': '한국',
#    'repGenreNm': '애니메이션',
#    'directors': [{'peopleNm': '장승욱'}],
#    'companys': []},
#   {'movieCd': '20212585',
#    'movieNm': '평화가 사람 속을 걸어다니네',
#    'movieNmEn': 'Peace is Walking through The People',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '다큐멘터리',
#    'repNationNm': '한국',
#    'repGenreNm': '다큐멘터리',
#    'directors': [{'peopleNm': '함유선'}],
#    'companys': []},
#   {'movieCd': '20223826',
#    'movieNm': '애완거미',
#    'movieNmEn': 'Pet Spider',
#    'prdtYear': '2020',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '기타',
#    'repNationNm': '한국',
#    'repGenreNm': '기타',
#    'directors': [{'peopleNm': '구소정'}],
#    'companys': []},
#   {'movieCd': '20223832',
#    'movieNm': '소녀,안녕',
#    'movieNmEn': 'Farewell, Girl',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '기타',
#    'repNationNm': '한국',
#    'repGenreNm': '기타',
#    'directors': [{'peopleNm': '최윤호'}],
#    'companys': []},
#   {'movieCd': '20212064',
#    'movieNm': '여기, 나의 정원',
#    'movieNmEn': 'Here, My Garden',
#    'prdtYear': '2021',
#    'openDt': '',
#    'typeNm': '단편',
#    'prdtStatNm': '기타',
#    'nationAlt': '한국',
#    'genreAlt': '다큐멘터리',
#    'repNationNm': '한국',
#    'repGenreNm': '다큐멘터리',
#    'directors': [{'peopleNm': '김지곤'}],
#    'companys': []}]}

# %%
#s내가 20개의 영화를 요청했는데 정말 20개  보냈는제 체크
movie_data["movieListResult"].keys()
# Out:
# dict_keys(['totCnt', 'source', 'movieList'])

# %%
len(movie_data["movieListResult"]["movieList"])
# Out:
# 20

# %%
#받은 데이터 중 첫번째 영화 이름에 접근
movie_data["movieListResult"]["movieList"][0]["movieNm"] #순차적으로 접근 필요
# Out:
# '살아오름: 천년의 동행'

# %%
#1번 영화에서 감독이 여러명이면은 1번 감독에 대한 이름 출력
movie_data["movieListResult"]["movieList"][0]["directors"][0]["peopleNm"]
# Out:
# '안재훈'

# %%
#Q) 5번째 영화의 코드값 : movieCd
#Q) 5번째 영화의 국문명 : movieNm
#Q) 5번째 영화의 영문명 : movieNmEn
#Q) 5번째 영화의 개봉일 : openDt
#Q) 5번째 영화의 감독이 있다면 첫번째 감독 : directors
idx = 5
temp = movie_data["movieListResult"]["movieList"][idx]
print(temp["movieCd"])
print(temp["movieNm"])
print(temp["movieNmEn"])
print(temp["openDt"])
if temp["directors"] == []:
    print("")
else:
    print(temp["directors"][0]["peopleNm"])
# Out:
# 20219245
# 만년이 지나도 변하지 않는 게 있어
# Till We Meet Again
# 20220209
# 구파도

# %%
#아무것도 없는 빈 상태에서 정보를 추출해서 누적하면서 데이터를 쌓으려면?
#일단 필요한 DF : 2개  -> 1개 영화 정보 담을 DF : Only 1st / 누적할 DF : 0층부터 ??층까지
movie_df = pd.DataFrame()
movie_df_temp = pd.DataFrame()
movie_df_temp = movie_df_temp.append({"movieCd": "","movieNm":"","movieEn":"","openDt":"","DirName":""}, ignore_index=True)

movie_df_temp
# Out:
#   movieCd movieNm movieEn openDt DirName
# 0

# %%
#내가 받은 영화의 수를 기반으로 해야하니
num = len(movie_data["movieListResult"]["movieList"])
temp_code_id = movie_df_temp.columns.get_loc("movieCd") #컬럼 이름을 바로 쓰지 않고 위치로 추출해서 쓰면 오류 날 일 줄어듦
temp_name_id = movie_df_temp.columns.get_loc("movieNm") 
temp_enname_id = movie_df_temp.columns.get_loc("movieEn") 
temp_open_id = movie_df_temp.columns.get_loc("openDt") 
temp_dirname_id = movie_df_temp.columns.get_loc("DirName") 
#i번째 영화에 대해서 정보를 추출..(정수)
for i in range(0,num):
    #i번째 영화에 대해서 필요한 정보(코드,이름, 개봉일..) 추출 -> 단, 정보가 없을 수도 있으니 예외처리 필요
    i_movie = movie_data["movieListResult"]["movieList"][i]
    # -> temo에 기록 (가로:i번째, 세로: 그 정보 컬럼 정수)
    movie_df_temp.iat[0,temp_code_id] = i_movie["movieCd"]
    movie_df_temp.iat[0,temp_name_id] = i_movie["movieNm"]
    movie_df_temp.iat[0,temp_enname_id] = i_movie["movieNmEn"]
    movie_df_temp.iat[0,temp_open_id] = i_movie["openDt"]
    if i_movie["directors"] !=[]: # 감독정보 있을 때.
        movie_df_temp.iat[0,temp_dirname_id] = i_movie["directors"][0]["peopleNm"]
        
    #temp것을 movie_df에 추가
    movie_df = movie_df.append(movie_df_temp,ignore_index=True)
    
    #temp싹 방정리 -> 다음 영화 정보를...
    for j in range(len(movie_df_temp.columns)):
        movie_df_temp.iat[0, j] = ""

# %%
movie_df
# Out:
#      movieCd              movieNm                                   movieEn  \
# 0   20223827         살아오름: 천년의 동행                 A Thousand Years Together
# 1   20212836                  355                                   The 355
# 2   20201965           해적: 도깨비 깃발     The Pirates : The Last Royal Treasure
# 3   20223793      서유기: 손오공 홍해아 대전          The Journey to the West: Red Boy
# 4   20223266              애니멀 체인지                             The Wild Life
# 5   20219245  만년이 지나도 변하지 않는 게 있어                        Till We Meet Again
# 6   20205443             나일 강의 죽음                         Death on the Nile
# 7   20212871       가슴이 떨리는 건 너 때문
# 8   20223691        퇴폐의 온상 은밀한 만남
# 9   20223724        몸으로 대출 갚는 유부녀
# 10  20223808             레트로 6969
# 11  20223725   남편이 데려온 나를 괴롭히는 남자
# 12  20223674     그녀의 육체 앞에 무너진 이성
# 13  20212569             거북이와 여자들  Transmigration: the Turtle and the Women
# 14  20212570              내일의 연인들                         tomorrow’s lovers
# 15  20212572              바다 위의 별                          Stars on the Sea
# 16  20212585      평화가 사람 속을 걸어다니네       Peace is Walking through The People
# 17  20223826                 애완거미                                Pet Spider
# 18  20223832                소녀,안녕                            Farewell, Girl
# 19  20212064            여기, 나의 정원                           Here, My Garden
#
#       openDt  DirName
# 0                 안재훈
# 1   20220209  사이먼 킨버그
# 2   20220126      김정훈
# 3
# 4   20220209       정량
# 5   20220209      구파도
# 6   20220209  케네스 브래너
# 7   20220209
# 8   20220208      강현성
# 9   20220208   제너럴리스트
# 10  20220208      김기환
# 11
# 12  20220208      강현성
# 13                한선희
# 14                김양희
# 15                장승욱
# 16                함유선
# 17                구소정
# 18                최윤호
# 19                김지곤

# %%
#openDt를 year - month - day로 구분해주기
movie_df["year"] = movie_df.iloc[ :,temp_open_id].apply(lambda x : str(x)[:4] )
movie_df["month"] = movie_df.iloc[ :,temp_open_id].apply(lambda x : str(x)[4:6] )
movie_df["day"] = movie_df.iloc[ :,temp_open_id].apply(lambda x : str(x)[6:] )
movie_df
# Out:
#      movieCd              movieNm                                   movieEn  \
# 0   20223827         살아오름: 천년의 동행                 A Thousand Years Together
# 1   20212836                  355                                   The 355
# 2   20201965           해적: 도깨비 깃발     The Pirates : The Last Royal Treasure
# 3   20223793      서유기: 손오공 홍해아 대전          The Journey to the West: Red Boy
# 4   20223266              애니멀 체인지                             The Wild Life
# 5   20219245  만년이 지나도 변하지 않는 게 있어                        Till We Meet Again
# 6   20205443             나일 강의 죽음                         Death on the Nile
# 7   20212871       가슴이 떨리는 건 너 때문
# 8   20223691        퇴폐의 온상 은밀한 만남
# 9   20223724        몸으로 대출 갚는 유부녀
# 10  20223808             레트로 6969
# 11  20223725   남편이 데려온 나를 괴롭히는 남자
# 12  20223674     그녀의 육체 앞에 무너진 이성
# 13  20212569             거북이와 여자들  Transmigration: the Turtle and the Women
# 14  20212570              내일의 연인들                         tomorrow’s lovers
# 15  20212572              바다 위의 별                          Stars on the Sea
# 16  20212585      평화가 사람 속을 걸어다니네       Peace is Walking through The People
# 17  20223826                 애완거미                                Pet Spider
# 18  20223832                소녀,안녕                            Farewell, Girl
# 19  20212064            여기, 나의 정원                           Here, My Garden
#
#       openDt  DirName  year month day
# 0                 안재훈
# 1   20220209  사이먼 킨버그  2022    02  09
# 2   20220126      김정훈  2022    01  26
# 3
# 4   20220209       정량  2022    02  09
# 5   20220209      구파도  2022    02  09
# 6   20220209  케네스 브래너  2022    02  09
# 7   20220209           2022    02  09
# 8   20220208      강현성  2022    02  08
# 9   20220208   제너럴리스트  2022    02  08
# 10  20220208      김기환  2022    02  08
# 11
# 12  20220208      강현성  2022    02  08
# 13                한선희
# 14                김양희
# 15                장승욱
# 16                함유선
# 17                구소정
# 18                최윤호
# 19                김지곤

# %%
#컬럼을 가로줄에 대한 내가 만든 인덱스로
#일단 하기전에 openDt 순서대로 먼저 정렬하고 그 순서대로 가로줄 인덱스로
movie_df.sort_values(by = "openDt", ascending = False, inplace = True)
#컬럼을 주고, 그 컬럼을 가로줄 인덱스로 지정
#주의) 그 컬럼이 없으면 에러
movie_df.set_index("movieCd", inplace=True)
movie_df
# Out:
#                       movieNm                                   movieEn  \
# movieCd
# 20223266              애니멀 체인지                             The Wild Life
# 20219245  만년이 지나도 변하지 않는 게 있어                        Till We Meet Again
# 20205443             나일 강의 죽음                         Death on the Nile
# 20212871       가슴이 떨리는 건 너 때문
# 20212836                  355                                   The 355
# 20223808             레트로 6969
# 20223691        퇴폐의 온상 은밀한 만남
# 20223724        몸으로 대출 갚는 유부녀
# 20223674     그녀의 육체 앞에 무너진 이성
# 20201965           해적: 도깨비 깃발     The Pirates : The Last Royal Treasure
# 20212572              바다 위의 별                          Stars on the Sea
# 20223832                소녀,안녕                            Farewell, Girl
# 20223826                 애완거미                                Pet Spider
# 20212585      평화가 사람 속을 걸어다니네       Peace is Walking through The People
# 20223827         살아오름: 천년의 동행                 A Thousand Years Together
# 20212570              내일의 연인들                         tomorrow’s lovers
# 20212569             거북이와 여자들  Transmigration: the Turtle and the Women
# 20223725   남편이 데려온 나를 괴롭히는 남자
# 20223793      서유기: 손오공 홍해아 대전          The Journey to the West: Red Boy
# 20212064            여기, 나의 정원                           Here, My Garden
#
#             openDt  DirName  year month day
# movieCd
# 20223266  20220209       정량  2022    02  09
# 20219245  20220209      구파도  2022    02  09
# 20205443  20220209  케네스 브래너  2022    02  09
# 20212871  20220209           2022    02  09
# 20212836  20220209  사이먼 킨버그  2022    02  09
# 20223808  20220208      김기환  2022    02  08
# 20223691  20220208      강현성  2022    02  08
# 20223724  20220208   제너럴리스트  2022    02  08
# 20223674  20220208      강현성  2022    02  08
# 20201965  20220126      김정훈  2022    01  26
# 20212572                장승욱
# 20223832                최윤호
# 20223826                구소정
# 20212585                함유선
# 20223827                안재훈
# 20212570                김양희
# 20212569                한선희
# 20223725
# 20223793
# 20212064                김지곤

# %%
#컬럼 순서를 변경
movie_df = movie_df.loc[ :, ["openDt","year","month","day","movieNm","movieEn"]]
movie_df.head()
# Out:
#             openDt  year month day              movieNm             movieEn
# movieCd
# 20223266  20220209  2022    02  09              애니멀 체인지       The Wild Life
# 20219245  20220209  2022    02  09  만년이 지나도 변하지 않는 게 있어  Till We Meet Again
# 20205443  20220209  2022    02  09             나일 강의 죽음   Death on the Nile
# 20212871  20220209  2022    02  09       가슴이 떨리는 건 너 때문
# 20212836  20220209  2022    02  09                  355             The 355

# %%
#엑셀로 내보내기
movie_df.to_excel("01_data/movie_list_xlsx.xlsx")

# %%
#지금 하려는 것은 개별 영화의 속성을 더 추가
# --> 형태적으로 옆으로 늘어나는 모양

# %%
#잠시) 상세 정보 요청하고, 처리하는 기능 체크
#1) 광해에 대한 상세 정보 요청 url (본인의 키값으로 작성)
url_p1 = "https://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key="
key = "955ef5d888fc11ea84bbe892453318e3"
url_p2 = "&movieCd="
movie_code = "20124079" #영화 코드만 변경하면 영화 바뀜
url = url_p1 + key + url_p2 + movie_code
#2) 그 주소에 대하여 통신(urllib.request.urlopen)
temp_page = urllib.request.urlopen(url)
#3) 파이썬에서 접근이 용이하게  json패기지써서 문자열 데이터를 파이썬dict, list처럼 변형
movie_info = json.loads(temp_page.read().decode("utf-8"))
movie_info
# Out:
# {'movieInfoResult': {'movieInfo': {'movieCd': '20124079',
#    'movieNm': '광해, 왕이 된 남자',
#    'movieNmEn': 'Masquerade',
#    'movieNmOg': '',
#    'showTm': '131',
#    'prdtYear': '2012',
#    'openDt': '20120913',
#    'prdtStatNm': '개봉',
#    'typeNm': '장편',
#    'nations': [{'nationNm': '한국'}],
#    'genres': [{'genreNm': '사극'}, {'genreNm': '드라마'}],
#    'directors': [{'peopleNm': '추창민', 'peopleNmEn': 'CHOO Chang-min'}],
#    'actors': [{'peopleNm': '이병헌',
#      'peopleNmEn': 'LEE Byung-hun',
#      'cast': '광해/하선',
#      'castEn': ''},
#     {'peopleNm': '류승룡',
#      'peopleNmEn': 'RYU Seung-ryong',
#      'cast': '허균',
#      'castEn': ''},
#     {'peopleNm': '한효주',
#      'peopleNmEn': 'HAN Hyo-joo',
#      'cast': '중전',
#      'castEn': ''},
#     {'peopleNm': '장광',
#      'peopleNmEn': 'JANG Kwang',
#      'cast': '조내관',
#      'castEn': ''},
#     {'peopleNm': '김인권',
#      'peopleNmEn': 'KIM In-kwon',
#      'cast': '도부장',
#      'castEn': ''},
#     {'peopleNm': '심은경',
#      'peopleNmEn': 'SHIM Eun-kyoung',
#      'cast': '사월이',
#      'castEn': ''},
#     {'peopleNm': '김명곤',
#      'peopleNmEn': 'KIM Myung-kon',
#      'cast': '박충수',
#      'castEn': ''},
#     {'peopleNm': '서진원',
#      'peopleNmEn': 'SEO Jin-won',
#      'cast': '도총관',
#      'castEn': ''},
#     {'peopleNm': '장재현',
#      'peopleNmEn': 'JANG Jae-hyun',
#      'cast': '광해 등불 내관1',
#      'castEn': ''},
#     {'peopleNm': '정창국', 'peopleNmEn': '', 'cast': '자객2', 'castEn': ''},
#     {'peopleNm': '조혜정', 'peopleNmEn': '', 'cast': '기미 궁녀1', 'castEn': ''},
#     {'peopleNm': '김남준', 'peopleNmEn': '', 'cast': '강원도 현감', 'castEn': ''},
#     {'peopleNm': '이수용', 'peopleNmEn': '', 'cast': '칼자국', 'castEn': ''},
#     {'peopleNm': '박윤호',
#      'peopleNmEn': 'PARK Yoon-ho',
#      'cast': '유생4',
#      'castEn': ''},
#     {'peopleNm': '김지수', 'peopleNmEn': '', 'cast': '자객1', 'castEn': ''},
#     {'peopleNm': '박민규', 'peopleNmEn': '', 'cast': '광해 등불 내관2', 'castEn': ''},
#     {'peopleNm': '박지아',
#      'peopleNmEn': 'PARK Zi-a',
#      'cast': '한상궁',
#      'castEn': ''},
#     {'peopleNm': '송미정', 'peopleNmEn': '', 'cast': '사월이 대역', 'castEn': ''},
#     {'peopleNm': '양준모', 'peopleNmEn': '', 'cast': '', 'castEn': ''},
#     {'peopleNm': '원동연',
#      'peopleNmEn': 'WON Dong-yeon',
#      'cast': '홍루몽 선비',
#      'castEn': ''},
#     {'peopleNm': '김종구',
#      'peopleNmEn': 'KIM Jong-gu',
#      'cast': '광해 어의',
#      'castEn': ''},
#     {'peopleNm': '주영호',
#      'peopleNmEn': 'JU Yeong-ho',
#      'cast': '광해 별감1',
#      'castEn': ''},
#     {'peopleNm': '이엘', 'peopleNmEn': 'LEE El', 'cast': '안개시', 'castEn': ''},
#     {'peopleNm': '전배수',
#      'peopleNmEn': 'JEON Bae-soo',
#      'cast': '형판',
#      'castEn': ''},
#     {'peopleNm': '이란희',
#      'peopleNmEn': 'LEE Ran-hee',
#      'cast': '수라간 궁녀3',
#      'castEn': ''},
#     {'peopleNm': '최욱',
#      'peopleNmEn': 'CHOI Wook',
#      'cast': '유생 2',
#      'castEn': ''},
#     {'peopleNm': '이봉련',
#      'peopleNmEn': 'LEE Bong-ryeon',
#      'cast': '수라간 궁녀1',
#      'castEn': ''},
#     {'peopleNm': '허성태',
#      'peopleNmEn': 'HEO Sungtae',
#      'cast': '국문장 나장1',
#      'castEn': ''},
#     {'peopleNm': '이양희',
#      'peopleNmEn': 'LEE Yang-hee',
#      'cast': '공판',
#      'castEn': ''},
#     {'peopleNm': '전국향',
#      'peopleNmEn': 'JEON Guk-hyang',
#      'cast': '정상궁',
#      'castEn': ''},
#     {'peopleNm': '김승훈',
#      'peopleNmEn': 'KIM Seung-hoon',
#      'cast': '이방',
#      'castEn': ''},
#     {'peopleNm': '권은수',
#      'peopleNmEn': 'GWON Eun-su',
#      'cast': '광해수건궁녀',
#      'castEn': ''},
#     {'peopleNm': '승의열',
#      'peopleNmEn': 'SEUNG Ui -yeol',
#      'cast': '사월 어의',
#      'castEn': ''},
#     {'peopleNm': '김비비',
#      'peopleNmEn': 'KIM Bi-bi',
#      'cast': '중전 궁녀',
#      'castEn': ''},
#     {'peopleNm': '한이진',
#      'peopleNmEn': 'HAN Iee-jin',
#      'cast': '하선 포졸1',
#      'castEn': ''},
#     {'peopleNm': '이은정', 'peopleNmEn': '', 'cast': '광해상궁', 'castEn': ''}],
#    'showTypes': [{'showTypeGroupNm': '필름', 'showTypeNm': '필름'},
#     {'showTypeGroupNm': '필름', 'showTypeNm': '청각장애인용 자막'},
#     {'showTypeGroupNm': '2D', 'showTypeNm': '디지털'},
#     {'showTypeGroupNm': '2D', 'showTypeNm': '디지털 영문자막'},
#     {'showTypeGroupNm': '2D', 'showTypeNm': '디지털 일어자막'},
#     {'showTypeGroupNm': '2D', 'showTypeNm': '디지털 가치봄'}],
#    'companys': [{'companyCd': '20100540',
#      'companyNm': '리얼라이즈픽쳐스(주)',
#      'companyNmEn': 'Realies Pictures, Inc.',
#      'companyPartNm': '제작사'},
#     {'companyCd': '20110854',
#      'companyNm': '(주)씨제이이엔엠',
#      'companyNmEn': 'CJ ENM Corp.',
#      'companyPartNm': '제작사'},
#     {'companyCd': '20110854',
#      'companyNm': '(주)씨제이이엔엠',
#      'companyNmEn': 'CJ ENM Corp.',
#      'companyPartNm': '배급사'},
#     {'companyCd': '20110854',
#      'companyNm': '(주)씨제이이엔엠',
 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '임재경',
#      'peopleNmEn': 'Lim Jae-kyung',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '임지호', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '임현정',
#      'peopleNmEn': 'Lim Hyun Jung',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '장정웅', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '장지연',
#      'peopleNmEn': 'JANG Ji-youn',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '정경숙',
#      'peopleNmEn': 'JEONG KYUNG SUK',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '정연찬', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '정우철',
#      'peopleNmEn': 'JEONG Woo-cheol',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '정재화',
#      'peopleNmEn': 'JUNG Jae Hwa',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김풍래', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김성준', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김성철', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김성환', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김세리', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '최지원',
#      'peopleNmEn': 'CHOI Ji-won',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '최진호',
#      'peopleNmEn': 'CHOI JIN HO',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김수한',
#      'peopleNmEn': 'Kim Soo-han',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '하돈수', 'peopleNmEn': 'HA DON SOO', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '박원봉', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '함유섭',
#      'peopleNmEn': 'HAM Yu-seop',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '홍서연',
#      'peopleNmEn': 'HONG Seo Yeon',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '홍정희',
#      'peopleNmEn': 'HONG Jung-hee',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '이문형', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김영미',
#      'peopleNmEn': 'KIM Young-mi',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김영아',
#      'peopleNmEn': 'Kim Young-a',
#      'staffRoleNm': 'VFX 아티스트'},
#     {'peopleNm': '김용빈', 'peopleNmEn': '', 'staffRoleNm': 'VFX 아티스트'}]},
#   'source': '영화진흥위원회'}}

# %%
#Q) 광해 영화의 장르는?
print(movie_info["movieInfoResult"]["movieInfo"]["genres"][0]["genreNm"])
#Q) 광해 영화의 출연한 배우의 수는?
print(len(movie_info["movieInfoResult"]["movieInfo"]["actors"]))
#Q) 광해 영화의 배우 정보가 있다면, 1번 배우에 대한 이름
print(movie_info["movieInfoResult"]["movieInfo"]["actors"][0]["peopleNm"])
#Q)                                    "  "                의 배역 이름
print(movie_info["movieInfoResult"]["movieInfo"]["actors"][0]["cast"])
# Out:
# 사극
# 36
# 이병헌
# 광해/하선

# %%
#movie_df의 기존 DF에서 장르 컬럼 추가 + 출연 배우 수 추가  +  1번 배우 배역 이름 추가 + 1번 배우 배역 이름 추가 -> 옆으로 확장
movie_df["Genre"] = ""
movie_df["ActNum"] = ""
movie_df["actActName"] = ""
movie_df["ActCast"] = ""

movie_df
# Out:
#                       movieNm                                   movieEn  \
# movieCd
# 20223266              애니멀 체인지                             The Wild Life
# 20219245  만년이 지나도 변하지 않는 게 있어                        Till We Meet Again
# 20205443             나일 강의 죽음                         Death on the Nile
# 20212871       가슴이 떨리는 건 너 때문
# 20212836                  355                                   The 355
# 20223808             레트로 6969
# 20223691        퇴폐의 온상 은밀한 만남
# 20223724        몸으로 대출 갚는 유부녀
# 20223674     그녀의 육체 앞에 무너진 이성
# 20201965           해적: 도깨비 깃발     The Pirates : The Last Royal Treasure
# 20212572              바다 위의 별                          Stars on the Sea
# 20223832                소녀,안녕                            Farewell, Girl
# 20223826                 애완거미                                Pet Spider
# 20212585      평화가 사람 속을 걸어다니네       Peace is Walking through The People
# 20223827         살아오름: 천년의 동행                 A Thousand Years Together
# 20212570              내일의 연인들                         tomorrow’s lovers
# 20212569             거북이와 여자들  Transmigration: the Turtle and the Women
# 20223725   남편이 데려온 나를 괴롭히는 남자
# 20223793      서유기: 손오공 홍해아 대전          The Journey to the West: Red Boy
# 20212064            여기, 나의 정원                           Here, My Garden
#
#             openDt  DirName  year month day Genre actActName ActCast ActNum
# movieCd
# 20223266  20220209       정량  2022    02  09
# 20219245  20220209      구파도  2022    02  09
# 20205443  20220209  케네스 브래너  2022    02  09
# 20212871  20220209           2022    02  09
# 20212836  20220209  사이먼 킨버그  2022    02  09
# 20223808  20220208      김기환  2022    02  08
# 20223691  20220208      강현성  2022    02  08
# 20223724  20220208   제너럴리스트  2022    02  08
# 20223674  20220208      강현성  2022    02  08
# 20201965  20220126      김정훈  2022    01  26
# 20212572                장승욱
# 20223832                최윤호
# 20223826                구소정
# 20212585                함유선
# 20223827                안재훈
# 20212570                김양희
# 20212569                한선희
# 20223725
# 20223793
# 20212064                김지곤

# %%
#접근 1) movie_df를 대상으로 영화코드값을 20개 출력해보세요
#    단, movie_df에서 반복문 for를 중심으로
movie_DF = pd.DataFrame()

for i_code in movie_df.index:
    #print(i_code)
    # i_code에 대한 상세정보를 요청하는 url만들기
    url_p1 = "https://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key="
    key = "955ef5d888fc11ea84bbe892453318e3"
    url_p2 = "&movieCd="
    movie_code = i_code
    url = url_p1 + key + url_p2 + movie_code
    #접근 2) 영화코드별로 상세정보를 요청하는 url을 출력해보세요
    #print(url)
    # i_code에 대한 상세정보 url을 직접 요청 -> 받아서 -> 처리하기 편하게 json 
    temp_page = urllib.request.urlopen(url)
    temp_data = json.loads(temp_page.read().decode("utf-8"))
    #필요정보 추출 -> DF에 위치에 맞게 업데이트
    temp_genre_id = movie_df.columns.get_loc("Genre")
    temp_actnum_id = movie_df.columns.get_loc("ActNum")
    temp_actname_id = movie_df.columns.get_loc("actActName")
    temp_castname_id = movie_df.columns.get_loc("ActCast")
    movie_df.iat[0,temp_genre_id] = temp_data["movieInfoResult"]["movieInfo"]["genres"][0]["genreNm"]
    movie_df.iat[0,temp_actnum_id] = len(temp_data["movieInfoResult"]["movieInfo"]["actors"])
    if temp_data["movieInfoResult"]["movieInfo"]["actors"] != []:
        
        movie_df.iat[0,temp_actname_id] = temp_data["movieInfoResult"]["movieInfo"]["actors"][0]["peopleNm"]
    movie_df.iat[0,temp_castname_id] = temp_data["movieInfoResult"]["movieInfo"]["actors"][0]["cast"]
    
    movie_DF = movie_DF.append(movie_df,ignore_index=True)
    
    #temp싹 방정리 -> 다음 영화 정보를...
    for j in range(len(movie_df.columns)):
        movie_df.iat[0, j] = ""

movie_DF
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_415068/1490620142.py in <module>
#      25     if temp_data["movieInfoResult"]["movieInfo"]["actors"] != []:
#      26         movie_df.iat[0,temp_actname_id] = temp_data["movieInfoResult"]["movieInfo"]["actors"][0]["peopleNm"]
# ---> 27     movie_df.iat[0,temp_castname_id] = temp_data["movieInfoResult"]["movieInfo"]["actors"][0]["cast"]
#      28
#      29     movie_DF = movie_DF.append(movie_df,ignore_index=True)
#
# IndexError: list index out of range

# %%
if temp_data["movieInfoResult"]["movieInfo"]["actors"] != []:
    print( temp_data["movieInfoResult"]["movieInfo"]["actors"][0]["peopleNm"])
