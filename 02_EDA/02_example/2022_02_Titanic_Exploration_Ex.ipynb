# %% [markdown]
# ###  Titanic_train.csv 파일을 data라는 변수에 불러오고, PassengerId를 index로 지정을 하시오!!!
# 필요한 패키지는 numpy / pandas / matplolib.pyplot

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Cumings, Mrs. John Bradley (Florence Briggs Th...</td>
#       <td>female</td>
#       <td>38.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>PC 17599</td>
#       <td>71.2833</td>
#       <td>C85</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>3</td>
#       <td>Heikkinen, Miss. Laina</td>
#       <td>female</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>STON/O2. 3101282</td>
#       <td>7.9250</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Futrelle, Mrs. Jacques Heath (Lily May Peel)</td>
#       <td>female</td>
#       <td>35.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>113803</td>
#       <td>53.1000</td>
#       <td>C123</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0</td>
#       <td>3</td>
#       <td>Allen, Mr. William Henry</td>
#       <td>male</td>
#       <td>35.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>373450</td>
#       <td>8.0500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 받은 데이터의 간략적인 정보 확인하세요!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>714.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.383838</td>
#       <td>2.308642</td>
#       <td>29.699118</td>
#       <td>0.523008</td>
#       <td>0.381594</td>
#       <td>32.204208</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.486592</td>
#       <td>0.836071</td>
#       <td>14.526497</td>
#       <td>1.102743</td>
#       <td>0.806057</td>
#       <td>49.693429</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.420000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.000000</td>
#       <td>2.000000</td>
#       <td>20.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7.910400</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.000000</td>
#       <td>3.000000</td>
#       <td>28.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>14.454200</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.000000</td>
#       <td>3.000000</td>
#       <td>38.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>31.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>1.000000</td>
#       <td>3.000000</td>
#       <td>80.000000</td>
#       <td>8.000000</td>
#       <td>6.000000</td>
#       <td>512.329200</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 데이터들에서 NaN이 없는지 확인!!!

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# * 항목별로 이상한 데이터들의 비율을 계산하시오!!!

# %%
# Out:
# Survived 0.0 %
# Pclass 0.0 %
# Name 0.0 %
# Sex 0.0 %
# Age 0.19865319865319866 %
# SibSp 0.0 %
# Parch 0.0 %
# Ticket 0.0 %
# Fare 0.0 %
# Cabin 0.7710437710437711 %
# Embarked 0.002244668911335578 %

# %% [markdown]
# ### 참고 : 데이터 항목 설명[ surveved : 생존여부(0/1), Pclass : 티켓의 클래스(1은 1st, 2는 2nd ..), name : 승객이름, sex : 승객성별, Age : 승객나이, SibSp : 함께 탑승한 형재와 배우자의 수, parch : 함께 탑승한 부모, 아이의 수, ticket: 티켓번호, Fare: 탑승료, cabin : 객실번호, embarked :탑승항구(C:Cherboug, Q :Queenstown, S:south ampton)]

# %% [markdown]
# * 탑승항구가 Cherboug 이면서, 탑승료를 200 초과로 지불한 사람들에 대한 데이터를 추리고, head로 앞에 불러서 확인!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>119</th>
#       <td>0</td>
#       <td>1</td>
#       <td>Baxter, Mr. Quigg Edmond</td>
#       <td>male</td>
#       <td>24.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>PC 17558</td>
#       <td>247.5208</td>
#       <td>B58 B60</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>259</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Ward, Miss. Anna</td>
#       <td>female</td>
#       <td>35.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>PC 17755</td>
#       <td>512.3292</td>
#       <td>NaN</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>300</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Baxter, Mrs. James (Helene DeLaudeniere Chaput)</td>
#       <td>female</td>
#       <td>50.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>PC 17558</td>
#       <td>247.5208</td>
#       <td>B58 B60</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>312</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Ryerson, Miss. Emily Borie</td>
#       <td>female</td>
#       <td>18.0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>PC 17608</td>
#       <td>262.3750</td>
#       <td>B57 B59 B63 B66</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>378</th>
#       <td>0</td>
#       <td>1</td>
#       <td>Widener, Mr. Harry Elkins</td>
#       <td>male</td>
#       <td>27.0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>113503</td>
#       <td>211.5000</td>
#       <td>C82</td>
#       <td>C</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 위의 조건에(항구/요금) 해당하는 것들을 요금에 대한 기준으로 정리를 하세요(요금이 높은 사람부터 낮은 사람 순서대로.)

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>259</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Ward, Miss. Anna</td>
#       <td>female</td>
#       <td>35.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>PC 17755</td>
#       <td>512.3292</td>
#       <td>NaN</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>680</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Cardeza, Mr. Thomas Drake Martinez</td>
#       <td>male</td>
#       <td>36.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>PC 17755</td>
#       <td>512.3292</td>
#       <td>B51 B53 B55</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>738</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Lesurer, Mr. Gustave J</td>
#       <td>male</td>
#       <td>35.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>PC 17755</td>
#       <td>512.3292</td>
#       <td>B101</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>312</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Ryerson, Miss. Emily Borie</td>
#       <td>female</td>
#       <td>18.0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>PC 17608</td>
#       <td>262.3750</td>
#       <td>B57 B59 B63 B66</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>743</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Ryerson, Miss. Susan Parker "Suzette"</td>
#       <td>female</td>
#       <td>21.0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>PC 17608</td>
#       <td>262.3750</td>
#       <td>B57 B59 B63 B66</td>
#       <td>C</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 나이에 대항 카테고리를 정리하는 함수를 만들고(기준은 30미만은 1, 30이상~55미만은 2, 그 이상은 3으로 코딩)하는 함수 만들기.

# %% [markdown]
# * 위의 나이를 분류하는 함수를 바탕으로 Age_catogory하는 컬럼을 만들어서 생성하시오!!!

# %% [markdown]
# * 성별이 남성, 성별이 여성인 사람들의 각각 전체 수는?

# %%
# Out:
# (577, 314)

# %% [markdown]
# * 성별에 대해서 남성/여성이 어떻게 분포하는지 확인

# %%
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# * 선실 등급 별로 성별이 어떻게 분포하는지 확인

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sex</th>
#       <th>female</th>
#       <th>male</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Pclass</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>94</td>
#       <td>122</td>
#       <td>216</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>76</td>
#       <td>108</td>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>144</td>
#       <td>347</td>
#       <td>491</td>
#     </tr>
#     <tr>
#       <th>All</th>
#       <td>314</td>
#       <td>577</td>
#       <td>891</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * crosstab 에서도 아래와 같이 꾸밀 수 있음!!

# %%
# Out:
# <style  type="text/css" >
#     #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col0 {
#             background-color:  #ecf666;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col1 {
#             background-color:  #f8fc66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col0 {
#             background-color:  #ffff66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col1 {
#             background-color:  #ffff66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col2 {
#             background-color:  #ffff66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col0 {
#             background-color:  #b6db66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col1 {
#             background-color:  #7dbe66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col2 {
#             background-color:  #90c866;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row3_col0 {
#             background-color:  #008066;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row3_col1 {
#             background-color:  #008066;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2" >
# <thead>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" >female</th>
#         <th class="col_heading level0 col1" >male</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col0" class="data row0 col0" >94</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col1" class="data row0 col1" >122</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col0" class="data row1 col0" >76</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col1" class="data row1 col1" >108</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col0" class="data row2 col0" >144</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col1" class="data row2 col1" >347</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row3_col0" class="data row3 col0" >314</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row3_col1" class="data row3 col1" >577</td>
#         <td id="T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# * 아래 그림과 같이 Pclass에 대한 히스토그램을 그리는데, 남자/여자/전체에 대해서 나타날 수 있도록 그리시오.

# %% [markdown]
# * 요금(fare)에 대한 평균/ 중앙값(median)/표준편차를 구해보시오.

# %%
round(12345.67891234,3)
# Out:
# 12345.679

# %%
# Out:
# Median fare:  14.45
# Fare std:  49.69

# %% [markdown]
# * 아래 그래프와 같이 생존 여부에 대한 나이별로 그래프를 나타내보시오!

# %% [markdown]
# * seaborn 패키지를 로드하세요.

# %% [markdown]
# * 아래 그림과 같이 생존 여부에 대한 나이별로 boxplot를 그려보세요.

# %% [markdown]
# * 생존자한 사람들의 나이 평균, 생존하지 못한 사람들의 나이 평균을 구하세요.

# %%
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %% [markdown]
# * 위의 결과들을 보고, 본인만의 기준을 가지고 (젊은 생존자의 구분 : 예 30, 나이든 생존자의 구분: 예60)이런 식으로 구분을 하고, 각기 전체에서 얼마나 차지하는지 비율을 계산해보세요..

# %%
# Out:
# 젊은 생존자 : 40.6
# 고령 생존자 : 22.7

# %% [markdown]
# * 남성 중에서 생존자들과, 여성 중에서 생존자들에 대한 것을 가지고 각기 평균 비율을 구하시오.

# %%
# Out:
# 남성 생존자 :  18.9
# 여성 생존자 :  74.2

# %% [markdown]
# * 이름 컬럼에 대한 head()를 보이세요.

# %%
# Out:
# PassengerId
# 1                              Braund, Mr. Owen Harris
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %% [markdown]
# * 1번 사람의 이름을 , 를 구분하여 분리해서,.  first name만 나타내보세요.

# %%
# Out:
# 'Owen'

# %% [markdown]
# * first_names 라는 변수를 만들어서 성별이 남자인 사람들의 firstname을 구하고, 각기  firstname별로 얼마나 많이 나타나는지 확인하세요.

# %%
# Out:
# William    35
# John       25
# George     14
# Thomas     13
# Charles    13
# Name: Name, dtype: int64

# %% [markdown]
# * 각 등급별로 남성/여성의 평균 나이를 계산해서 나타내시오..

# %%
# Out:
# 평균나이 : male // 객실등급 3: 26.51
# 평균나이 : female // 객실등급 3: 21.75
# 평균나이 : male // 객실등급 1: 41.28
# 평균나이 : female // 객실등급 1: 34.61
# 평균나이 : male // 객실등급 2: 30.74
# 평균나이 : female // 객실등급 2: 28.72

# %%
# Out:
# 평균 나이 :female // 등급 : 1: 34.61
# 평균 나이 :male // 등급 : 1: 41.28
# 평균 나이 :female // 등급 : 2: 28.72
# 평균 나이 :male // 등급 : 2: 30.74
# 평균 나이 :female // 등급 : 3: 21.75
# 평균 나이 :male // 등급 : 3: 26.51

# %% [markdown]
# * 등급별로 성별에 대한 나이 평균을 표로 만드세요.

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sex</th>
#       <th>female</th>
#       <th>male</th>
#     </tr>
#     <tr>
#       <th>Pclass</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>34.611765</td>
#       <td>41.281386</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28.722973</td>
#       <td>30.740707</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21.750000</td>
#       <td>26.507589</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 위의 그래프는 boxplot으로 나타내시오

# %% [markdown]
# * 정보를 보면 cabin에 대해서는 정보가 많이 부족하기에, 이 항목은 제거.

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 1 to 891
# Data columns (total 10 columns):
# Survived    712 non-null int64
# Pclass      712 non-null int64
# Name        712 non-null object
# Sex         712 non-null object
# Age         712 non-null float64
# SibSp       712 non-null int64
# Parch       712 non-null int64
# Ticket      712 non-null object
# Fare        712 non-null float64
# Embarked    712 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 61.2+ KB

# %% [markdown]
# * survived/Age/Fare/SibSp/Parch에 대한 pairplot 그려보기

# %% [markdown]
# * Pclass, Fare에 대한 boxplot를 그려보시오!

# %% [markdown]
# * 위의 그래프를 보고, 원본 데이터에 대해서 이상한 아웃라이어를 제거하고 싶음. 그 기준은 0.95 인 quantile에 대한 값으로..수정을 해보자...

# %% [markdown]
# * Pclass별로 생존 여부 확인 --> 안 좋은 사실이 발견이 됨;;;ㅠㅠ

# %%
# Out:
# Text(0.5,1,'Pclass:Survived vs Death')

# %%
import h5py

# %%
f=h5py.File("/Users/minkyukwon/Desktop/2020_1_2/50_DataExploration/03_titanic/TRAAAAW128F429D538.h5","r")

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['analysis', 'metadata', 'musicbrainz']>

# %%
list(f.keys())[0]
# Out:
# 'analysis'

# %%
list(f[list(f.keys())[0]])
# Out:
# ['bars_confidence',
#  'bars_start',
#  'beats_confidence',
#  'beats_start',
#  'sections_confidence',
#  'sections_start',
#  'segments_confidence',
#  'segments_loudness_max',
#  'segments_loudness_max_time',
#  'segments_loudness_start',
#  'segments_pitches',
#  'segments_start',
#  'segments_timbre',
#  'songs',
#  'tatums_confidence',
#  'tatums_start']
