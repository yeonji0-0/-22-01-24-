# %% [markdown]
# # Col 구성

# %% [markdown]
# ## 결혼, 이혼, 전입, 전출, 출생, 사망

# %%
import pandas as pd
import numpy as np

# %%
ma = pd.read_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\서울시_출생_사망.xls')

# %%
ma
# Out:
#        기간  자치구     동     출생   출생.1   출생.2     사망   사망.1   사망.2
# 0      기간  자치구     동      계     남자     여자      계     남자     여자
# 1    2020   합계    합계  47445  24344  23101  45522  25626  19896
# 2    2020  종로구    소계    529    268    261    867    519    348
# 3    2020  종로구   사직동     28     13     15     46     27     19
# 4    2020  종로구   삼청동      9      5      4     24     14     10
# ..    ...  ...   ...    ...    ...    ...    ...    ...    ...
# 447  2020  강동구  둔촌1동      1      -      1      1      -      1
# 448  2020  강동구  둔촌2동    148     73     75    121     72     49
# 449  2020  강동구  암사1동    186     93     93    172    110     62
# 450  2020  강동구  천호2동    175     88     87    175     99     76
# 451  2020  강동구    길동    209    104    105    210    118     92
#
# [452 rows x 9 columns]

# %%
ma.drop(ma['자치구'] == '합계', axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_129992/4014271208.py in <module>
# ----> 1 ma.drop(ma['자치구'] == '합계', axis=0, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
ma_1 = ma[['자치구']]
ma_1
# Out:
#      자치구
# 0    자치구
# 1     합계
# 2    종로구
# 3    종로구
# 4    종로구
# ..   ...
# 447  강동구
# 448  강동구
# 449  강동구
# 450  강동구
# 451  강동구
#
# [452 rows x 1 columns]

# %%
ma[ma['자치구']=='합계']
# Out:
#      기간 자치구   동     출생   출생.1   출생.2     사망   사망.1   사망.2
# 1  2020  합계  합계  47445  24344  23101  45522  25626  19896

# %%
ma.drop('기간', axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_129992/3236576163.py in <module>
# ----> 1 ma.drop('합계', axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
len(ma['기간']==2020)
# Out:
# 452

# %%
ma.drop('기간', inplace=True, axis=1)

# %%
ma
# Out:
#      자치구     동     출생   출생.1   출생.2     사망   사망.1   사망.2
# 0    자치구     동      계     남자     여자      계     남자     여자
# 1     합계    합계  47445  24344  23101  45522  25626  19896
# 2    종로구    소계    529    268    261    867    519    348
# 3    종로구   사직동     28     13     15     46     27     19
# 4    종로구   삼청동      9      5      4     24     14     10
# ..   ...   ...    ...    ...    ...    ...    ...    ...
# 447  강동구  둔촌1동      1      -      1      1      -      1
# 448  강동구  둔촌2동    148     73     75    121     72     49
# 449  강동구  암사1동    186     93     93    172    110     62
# 450  강동구  천호2동    175     88     87    175     99     76
# 451  강동구    길동    209    104    105    210    118     92
#
# [452 rows x 8 columns]

# %%
ma_1 = ma[ma['자치구']!='합계']
# Out:
# 자치구     자치구
# 동         동
# 출생        계
# 출생.1     남자
# 출생.2     여자
# 사망        계
# 사망.1     남자
# 사망.2     여자
# Name: 0, dtype: object

# %%
ma_1
# Out:
#      자치구     동   출생 출생.1 출생.2   사망 사망.1 사망.2
# 0    자치구     동    계   남자   여자    계   남자   여자
# 2    종로구    소계  529  268  261  867  519  348
# 3    종로구   사직동   28   13   15   46   27   19
# 4    종로구   삼청동    9    5    4   24   14   10
# 5    종로구   부암동   21   12    9   45   24   21
# ..   ...   ...  ...  ...  ...  ...  ...  ...
# 447  강동구  둔촌1동    1    -    1    1    -    1
# 448  강동구  둔촌2동  148   73   75  121   72   49
# 449  강동구  암사1동  186   93   93  172  110   62
# 450  강동구  천호2동  175   88   87  175   99   76
# 451  강동구    길동  209  104  105  210  118   92
#
# [451 rows x 8 columns]

# %%
ma_1.drop(index=0, inplace=True)
# Out:
# C:\Users\2106-017\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ma_1
# Out:
#      자치구     동   출생 출생.1 출생.2   사망 사망.1 사망.2
# 2    종로구    소계  529  268  261  867  519  348
# 3    종로구   사직동   28   13   15   46   27   19
# 4    종로구   삼청동    9    5    4   24   14   10
# 5    종로구   부암동   21   12    9   45   24   21
# 6    종로구   평창동   71   31   40  104   47   57
# ..   ...   ...  ...  ...  ...  ...  ...  ...
# 447  강동구  둔촌1동    1    -    1    1    -    1
# 448  강동구  둔촌2동  148   73   75  121   72   49
# 449  강동구  암사1동  186   93   93  172  110   62
# 450  강동구  천호2동  175   88   87  175   99   76
# 451  강동구    길동  209  104  105  210  118   92
#
# [450 rows x 8 columns]

# %%
ma_2 = ma_1[ma_1['동']!='소계']

# %%
ma_2.set_index('자치구')
# Out:
#         동   출생 출생.1 출생.2   사망 사망.1 사망.2
# 자치구
# 종로구   사직동   28   13   15   46   27   19
# 종로구   삼청동    9    5    4   24   14   10
# 종로구   부암동   21   12    9   45   24   21
# 종로구   평창동   71   31   40  104   47   57
# 종로구   무악동   39   19   20   24   12   12
# ..    ...  ...  ...  ...  ...  ...  ...
# 강동구  둔촌1동    1    -    1    1    -    1
# 강동구  둔촌2동  148   73   75  121   72   49
# 강동구  암사1동  186   93   93  172  110   62
# 강동구  천호2동  175   88   87  175   99   76
# 강동구    길동  209  104  105  210  118   92
#
# [425 rows x 7 columns]

# %%
ma_2.sort_index()
# Out:
#      자치구     동   출생 출생.1 출생.2   사망 사망.1 사망.2
# 3    종로구   사직동   28   13   15   46   27   19
# 4    종로구   삼청동    9    5    4   24   14   10
# 5    종로구   부암동   21   12    9   45   24   21
# 6    종로구   평창동   71   31   40  104   47   57
# 7    종로구   무악동   39   19   20   24   12   12
# ..   ...   ...  ...  ...  ...  ...  ...  ...
# 447  강동구  둔촌1동    1    -    1    1    -    1
# 448  강동구  둔촌2동  148   73   75  121   72   49
# 449  강동구  암사1동  186   93   93  172  110   62
# 450  강동구  천호2동  175   88   87  175   99   76
# 451  강동구    길동  209  104  105  210  118   92
#
# [425 rows x 8 columns]

# %%
ma_2.drop('출생.1', inplace=True, axis=1)
ma_2.drop('출생.2', inplace=True, axis=1)
ma_2.drop('사망.1', inplace=True, axis=1)
ma_2.drop('사망.2', inplace=True, axis=1)
ma_2
# Out:
# C:\Users\2106-017\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      자치구     동   출생   사망
# 3    종로구   사직동   28   46
# 4    종로구   삼청동    9   24
# 5    종로구   부암동   21   45
# 6    종로구   평창동   71  104
# 7    종로구   무악동   39   24
# ..   ...   ...  ...  ...
# 447  강동구  둔촌1동    1    1
# 448  강동구  둔촌2동  148  121
# 449  강동구  암사1동  186  172
# 450  강동구  천호2동  175  175
# 451  강동구    길동  209  210
#
# [425 rows x 4 columns]

# %%
mo = pd.read_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\서울시_전입_전출.xls')
mo
# Out:
#        기간  자치구     동            구분          구분.1    구분.2    구분.3    구분.4  \
# 0      기간  자치구     동  총전입(⑦=①+③+⑤)  총전출(⑧=②+④+⑥)    구내이동    구내이동    구간이동
# 1      기간  자치구     동  총전입(⑦=①+③+⑤)  총전출(⑧=②+④+⑥)   전입(①)   전출(②)   전입(③)
# 2    2021   합계    합계       1418187       1524430  387416  387416  569648
# 3    2021  종로구    소계         22204         24428    3223    3223   11004
# 4    2021  종로구   사직동          1686          1669     262     272     910
# ..    ...  ...   ...           ...           ...     ...     ...     ...
# 449  2021  강동구  천호2동          5310          6557    1767    2631    1930
# 450  2021  강동구    길동          6781          7559    2459    2705    2093
# 451  2021  강동구   강일동          8494          3277    2737     850    4550
# 452  2021  강동구  상일1동          9151          3668    2990     846    3788
# 453  2021  강동구  상일2동          3182          1044    1126     276    1613
#
#        구분.5    구분.6    구분.7
# 0      구간이동  시ㆍ도간이동  시ㆍ도간이동
# 1     전출(④)   전입(⑤)   전출(⑥)
# ...

# %%
mo.columns
# Out:
# Index(['기간', '자치구', '동', '구분', '구분.1', '구분.2', '구분.3', '구분.4', '구분.5', '구분.6',
#        '구분.7'],
#       dtype='object')

# %%
mo.drop(index=0, inplace=True)
mo.drop(index=1, inplace=True)

# %%
mo.drop('기간', inplace=True, axis=1)
mo.drop('구분.2', inplace=True, axis=1)
mo.drop('구분.3', inplace=True, axis=1)
mo.drop('구분.4', inplace=True, axis=1)
mo.drop('구분.5', inplace=True, axis=1)
mo.drop('구분.6', inplace=True, axis=1)
mo.drop('구분.7', inplace=True, axis=1)

# %%
mo
# Out:
#      자치구     동       구분     구분.1
# 2     합계    합계  1418187  1524430
# 3    종로구    소계    22204    24428
# 4    종로구   사직동     1686     1669
# 5    종로구   삼청동      302      391
# 6    종로구   부암동     1075     1369
# ..   ...   ...      ...      ...
# 449  강동구  천호2동     5310     6557
# 450  강동구    길동     6781     7559
# 451  강동구   강일동     8494     3277
# 452  강동구  상일1동     9151     3668
# 453  강동구  상일2동     3182     1044
#
# [452 rows x 4 columns]

# %%
mo.drop(mo['자치구']=='합계', axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_129992/2057900679.py in <module>
# ----> 1 mo.drop(mo['자치구']=='합계', axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#mo.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\전입전출.xlsx')
ma_2.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\출생사망.xlsx')

# %%
mar = pd.read_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\서울시_혼인_이혼.xls')
mar
# Out:
#        기간  자치구     동     혼인     이혼
# 0    2021   합계    합계  37012  14967
# 1    2021  종로구    소계    478    204
# 2    2021  종로구   사직동     42     16
# 3    2021  종로구   삼청동     11      6
# 4    2021  종로구   부암동     35      7
# ..    ...  ...   ...    ...    ...
# 447  2021  강동구  천호2동    234     72
# 448  2021  강동구    길동    216     72
# 449  2021  강동구   강일동     84     59
# 450  2021  강동구  상일1동     87     27
# 451  2021  강동구  상일2동     11     10
#
# [452 rows x 5 columns]

# %%
mar.drop('기간', inplace=True, axis=1)

# %%
mar
# Out:
#      자치구     동     혼인     이혼
# 0     합계    합계  37012  14967
# 1    종로구    소계    478    204
# 2    종로구   사직동     42     16
# 3    종로구   삼청동     11      6
# 4    종로구   부암동     35      7
# ..   ...   ...    ...    ...
# 447  강동구  천호2동    234     72
# 448  강동구    길동    216     72
# 449  강동구   강일동     84     59
# 450  강동구  상일1동     87     27
# 451  강동구  상일2동     11     10
#
# [452 rows x 4 columns]

# %%
mar = mar[mar['동']!='소계']
mar
# Out:
#      자치구     동     혼인     이혼
# 0     합계    합계  37012  14967
# 2    종로구   사직동     42     16
# 3    종로구   삼청동     11      6
# 4    종로구   부암동     35      7
# 5    종로구   평창동     46     21
# ..   ...   ...    ...    ...
# 447  강동구  천호2동    234     72
# 448  강동구    길동    216     72
# 449  강동구   강일동     84     59
# 450  강동구  상일1동     87     27
# 451  강동구  상일2동     11     10
#
# [427 rows x 4 columns]

# %%
mar = mar[mar['자치구']!='합계']
mar
# Out:
#      자치구     동   혼인  이혼
# 2    종로구   사직동   42  16
# 3    종로구   삼청동   11   6
# 4    종로구   부암동   35   7
# 5    종로구   평창동   46  21
# 6    종로구   무악동   17   3
# ..   ...   ...  ...  ..
# 447  강동구  천호2동  234  72
# 448  강동구    길동  216  72
# 449  강동구   강일동   84  59
# 450  강동구  상일1동   87  27
# 451  강동구  상일2동   11  10
#
# [426 rows x 4 columns]

# %%
mar.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\혼인이혼.xlsx')

# %%
mo
# Out:
#      자치구     동       구분     구분.1
# 2     합계    합계  1418187  1524430
# 3    종로구    소계    22204    24428
# 4    종로구   사직동     1686     1669
# 5    종로구   삼청동      302      391
# 6    종로구   부암동     1075     1369
# ..   ...   ...      ...      ...
# 449  강동구  천호2동     5310     6557
# 450  강동구    길동     6781     7559
# 451  강동구   강일동     8494     3277
# 452  강동구  상일1동     9151     3668
# 453  강동구  상일2동     3182     1044
#
# [452 rows x 4 columns]

# %%
mo = mo[mo['자치구']!='합계']
mo = mo[mo['동'] != '소계']

# %%
mo
# Out:
#      자치구     동    구분  구분.1
# 4    종로구   사직동  1686  1669
# 5    종로구   삼청동   302   391
# 6    종로구   부암동  1075  1369
# 7    종로구   평창동  2239  2319
# 8    종로구   무악동   904  1049
# ..   ...   ...   ...   ...
# 449  강동구  천호2동  5310  6557
# 450  강동구    길동  6781  7559
# 451  강동구   강일동  8494  3277
# 452  강동구  상일1동  9151  3668
# 453  강동구  상일2동  3182  1044
#
# [426 rows x 4 columns]

# %%
mo.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\전입전출.xlsx')

# %%
mo
# Out:
#      자치구     동    전입    전출
# 395  강남구  개포1동   829   937
# 405  강남구  개포2동  9853  4191
# 396  강남구  개포4동  4408  3308
# 385  강남구  논현1동  5141  5967
# 386  강남구  논현2동  4171  4824
# ..   ...   ...   ...   ...
# 109  중랑구  상봉2동  4437  4029
# 115  중랑구  신내1동  3719  4709
# 116  중랑구  신내2동  2182  2903
# 110  중랑구  중화1동  2619  3157
# 111  중랑구  중화2동  3464  3919
#
# [426 rows x 4 columns]

# %%
ma_2
# Out:
#      자치구     동   출생   사망
# 394  강남구  개포1동   17   29
# 404  강남구  개포2동  152   57
# 395  강남구  개포4동   91   57
# 384  강남구  논현1동   93   81
# 385  강남구  논현2동  102   76
# ..   ...   ...  ...  ...
# 108  중랑구  상봉2동  126   96
# 114  중랑구  신내1동  183  249
# 115  중랑구  신내2동  132  139
# 109  중랑구  중화1동  131  118
# 110  중랑구  중화2동   91  176
#
# [425 rows x 4 columns]

# %%
mar
# Out:
#      자치구     동   혼인  이혼
# 393  강남구  개포1동   12  13
# 403  강남구  개포2동   61  28
# 394  강남구  개포4동   91  41
# 383  강남구  논현1동  112  45
# 384  강남구  논현2동   87  40
# ..   ...   ...  ...  ..
# 107  중랑구  상봉2동  160  44
# 113  중랑구  신내1동   95  49
# 114  중랑구  신내2동   74  39
# 108  중랑구  중화1동   98  34
# 109  중랑구  중화2동   95  49
#
# [426 rows x 4 columns]

# %%
m = ma_2.merge( mo ,how='outer')
m = m.merge(mar, how = 'outer')
m
# Out:
#      자치구     동   출생   사망    전입    전출     혼인    이혼
# 0    강남구  개포1동   17   29   829   937   12.0  13.0
# 1    강남구  개포2동  152   57  9853  4191   61.0  28.0
# 2    강남구  개포4동   91   57  4408  3308   91.0  41.0
# 3    강남구  논현1동   93   81  5141  5967  112.0  45.0
# 4    강남구  논현2동  102   76  4171  4824   87.0  40.0
# ..   ...   ...  ...  ...   ...   ...    ...   ...
# 422  중랑구  신내2동  132  139  2182  2903   74.0  39.0
# 423  중랑구  중화1동  131  118  2619  3157   98.0  34.0
# 424  중랑구  중화2동   91  176  3464  3919   95.0  49.0
# 425  강동구  상일1동  NaN  NaN  9151  3668   87.0  27.0
# 426  강동구  상일2동  NaN  NaN  3182  1044   11.0  10.0
#
# [427 rows x 8 columns]

# %%
m.isna().sum()
# Out:
# 자치구    0
# 동      0
# 출생     2
# 사망     2
# 전입     1
# 전출     1
# 혼인     1
# 이혼     1
# dtype: int64

# %%
# !pip install missingno

# %%
import missingno
import matplotlib
missingno.matrix(m)
plt.show()

# %%
m.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\all.xlsx')

# %%
mar = mar.sort_values(by=['자치구','동'])

# %%
ma_2 = ma_2.sort_values(by=['자치구','동'])

# %%
mo = mo.sort_values(by = ['자치구','동'])

# %%
# mo.columns = ['자치구', '동', '전입', '전출']

# %%
mar.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\혼인이혼.xlsx')
ma_2.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\출생사망.xlsx')
mo.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\전입전출.xlsx')

# %%
print(mar['동'])
print(mo['동'])
print(ma_2['동'])
# Out:
# 393    개포1동
# 403    개포2동
# 394    개포4동
# 383    논현1동
# 384    논현2동
#        ...
# 107    상봉2동
# 113    신내1동
# 114    신내2동
# 108    중화1동
# 109    중화2동
# Name: 동, Length: 426, dtype: object
# 395    개포1동
# 405    개포2동
# 396    개포4동
# 385    논현1동
# 386    논현2동
#        ...
# 109    상봉2동
# 115    신내1동
# 116    신내2동
# 110    중화1동
# 111    중화2동
# Name: 동, Length: 426, dtype: object
# 394    개포1동
# 404    개포2동
# 395    개포4동
# 384    논현1동
# 385    논현2동
#        ...
# 108    상봉2동
# 114    신내1동
# 115    신내2동
# 109    중화1동
# 110    중화2동
# Name: 동, Length: 425, dtype: object
