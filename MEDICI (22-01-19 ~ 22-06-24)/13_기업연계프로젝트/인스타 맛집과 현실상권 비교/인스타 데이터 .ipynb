# %%
import pandas as pd
import numpy as np
import re
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
data = pd.read_excel(r"instagram_hashtag_data_f.xlsx")
data
# Out:
#                                              id  type  \
# 0      https://www.instagram.com/p/BVwh5IYAXyJ/     1
# 1      https://www.instagram.com/p/BYgQOMJFY36/     0
# 2      https://www.instagram.com/p/BbvQarblI8-/     1
# 3      https://www.instagram.com/p/Bb8V2uEhFiF/     0
# 4      https://www.instagram.com/p/BZd39qTnDU0/     1
# ...                                         ...   ...
# 10361  https://www.instagram.com/p/BcMVdbUHMyg/     0
# 10362  https://www.instagram.com/p/Ba3Nj_QH90T/     0
# 10363  https://www.instagram.com/p/BbeCcYzF4kp/     1
# 10364  https://www.instagram.com/p/BbMStBTBHAi/     1
# 10365  https://www.instagram.com/p/BaTTU_hHNMn/     0
#
#                                                     word
# 0                                         경리단길카페, 맛스타그램,
# 1      가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                  이태원, 브런치, 데이트, 럽스타그램,
# 3        앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4                                        사유, 이태원, 이태원카페,
# ...                                                  ...
# 10361  성산일출봉\t, 해운대맛집\t, 환승\t, 신천\t, 시험기간, 11자복근\t, 스...
# 10362  jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363  먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364  오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365  Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
#
# [10366 rows x 3 columns]

# %%
# 이모티콘 없애기
data["word"] = data["word"].apply(lambda x : re.sub("\<.*\>|\s-\s.*",'', str(x)))

# %%
# 특수기호 없애기
data["word"] = data["word"].apply(lambda x : re.sub('[^\w\s]','', str(x)))

# %% [markdown]
# # 자연어 처리하기(Tokenizer)

# %%
from sklearn.model_selection import train_test_split
X = data["word"]
y = data["type"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 123,stratify=y)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
X_train_encoded = tokenizer.texts_to_sequences(X_train)
X_test_encoded = tokenizer.texts_to_sequences(X_test)

# %%
word_to_index = tokenizer.word_index
print(word_to_index)
# Out:
# {'이태원': 1, '이태원맛집': 2, '먹스타그램': 3, '우사단길': 4, '경리단길': 5, '이태원카페': 6, '일상': 7, '맛스타그램': 8, '한남동': 9, '한남동맛집': 10, '경리단길카페': 11, '데일리': 12, '해방촌맛집': 13, '해방촌': 14, '맛집': 15, 'itaewon': 16, '맞팔': 17, '먹방': 18, '한남동카페': 19, '경리단길맛집': 20, '카페': 21, '커피': 22, '디저트': 23, '경리단': 24, '카페스타그램': 25, '소통': 26, 'daily': 27, '좋아요': 28, 'cafe': 29, '커피스타그램': 30, '해방촌카페': 31, '럽스타그램': 32, '셀카': 33, '데이트': 34, '이태원역': 35, '셀피': 36, '오늘뭐먹지': 37, '이태원술집': 38
': 196, '꽃': 197, '토요일': 198, '해방촌술집': 199, '브런치타임': 200, '오겹살': 201, '이태원루프탑': 202, '타코맛집': 203, 'selca': 204, '보니스피자': 205, '후암동맛집': 206, '보광헌옷': 207, 'instagood': 208, '씨스루': 209, '연탄': 210, '아지트': 211, '모델': 212, '탭하우스계의배스킨라빈스': 213, '골라먹는재미': 214, '불토': 215, 'coffeetime': 216, 'bogwangdong': 217, '용산': 218, '그림': 219, 'usedthings': 220, 'thriftstore': 221, '자코비버거': 222, '이슬람사원': 223, '챔프라떼': 224, 'roasters': 225, '경리단길디저트': 226, '맛집탐방': 227, '파티': 228, '분위기깡패': 229, '챔프쿠키': 230, 'chimac': 231, '댓글': 232, '바베큐': 233, '위스키': 234, '서울카페': 235, '남산뷰': 236, 'openrp': 237, '라떼아트': 238, 'brunch': 239, '경리단길브런치': 240, '빈티지': 241, 'latte': 242, '해방촌오거리': 243, '타코플래터': 244, '인스타': 245, '인스타그램': 246, '36ontap': 247, '36가지탭': 248, '티라미수': 249, 'nike': 250, '디저트카페': 251, '이태원역맛집': 252, 'bar': 253, '동구다방': 254, '이태원꽃집': 255, '공방': 256, '챔프커피': 257, '타코': 258, '드로잉': 259, '루프탑카페': 260, '먹방스타그램': 261, '일요일': 262, '경리단길까페': 263, '가로수길': 264, '韓': 265, '예쁜카페': 266, '이로공작': 267, '주문제작': 268, '한강진맛집': 269, '플라워카페': 270, 'pizza': 271, '더백푸드트럭': 272, '홍대': 273, '블루밍부케': 274, 'f4f': 275, 'like4like': 276, '행복': 277, '아보카도버거': 278, '모우모우경리단점': 279, 'haebangchon': 280, '스테이크': 281, '우사단길카페': 282, '아틀리에봄': 283, '도자기': 284, '냠냠': 285, 'latteart': 286, '낮술': 287, 'handmade': 288, '맛집추천': 289, '오리올': 290, '포슬린': 291, 'ring': 292, '커플스타그램': 293, '혼술': 294, 'artwork': 295, '가로수길맛집': 296, 'bouquet': 297, '서울여행': 298, '망원동카페': 299, '슈퍼마켓': 300, '경리단길핫풀': 301, '디뮤 ...

# %%
s = sorted(tokenizer.word_counts.items(),reverse=True, key=lambda item:item[1])
s
# Out:
# [('이태원', 3175),
#  ('이태원맛집', 1976),
#  ('먹스타그램', 1479),
#  ('우사단길', 1402),
#  ('경리단길', 1346),
#  ('이태원카페', 1330),
#  ('일상', 1176),
#  ('맛스타그램', 1089),
#  ('한남동', 856),
#  ('한남동맛집', 854),
#  ('경리단길카페', 822),
#  ('데일리', 814),
#  ('해방촌맛집', 771),
#  ('해방촌', 715),
#  ('맛집', 687),
#  ('itaewon', 628),
#  ('맞팔', 595),
#  ('먹방', 587),
#  ('한남동카페', 586),
#  ('경리단길맛집', 581),
#  ('카페', 558),
#  ('커피', 485),
#  ('디저트', 468),
#  ('경리단', 457),
#  ('카페스타그램', 442),
#  ('소통', 435),
#  ('daily', 411),
#  ('좋아요', 408),
#  ('cafe', 403),
#  ('커피스타그램', 394),
#  ('해방촌카페', 375),
#  ('럽스타그램', 368),
#  ('셀카', 352),
#  ('데이트', 340),
#  ('이태원역', 334),
#  ('셀피', 311),
#  ('오늘뭐먹지', 305),
#  ('이태원술집', 304),
#  ('인테리어', 299),
#  ('사진', 298),
#  ('힐링', 291),
#  ('불금', 289),
#  ('가을', 287),
#  ('셀스타그램', 281),
#  ('온더테이블', 262),
#  ('coffee', 257),
#  ('금요일', 249),
#  ('퇴근길', 249),
#  ('푸딩', 247),
#  ('디저트스타그램', 245),
#  ('이태원데이트', 241),
#  ('우사단로', 241),
#  ('아이폰7', 236),
#  ('퇴근', 234),
#  ('이태원핫플', 229),
#  ('후식', 219),
#  ('seoul', 212),
#  ('이태원핫플레이스', 206),
#  ('얼스타그램', 205),
#  ('맛있다그램', 195),
#  ('핵존맛', 195),
#  ('보석길', 195),
#  ('브런치', 192),
#  ('이태원회식', 183),
#  ('서울', 181),
#  ('이태원막걸리', 178),
#  ('food', 176),
#  ('ootd', 175),
#  ('녹사평맛집', 175),
#  ('와인', 166),
#  ('주말', 165),
#  ('녹사평', 163),
#  ('보광동', 163),
#  ('instafood', 160),
#  ('꽃스타그램', 159),
#  ('루프탑', 159),
#  ('선팔', 155),
#  ('브런치카페', 154),
#  ('존맛', 146),
#  ('selfie', 144),
#  ('술스타그램', 144),
#  ('핵맛', 140),
#  ('에스프레소', 138),
#  ('빵스타그램', 136),
#  ('압구정맛집', 136),
#  ('홍대맛집', 135),
#  ('이태원펍', 133),
#  ('서울맛집', 133),
#  ('데일리룩', 132),
#  ('대존맛', 132),
#  ('먹스타', 126),
#  ('카페투어', 125),
#  ('korea', 125),
#  ('남산', 124),
#  ('디저트그램', 120),
#  ('친스타그램', 120),
#  ('얼짱', 120),
#  ('여행스타그램', 119),
#  ('라떼', 113),
#  ('맥주', 112),
#  ('꿀맛', 112),
#  ('핫플레이스', 109),
#  ('일상스타그램', 108),
#  ('케이크', 107),
#  ('브런치맛집', 105),
#  ('이태원피자', 102),
#  ('맛스타', 98),
#  ('녹사평카페', 98),
#  ('foodstagram', 98),
#  ('패션', 97),
#  ('dailylook', 97),
#  ('점심', 97),
#  ('이태원디저트', 97),
#  ('연남동맛집', 96),
#  ('내가사는세상', 95),
#  ('고기', 94),
#  ('셀스타스램', 93),
#  ('dessert', 90),
#  ('오오티디', 90),
#  ('팔로우', 90),
#  ('아메리카노', 89),
#  ('음식', 88),
#  ('이태원바', 87),
#  ('연남동', 86),
#  ('hbc', 86),
#  ('야식', 84),
#  ('whiterabbit', 84),
#  ('whiterabbittaphouse', 84),
#  ('화이트래빗', 84),
#  ('화이트래빗탭하우스', 84),
#  ('녹사평역2번출구', 84),
#  ('victory', 84),
#  ('beersatio0l', 84),
#  ('칵테일', 84),
#  ('용산맛집', 84),
#  ('간식', 82),
#  ('instadaily', 82),
#  ('케이크스타그램', 81),
#  ('남산타워', 81),
#  ('인친', 80),
#  ('오늘의메뉴', 79),
#  ('식스타그램', 79),
#  ('원데이클래스', 79),
#  ('repost', 79),
#  ('맛점', 79),
#  ('맛집인정', 78),
#  ('마카롱그램', 78),
#  ('내가먹는세상', 78),
#  ('피자', 78),
#  ('맛있는음식', 77),
#  ('서촌', 76),
#  ('밥스타그램', 76),
#  ('먹방여행', 76),
#  ('분위기', 76),
#  ('경리단길맥주', 76),
#  ('북촌', 75),
#  ('경리단맛집', 75),
#  ('데일리그램', 74),
#  ('foodie', 74),
#  ('핸드메이드', 74),
#  ('우사단', 73),
#  ('우사단고기', 72),
#  ('작업실', 72),
#  ('챔프커피1작업실', 72),
#  ('이태원나들이', 72),
#  ('수제버거', 71),
#  ('혼자', 71),
#  ('franciscolachowski', 71),
#  ('야경', 70),
#  ('경리단길술집', 70),
#  ('foodporn', 70),
#  ('계단장', 69),
#  ('champcoffee', 69),
#  ('경리단길데이트', 68),
#  ('자몽', 68),
#  ('이태원와인', 68),
#  ('팬케이크', 68),
#  ('fashion', 68),
#  ('플랫화이트', 67),
#  ('오렌지', 67),
#  ('openbrinks', 67),
#  ('오랑오랑', 67),
#  ('는스타그램', 66),
#  ('파스타', 65),
#  ('후암동', 65),
#  ('vintage', 65),
#  ('청포도에이드', 65),
#  ('남산맛집', 64),
#  ('선팔하면맞팔', 64),
#  ('음레코드', 64),
#  ('삼형제커피', 64),
#  ('그린빈생두', 64),
#  ('핸드핀작업', 64),
#  ('블랙엔소울', 64),
#  ('브라우니소울', 64),
#  ('셀카놀이', 64),
#  ('꽃', 64),
#  ('토요일', 63),
#  ('해방촌술집', 62),
#  ('브런치타임', 62),
#  ('오겹살', 61),
#  ('이태원루프탑', 61),
#  ('타코맛집', 61),
#  ('selca', 61),
#  ('보니스피자', 60),
#  ('후암동맛집', 60),
#  ('보광헌옷', 60),
#  ('instagood', 59),
#  ('씨스루', 58),
#  ('연탄', 58),
#  ('아지트', 58),
#  ('모델', 57),
#  ('탭하우스계의배스킨라빈스', 57),
#  ('골라먹는재미', 57),
#  ('불토', 57),
#  ('coffeetime', 56),
#  ('bogwangdong', 56),
#  ('용산', 56),
#  ('그림', 55),
#  ('usedthings', 55),
#  ('thriftstore', 55),
#  ('자코비버거', 55),
#  ('이슬람사원', 55),
#  ('챔프라떼', 55),
#  ('roasters', 55),
#  ('경리단길디저트', 55),
#  ('맛집탐방', 55),
#  ('파티', 55),
#  ('분위기깡패', 54),
#  ('챔프쿠키', 54),
#  ('chimac', 54),
#  ('댓글', 54),
#  ('바베큐', 54),
#  ('위스키', 54),
#  ('서울카페', 53),
#  ('남산뷰', 52),
#  ('openrp', 52),
#  ('라떼아트', 51),
#  ('brunch', 51),
#  ('경리단길브런치', 51),
#  ('빈티지', 51),
#  ('latte', 50),
#  ('해방촌오거리', 50),
#  ('타코플래터', 50),
#  ('인스타', 50),
#  ('인스타그램', 50),
#  ('36ontap', 49),
#  ('36가지탭', 49),
#  ('티라미수', 49),
#  ('nike', 49),
#  ('디저트카페', 49),
#  ('이태원역맛집', 49),
#  ('bar', 48),
#  ('동구다방', 48),
#  ('이태원꽃집', 48),
#  ('공방', 48),
#  ('챔프커피', 48),
#  ('타코', 48),
#  ('드로잉', 47),
#  ('루프탑카페', 47),
#  ('먹방스타그램', 47),
#  ('일요일', 47),
#  ('경리단길까페', 46),
#  ('가로수길', 46),
#  ('韓', 46),
#  ('예쁜카페', 46),
#  ('이로공작', 46),
#  ('주문제작', 46),
#  ('한강진맛집', 45),
#  ('플라워카페', 45),
#  ('pizza', 45),
#  ('더백푸드트럭', 45),
#  ('홍대', 44),
#  ('블루밍부케', 44),
#  ('f4f', 44),
#  ('like4like', 44),
#  ('행복', 44),
#  ('아보카도버거', 44),
#  ('모우모우경리단점', 44),
#  ('haebangchon', 44),
#  ('스테이크', 44),
#  ('우사단길카페', 43),
#  ('아틀리에봄', 43),
#  ('도자기', 43),
#  ('냠냠', 43),
#  ('latteart', 42),
#  ('낮술', 42),
#  ('handmade', 42),
#  ('맛집추천', 42),
#  ('오리올', 42),
#  ('포슬린', 42),
#  ('ring', 42),
#  ('커플스타그램', 42),
#  ('혼술', 42),
#  ('artwork', 41),
#  ('가로수길맛집', 41),
#  ('bouquet', 41),
#  ('서울여행', 41),
#  ('망원동카페', 41),
#  ('슈퍼마켓', 41),
#  ('경리단길핫풀', 41),
#  ('디뮤지엄', 41),
#  ('beer', 41),
#  ('interior', 41),
#  ('silver', 41),
#  ('피맥', 40),
#  ('크리마트', 40),
#  ('플라워레슨', 40),
#  ('wearethefamily', 40),
#  ('아뜰리에봄', 40),
#  ('art', 40),
#  ('cafestagram', 40),
#  ('모임', 40),
#  ('회식', 40),
#  ('한강진', 40),
#  ('팔로미', 40),
#  ('금속세공', 40),
#  ('주얼리공방', 40),
#  ('한강진카페', 40),
#  ('멍스타그램', 40),
#  ('카페씨스루', 39),
#  ('페리로스터즈', 39),
#  ('한강진역맛집', 39),
#  ('감성', 39),
#  ('instagram', 39),
#  ('맛집스타그램', 39),
#  ('한남동슈퍼마켓', 39),
#  ('tap', 39),
#  ('이태원맛집더앨리펍', 39),
#  ('술', 39),
#  ('맛있다', 38),
#  ('wine', 38),
#  ('그릇', 38),
#  ('han0mdong', 38),
#  ('오늘', 38),
#  ('lp', 38),
#  ('퀸즈라떼커피', 38),
#  ('챔프더치', 38),
#  ('강남맛집', 38),
#  ('수요미식회', 38),
#  ('카페아이아이', 37),
#  ('cthrough', 37),
#  ('barista', 37),
#  ('다운타우너', 37),
#  ('花', 37),
#  ('이태원공방', 37),
#  ('취미생활', 37),
#  ('로얄코펜하겐', 37),
#  ('취미', 37),
#  ('신흥시장', 37),
#  ('mmmrecords', 37),
#  ('테스티로드', 37),
#  ('upp', 36),
#  ('flower', 36),
#  ('감사합니다', 36),
#  ('아베크펫', 36),
#  ('커플링', 36),
#  ('프로포즈', 36),
#  ('줌스타그램', 35),
#  ('선물', 35),
#  ('yummy', 35),
#  ('내장파괴버거', 35),
#  ('장진우거리', 35),
#  ('해방촌데이트', 35),
#  ('여행', 35),
#  ('mywonder', 35),
#  ('꽁티드툴레아', 35),
#  ('love', 35),
#  ('녹사평역', 34),
#  ('rooftop', 34),
#  ('creamart', 34),
#  ('혼밥', 34),
#  ('샐러드', 34),
#  ('가로수길카페', 34),
#  ('생일', 34),
#  ('마카롱', 34),
#  ('쇼룸', 34),
#  ('wanikim', 34),
#  ('미수식당', 34),
#  ('디자인', 34),
#  ('회나무길', 33),
#  ('소월길', 33),
#  ('샌드위치', 33),
#  ('그릇스타그램', 33),
#  ('カフェ', 33),
#  ('직장인', 33),
#  ('겨울', 33),
#  ('burger', 33),
#  ('flowers', 33),
#  ('부산', 33),
#  ('빵', 33),
#  ('아이폰', 32),
#  ('나들이', 32),
#  ('테이블세팅', 32),
#  ('아오이소라', 32),
#  ('해크니', 32),
#  ('카페추천', 32),
#  ('해방촌길', 32),
#  ('데이트코스', 32),
#  ('metalwork', 32),
#  ('강남', 31),
#  ('탄탈라이즈', 31),
#  ('연남동카페', 31),
#  ('한남동브런치', 31),
#  ('컬러링북', 31),
#  ('푸드스타그램', 31),
#  ('cake', 31),
#  ('outfit', 31),
#  ('여유', 31),
#  ('레이블', 31),
#  ('수제버거맛집', 31),
#  ('보광동맛집', 31),
#  ('photo', 31),
#  ('design', 31),
#  ('저녁', 30),
#  ('웨딩부케', 30),
#  ('밀크티', 30),
#  ('치킨', 30),
#  ('셀기꾼', 30),
#  ('찻잔', 30),
#  ('명품그릇', 30),
#  ('오픈', 30),
#  ('바이닐', 30),
#  ('첫줄', 30),
#  ('이벤트', 30),
#  ('소통해요', 30),
#  ('배송가능', 30),
#  ('coreanosbrinks', 30),
#  ('옥수동맛집', 30),
#  ('그린그라피제이', 29),
#  ('seoulcafe', 29),
#  ('플리마켓', 29),
#  ('경리단길꽃집', 29),
#  ('이태원애견동반', 29),
#  ('용산구맛집', 29),
#  ('l4l', 28),
#  ('dailyart', 28),
#  ('우사단길꽃집', 28),
#  ('셀프웨딩', 28),
#  ('스몰웨딩', 28),
#  ('부케', 28),
#  ('커플', 28),
#  ('cafelatte', 28),
#  ('pasta', 28),
#  ('퀸', 28),
#  ('다이어트', 28),
#  ('햄버거', 28),
#  ('파란상점', 27),
#  ('이태원프리덤', 27),
#  ('카페라떼', 27),
#  ('쌀국수', 27),
#  ('한남', 27),
#  ('은공예', 27),
#  ('인테리어소품', 27),
#  ('피자맛집', 27),
#  ('ca0da', 27),
#  ('jordan', 27),
#  ('adidas', 27),
#  ('espresso', 27),
#  ('해방촌군침', 27),
#  ('수제맥주', 27),
#  ('악세사리', 27),
#  ('특이한케이스', 27),
#  ('삼각지맛집', 27),
#  ('정이예리룽지', 27),
#  ('장진우', 27),
#  ('instasize', 26),
#  ('하우스웨딩', 26),
#  ('동대문맛집', 26),
#  ('분짜라붐', 26),
#  ('분위기좋은카페', 26),
#  ('크리스마스', 26),
#  ('친구', 26),
#  ('7294court', 26),
#  ('7294ct', 26),
#  ('7294코트', 26),
#  ('asics', 26),
#  ('newbalance', 26),
#  ('puma', 26),
#  ('mitchellandness', 26),
#  ('diamondsupply', 26),
#  ('7294', 26),
#  ('사진스타그램', 26),
#  ('홍대카페', 26),
#  ('테라스', 26),
#  ('취향저격', 26),
#  ('이태원수제버거', 26),
#  ('치맥', 26),
#  ('인생템', 26),
#  ('커플케이스', 26),
#  ('줌마그램', 26),
#  ('할로윈', 25),
#  ('바리스타', 25),
#  ('weddingbouquet', 25),
#  ('아보카도', 25),
#  ('테라스카페', 25),
#  ('민화그리기', 25),
#  ('일상그램', 25),
#  ('followme', 25),
#  ('우사단길dm', 25),
#  ('한남동꽃집', 25),
#  ('해방촌수제버거', 25),
#  ('경리단카페', 25),
#  ('dailypic', 25),
#  ('맘스타그램', 25),
#  ('성수동카페', 25),
#  ('깊잠', 25),
#  ('gippjam', 25),
#  ('취저템', 25),
#  ('나이키', 25),
#  ('맞팔환영', 25),
#  ('존맛탱', 25),
#  ('26ontap', 24),
#  ('잠실맛집', 24),
#  ('아이스크림', 24),
#  ('한남오거리', 24),
#  ('이태원브런치', 24),
#  ('론드리프로젝트', 24),
#  ('weekend', 24),
#  ('음악감상', 24),
#  ('music', 24),
#  ('이태원파스타', 24),
#  ('산책', 24),
#  ('케냐캔디', 24),
#  ('koreanfood', 24),
#  ('심플케이스', 24),
#  ('심플라이프', 24),
#  ('미니멀라이프', 24),
#  ('플라워케이스', 24),
#  ('데일리케이스', 24),
#  ('드로잉케이스', 24),
#  ('커플폰', 24),
#  ('커플아이폰', 24),
#  ('클래식케이스', 24),
#  ('빈티지케이스', 24),
#  ('이태원만물상', 24),
#  ('성수동맛집', 24),
#  ('3dprinted', 24),
#  ('녹사평역맛집', 23),
#  ('바', 23),
#  ('blooming', 23),
#  ('개스타그램', 23),
#  ('떡볶이', 23),
#  ('감성사진', 23),
#  ('갤러리', 23),
#  ('경리단네일', 23),
#  ('와인스타그램', 23),
#  ('하트케이스', 23),
#  ('사유', 23),
#  ('캔들', 23),
#  ('아러바우트', 23),
#  ('펍', 23),
#  ('드도트', 22),
#  ('압구정', 22),
#  ('파스타맛집', 22),
#  ('패션5', 22),
#  ('아이스아메리카노', 22),
#  ('today', 22),
#  ('이자카야', 22),
#  ('주말데이트', 22),
#  ('followtrain', 22),
#  ('like4follow', 22),
#  ('우사단데이', 22),
#  ('경리단길에서', 22),
#  ('경리단네일샵', 22),
#  ('마릴린먼로', 22),
#  ('하쿠나마타타', 22),
#  ('원인어밀리언', 22),
#  ('보니스피자펍', 22),
#  ('가방참', 22),
#  ('梨泰院', 22),
#  ('いいねした人全員フォロ', 22),
#  ('dog', 22),
#  ('플로리스트', 22),
#  ('dedot', 21),
#  ('ferryroasters', 21),
#  ('와인바', 21),
#  ('피쉬앤칩스', 21),
#  ('치맥라이프', 21),
#  ('식물', 21),
#  ('전시', 21),
#  ('한남동술집', 21),
#  ('약수맛집', 21),
#  ('カフェ部', 21),
#  ('먹부림', 21),
#  ('이태원클럽', 21),
#  ('튜브라떼', 20),
#  ('follow4follow', 20),
#  ('드라이플라워', 20),
#  ('laundryproject', 20),
#  ('당근케이크', 20),
#  ('bnhr', 20),
#  ('출근', 20),
#  ('wedding', 20),
#  ('플라워클래스', 20),
#  ('북카페', 20),
#  ('대관', 20),
#  ('travel', 20),
#  ('혼술집', 20),
#  ('감자튀김', 20),
#  ('전망좋은곳', 20),
#  ('cute', 20),
#  ('tumblr', 20),
#  ('littleforest', 20),
#  ('리틀포레스트', 20),
#  ('스페셜티커피', 19),
#  ('팔로우미', 19),
#  ('jewelry', 19),
#  ('tantalize', 19),
#  ('예쁜꽃집', 19),
#  ('쿠촐로', 19),
#  ('베트남', 19),
#  ('aun', 19),
#  ('우사단10길', 19),
#  ('부산맛집', 19),
#  ('만화경', 19),
#  ('오아시스', 19),
#  ('해방촌바', 19),
#  ('수다', 19),
#  ('s0p', 19),
#  ('카페놀이', 19),
#  ('식신', 19),
#  ('봄', 19),
#  ('openrpg', 19),
#  ('스냅', 19),
#  ('연인', 19),
#  ('artist', 18),
#  ('주말스타그램', 18),
#  ('꽃다발', 18),
#  ('milktea', 18),
#  ('치즈', 18),
#  ('대구카페', 18),
#  ('flatwhite', 18),
#  ('장난감', 18),
#  ('음식스타그램', 18),
#  ('인스타푸드', 18),
#  ('아티팩스', 18),
#  ('선데이스위츠', 18),
#  ('은유다방', 18),
#  ('oriole', 18),
#  ('올어바웃미', 18),
#  ('술집', 18),
#  ('분짜', 18),
#  ('한강진역카페', 18),
#  ('마이원더', 18),
#  ('우니', 18),
#  ('사랑', 18),
#  ('follow', 18),
#  ('튀김', 18),
#  ('beautiful', 18),
#  ('greens', 18),
#  ('프랭크', 18),
#  ('카페인테리어', 18),
#  ('폼폼이키링', 18),
#  ('출근길', 18),
#  ('화요일', 18),
#  ('photography', 18),
#  ('술집추천', 18),
#  ('헬요일', 18),
#  ('수제초콜릿', 17),
#  ('해운대', 17),
#  ('소품샵', 17),
#  ('레스토랑', 17),
#  ('우사단로10길', 17),
#  ('한강진역', 17),
#  ('artifexcraft', 17),
#  ('artifex', 17),
#  ('왁스카빙', 17),
#  ('silvercraft', 17),
#  ('은세공', 17),
#  ('주얼리', 17),
#  ('수제양갱', 17),
#  ('케익', 17),
#  ('itaewoncafe', 17),
#  ('이태원맥주', 17),
#  ('블루스퀘어', 17),
#  ('일산카페', 17),
#  ('seouleats', 17),
#  ('선인장', 17),
#  ('용산구', 17),
#  ('후암동술집', 17),
#  ('고로킹', 17),
#  ('경리단길고로킹', 17),
#  ('빵같은고로케아닌리얼고로케', 17),
#  ('수제고로케집', 17),
#  ('죽기전에고로킹', 17),
#  ('멘치카츠', 17),
#  ('오리지날감자고록헤', 17),
#  ('지구최고고록헤', 17),
#  ('잡스타그램', 17),
#  ('막걸리', 17),
#  ('kyliejenner', 17),
#  ('likeback', 17),
#  ('이태원슈퍼마켓', 17),
#  ('소이연남', 17),
#  ('한남오거리맛집', 17),
#  ('173', 17),
#  ('회나무로', 17),
#  ('라이크선데이', 17),
#  ('반미리', 17),
#  ('regrann', 17),
#  ('펫스타그램', 17),
#  ('pub', 17),
#  ('painting', 17),
#  ('투데이', 17),
#  ('하늘', 17),
#  ('소규모모임', 17),
#  ('코스모스식당', 17),
#  ('자연주의', 17),
#  ('생일파티', 16),
#  ('metalcraft', 16),
#  ('먹방불금', 16),
#  ('추석', 16),
#  ('해방촌펍', 16),
#  ('음악', 16),
#  ('군침', 16),
#  ('타르트', 16),
#  ('숙대', 16),
#  ('은반지', 16),
#  ('foodpic', 16),
#  ('likeforlike', 16),
#  ('likeforfollow', 16),
#  ('내사세', 16),
#  ('부자피자', 16),
#  ('강남역맛집', 16),
#  ('강아지옷', 16),
#  ('스타일지음', 16),
#  ('망원동', 16),
#  ('dinner', 16),
#  ('남자식당', 16),
#  ('골든리트리버', 16),
#  ('puppy', 16),
#  ('베이킹', 16),
#  ('캠핑컴퍼니', 16),
#  ('makeup', 16),
#  ('manga', 16),
#  ('ulzzang', 16),
#  ('ulzzangmakeup', 16),
#  ('anime', 16),
#  ('kawaii', 16),
#  ('아이스라떼', 16),
#  ('라비앙코코', 15),
#  ('chocolate', 15),
#  ('페퍼로니피자', 15),
#  ('데이트맛집', 15),
#  ('이태원메이드', 15),
#  ('도넛', 15),
#  ('런치', 15),
#  ('신사동맛집', 15),
#  ('신촌맛집', 15),
#  ('금속공예', 15),
#  ('seoulfood', 15),
#  ('상수맛집', 15),
#  ('양갱', 15),
#  ('키링', 15),
#  ('책스타그램', 15),
#  ('cafeii', 15),
#  ('ソウルカフェ', 15),
#  ('양갈비', 15),
#  ('페인팅', 15),
#  ('에그베네딕트', 15),
#  ('baristalife', 15),
#  ('실버커스텀', 15),
#  ('173내가사는세상', 15),
#  ('fave', 15),
#  ('서울나들이', 15),
#  ('맛집투어', 15),
#  ('loner', 15),
#  ('로너', 15),
#  ('uglyfollowtrain', 15),
#  ('bondedaskoreia', 15),
#  ('우사단길맛집', 15),
#  ('커피타임', 15),
#  ('restaurant', 15),
#  ('canon', 15),
#  ('삼겹살', 15),
#  ('견스타그램', 15),
#  ('독스타그램', 15),
#  ('꾸까', 15),
#  ('kukka', 15),
#  ('전통주', 15),
#  ('カフェ巡り', 15),
#  ('hotplace', 15),
#  ('cocktail', 15),
#  ('iteawon', 15),
#  ('버거', 15),
#  ('goldenretriever', 15),
#  ('instadog', 15),
#  ('florist', 15),
#  ('han0m', 15),
#  ('harajuku', 15),
#  ('올프리마', 15),
#  ('티타임', 15),
#  ('sweets', 14),
#  ('스카치노', 14),
#  ('동성로맛집', 14),
#  ('이태원밥집', 14),
#  ('종로맛집', 14),
#  ('광화문맛집', 14),
#  ('여름', 14),
#  ('푸들', 14),
#  ('인스타데일리', 14),
#  ('숙대입구', 14),
#  ('극장판', 14),
#  ('33apartment', 14),
#  ('생맥주', 14),
#  ('북스타그램', 14),
#  ('오마일', 14),
#  ('홍대술집', 14),
#  ('다육이', 14),
#  ('한남맛집', 14),
#  ('마켓', 14),
#  ('baristadaily', 14),
#  ('압구정수제버거', 14),
#  ('173thepizza', 14),
#  ('블로그마켓', 14),
#  ('수요일', 14),
#  ('합정맛집', 14),
#  ('서울야경', 14),
#  ('스텔라', 14),
#  ('same', 14),
#  ('반포대교', 14),
#  ('까페', 14),
#  ('숙대맛집', 14),
#  ('고양이옷', 14),
#  ('정엽카페', 14),
#  ('한식', 14),
#  ('영화', 14),
#  ('양주', 14),
#  ('하와이안피자', 14),
#  ('그바람에주식회사', 14),
#  ('coreanobrinks', 14),
#  ('태슬', 14),
#  ('가방장식', 14),
#  ('경리단길루프탑', 14),
#  ('goldenpuppy', 14),
#  ('합정카페', 14),
#  ('키덜트', 14),
#  ('조이의공간', 14),
#  ('강아지', 14),
#  ('브이', 14),
#  ('onthetable', 14),
#  ('플랫아이언', 14),
#  ('dailyphoto', 14),
#  ('inspiration', 14),
#  ('자연성애자', 14),
#  ('ソウル', 14),
#  ('창화당', 13),
#  ('0msan', 13),
#  ('반지', 13),
#  ('뒤에나비', 13),
#  ('스콘', 13),
#  ('가드닝', 13),
#  ('명동맛집', 13),
#  ('이대맛집', 13),
#  ('옷스타그램', 13),
#  ('바코', 13),
#  ('카페그램', 13),
#  ('icecream', 13),
#  ('부산카페', 13),
#  ('연말', 13),
#  ('플랜테리어', 13),
#  ('독립서점', 13),
#  ('루프탑바', 13),
#  ('잠실카페', 13),
#  ('디스플레이', 13),
#  ('instalike', 13),
#  ('애스타그램', 13),
#  ('핫플', 13),
#  ('수요미식회맛집', 13),
#  ('언더프레셔', 13),
#  ('소품', 13),
#  ('짱맛', 13),
#  ('셀스타', 13),
#  ('신상카페', 13),
#  ('아렌델', 13),
#  ('arendelle', 13),
#  ('프렌치토스트', 13),
#  ('chimaclife', 13),
#  ('이색데이트', 13),
#  ('데이트그램', 13),
#  ('제주도맛집', 13),
#  ('로우커피', 13),
#  ('hongdae', 13),
#  ('aria0grande', 13),
#  ('dotz', 13),
#  ('키즈클래스', 13),
#  ('부부스타그램', 13),
#  ('재즈', 13),
#  ('카페사루', 13),
#  ('베이커리', 13),
#  ('tiramisu', 13),
#  ('세렝게티', 13),
#  ('108계단', 13),
#  ('우산단로', 13),
#  ('해방촌루프탑', 13),
#  ('패션스타그램', 13),
#  ('친구랑', 13),
#  ('차돌박이', 13),
#  ('편집샵', 13),
#  ('lunch', 13),
#  ('망원동맛집', 13),
#  ('모사부카', 13),
#  ('딸기', 13),
#  ('디뮤지엄맛집', 13),
#  ('3d프린트', 13),
#  ('맞팔해요', 13),
#  ('강남카페', 13),
#  ('혼자가는술집', 13),
#  ('헬카페', 13),
#  ('옷스타그램i', 13),
#  ('livingdoll', 13),
#  ('japanesefashion', 13),
#  ('대구맛집', 13),
#  ('downtowner', 13),
#  ('장진우식당', 13),
#  ('아벡누', 13),
#  ('초콜릿', 12),
#  ('도넛라떼', 12),
#  ('집밥', 12),
#  ('good', 12),
#  ('instapic', 12),
#  ('bonnyspizza', 12),
#  ('좋아요반사', 12),
#  ('rockeat', 12),
#  ('카페대관', 12),
#  ('hackney', 12),
#  ('발렌타인데이', 12),
#  ('스타벅스', 12),
#  ('망고서림', 12),
#  ('소월길카페', 12),
#  ('brandy', 12),
#  ('plants', 12),
#  ('해방촌맥주', 12),
#  ('달다구리', 12),
#  ('foodpics', 12),
#  ('반미', 12),
#  ('치킨맛집', 12),
#  ('스냅사진', 12),
#  ('주말나들이', 12),
#  ('cafeoye', 12),
#  ('이태원해방촌', 12),
#  ('그랜드뮤즈', 12),
#  ('경리단수제버거', 12),
#  ('제주식당', 12),
#  ('이태원맛집추천', 12),
#  ('jazz', 12),
#  ('이탈리안레스토랑', 12),
#  ('더베이커스테이블', 12),
#  ('orangorang', 12),
#  ('심야식당', 12),
#  ('커피숍', 12),
#  ('행복해', 12),
#  ('vinyl', 12),
#  ('한남동바', 12),
#  ('제일기획', 12),
#  ('쿠키', 12),
#  ('사루', 12),
#  ('onei0million', 12),
#  ('멋스타그램', 12),
#  ('영화관', 12),
#  ('독립영화', 12),
#  ('제주여행', 12),
#  ('selstagram', 12),
#  ('더시리얼', 12),
#  ('미주리', 12),
#  ('contedetulear', 12),
#  ('공간', 12),
#  ('bracelet', 12),
#  ('모어댄위스키', 12),
#  ('증류펍', 12),
#  ('소라사장', 12),
#  ('ㅅㅅ음식작업소', 12),
#  ('샤워룸', 12),
#  ('키에리', 12),
#  ('애교', 12),
#  ('스타일', 12),
#  ('마렘마', 12),
#  ('아인슈페너', 12),
#  ('party', 12),
#  ('샴페인', 12),
#  ('해방촌노아', 12),
#  ('harajukufasion', 12),
#  ('방탄소년단', 12),
#  ('인천맛집', 12),
#  ('그랑블루', 12),
#  ('와인파티', 12),
#  ('샌드위치가게', 12),
#  ('sunday', 12),
#  ('앤드하리한남', 12),
#  ('pink', 11),
#  ('chocolat', 11),
#  ('오라라', 11),
#  ('맛있어', 11),
#  ('녹사평술집', 11),
#  ('대전', 11),
#  ('서면', 11),
#  ('마크컬렉션', 11),
#  ('반려견', 11),
#  ('무화과', 11),
#  ...]

# %%
for i in range(len(s)):
    print(s[i][0],round(s[i][1]/len(data),4))
# Out:
# 이태원 0.3063
# 이태원맛집 0.1906
# 먹스타그램 0.1427
# 우사단길 0.1352
# 경리단길 0.1298
# 이태원카페 0.1283
# 일상 0.1134
# 맛스타그램 0.1051
# 한남동 0.0826
# 한남동맛집 0.0824
# 경리단길카페 0.0793
# 데일리 0.0785
# 해방촌맛집 0.0744
# 해방촌 0.069
# 맛집 0.0663
# itaewon 0.0606
# 맞팔 0.0574
# 먹방 0.0566
# 한남동카페 0.0565
# 경리단길맛집 0.056
# 카페 0.0538
# 커피 0.0468
# 디저트 0.0451
# 경리단 0.0441
# 카페스타그램 0.0426
# 소통 0.042
# daily 0.0396
# 좋아요 0.0394
# cafe 0.0389
# 커피스타그램 0.038
# 해방촌카페 0.0362
# 럽스타그램 0.0355
# 셀카 0.034
# 데이트 0.0328
# 이태원역 0.0322
# 셀피 0.03
# 오늘뭐먹지 0.0294
# 이태원술집 0.0293
# 인테리어 0.0288
# 사진 0.0287
# 힐링 0.0281
# 불금 0.0279
# 가을 0.0277
# 셀스타그램 0.0271
# 온더테이블 0.0253
# coffee 0.0248
# 금요일 0.024
# 퇴근길 0.024
# 푸딩 0.0238
# 디저트스타그램 0.0236
# 이태원데이트 0.0232
# 우사단로 0.0232
# 아이폰7 0.0228
# 퇴근 0.0226
# 이태원핫플 0.0221
# 후식 0.0211
# seoul 0.0205
# 이태원핫플레이스 0.0199
# 얼스타그램 0.0198
# 맛있다그램 0.0188
# 핵존맛 0.0188
# 보석길 0.0188
# 브런치 0.0185
# 이태원회식 0.0177
# 서울 0.0175
# 이태원막걸리 0.0172
# food 0.017
# ootd 0.0169
# 녹사평맛집 0.0169
# 와인 0.016
# 주말 0.0159
# 녹사평 0.0157
# 보광동 0.0157
# instafood 0.0154
# 꽃스타그램 0.0153
# 루프탑 0.0153
# 선팔 0.015
# 브런치카페 0.0149
# 존맛 0.0141
# selfie 0.0139
# 술스타그램 0.0139
# 핵맛 0.0135
# 에스프레소 0.0133
# 빵스타그램 0.0131
# 압구정맛집 0.0131
# 홍대맛집 0.013
# 이태원펍 0.0128
# 서울맛집 0.0128
# 데일리룩 0.0127
# 대존맛 0.0127
# 먹스타 0.0122
# 카페투어 0.0121
# korea 0.0121
# 남산 0.012
# 디저트그램 0.0116
# 친스타그램 0.0116
# 얼짱 0.0116
# 여행스타그램 0.0115
# 라떼 0.0109
# 맥주 0.0108
# 꿀맛 0.0108
# 핫플레이스 0.0105
# 일상스타그램 0.0104
# 케이크 0.0103
# 브런치맛집 0.0101
# 이태원피자 0.0098
# 맛스타 0.0095
# 녹사평카페 0.0095
# foodstagram 0.0095
# 패션 0.0094
# dailylook 0.0094
# 점심 0.0094
# 이태원디저트 0.0094
# 연남동맛집 0.0093
# 내가사는세상 0.0092
# 고기 0.0091
# 셀스타스램 0.009
# dessert 0.0087
# 오오티디 0.0087
# 팔로우 0.0087
# 아메리카노 0.0086
# 음식 0.0085
# 이태원바 0.0084
# 연남동 0.0083
# hbc 0.0083
# 야식 0.0081
# whiterabbit 0.0081
# whiterabbittaphouse 0.0081
# 화이트래빗 0.0081
# 화이트래빗탭하우스 0.0081
# 녹사평역2번출구 0.0081
# victory 0.0081
# beersatio0l 0.0081
# 칵테일 0.0081
# 용산맛집 0.0081
# 간식 0.0079
# instadaily 0.0079
# 케이크스타그램 0.0078
# 남산타워 0.0078
# 인친 0.0077
# 오늘의메뉴 0.0076
# 식스타그램 0.0076
# 원데이클래스 0.0076
# repost 0.0076
# 맛점 0.0076
# 맛집인정 0.0075
# 마카롱그램 0.0075
# 내가먹는세상 0.0075
# 피자 0.0075
# 맛있는음식 0.0074
# 서촌 0.0073
# 밥스타그램 0.0073
# 먹방여행 0.0073
# 분위기 0.0073
# 경리단길맥주 0.0073
# 북촌 0.0072
# 경리단맛집 0.0072
# 데일리그램 0.0071
# foodie 0.0071
# 핸드메이드 0.0071
# 우사단 0.007
# 우사단고기 0.0069
# 작업실 0.0069
# 챔프커피1작업실 0.0069
# 이태원나들이 0.0069
# 수제버거 0.0068
# 혼자 0.0068
# franciscolachowski 0.0068
# 야경 0.0068
# 경리단길술집 0.0068
# foodporn 0.0068
# 계단장 0.0067
# champcoffee 0.0067
# 경리단길데이트 0.0066
# 자몽 0.0066
# 이태원와인 0.0066
# 팬케이크 0.0066
# fashion 0.0066
# 플랫화이트 0.0065
# 오렌지 0.0065
# openbrinks 0.0065
# 오랑오랑 0.0065
# 는스타그램 0.0064
# 파스타 0.0063
# 후암동 0.0063
# vintage 0.0063
# 청포도에이드 0.0063
# 남산맛집 0.0062
# 선팔하면맞팔 0.0062
# 음레코드 0.0062
# 삼형제커피 0.0062
# 그린빈생두 0.0062
# 핸드핀작업 0.0062
# 블랙엔소울 0.0062
# 브라우니소울 0.0062
# 셀카놀이 0.0062
# 꽃 0.0062
# 토요일 0.0061
# 해방촌술집 0.006
# 브런치타임 0.006
# 오겹살 0.0059
# 이태원루프탑 0.0059
# 타코맛집 0.0059
# selca 0.0059
# 보니스피자 0.0058
# 후암동맛집 0.0058
# 보광헌옷 0.0058
# instagood 0.0057
# 씨스루 0.0056
# 연탄 0.0056
# 아지트 0.0056
# 모델 0.0055
# 탭하우스계의배스킨라빈스 0.0055
# 골라먹는재미 0.0055
# 불토 0.0055
# coffeetime 0.0054
# bogwangdong 0.0054
# 용산 0.0054
# 그림 0.0053
# usedthings 0.0053
# thriftstore 0.0053
# 자코비버거 0.0053
# 이슬람사원 0.0053
# 챔프라떼 0.0053
# roasters 0.0053
# 경리단길디저트 0.0053
# 맛집탐방 0.0053
# 파티 0.0053
# 분위기깡패 0.0052
# 챔프쿠키 0.0052
# chimac 0.0052
# 댓글 0.0052
# 바베큐 0.0052
# 위스키 0.0052
# 서울카페 0.0051
# 남산뷰 0.005
# openrp 0.005
# 라떼아트 0.0049
# brunch 0.0049
# 경리단길브런치 0.0049
# 빈티지 0.0049
# latte 0.0048
# 해방촌오거리 0.0048
# 타코플래터 0.0048
# 인스타 0.0048
# 인스타그램 0.0048
# 36ontap 0.0047
# 36가지탭 0.0047
# 티라미수 0.0047
# nike 0.0047
# 디저트카페 0.0047
# 이태원역맛집 0.0047
# bar 0.0046
# 동구다방 0.0046
# 이태원꽃집 0.0046
# 공방 0.0046
# 챔프커피 0.0046
# 타코 0.0046
# 드로잉 0.0045
# 루프탑카페 0.0045
# 먹방스타그램 0.0045
# 일요일 0.0045
# 경리단길까페 0.0044
# 가로수길 0.0044
# 韓 0.0044
# 예쁜카페 0.0044
# 이로공작 0.0044
# 주문제작 0.0044
# 한강진맛집 0.0043
# 플라워카페 0.0043
# pizza 0.0043
# 더백푸드트럭 0.0043
# 홍대 0.0042
# 블루밍부케 0.0042
# f4f 0.0042
# like4like 0.0042
# 행복 0.0042
# 아보카도버거 0.0042
# 모우모우경리단점 0.0042
# haebangchon 0.0042
# 스테이크 0.0042
# 우사단길카페 0.0041
# 아틀리에봄 0.0041
# 도자기 0.0041
# 냠냠 0.0041
# latteart 0.0041
# 낮술 0.0041
# handmade 0.0041
# 맛집추천 0.0041
# 오리올 0.0041
# 포슬린 0.0041
# ring 0.0041
# 커플스타그램 0.0041
# 혼술 0.0041
# artwork 0.004
# 가로수길맛집 0.004
# bouquet 0.004
# 서울여행 0.004
# 망원동카페 0.004
# 슈퍼마켓 0.004
# 경리단길핫풀 0.004
# 디뮤지엄 0.004
# beer 0.004
# interior 0.004
# silver 0.004
# 피맥 0.0039
# 크리마트 0.0039
# 플라워레슨 0.0039
# wearethefamily 0.0039
# 아뜰리에봄 0.0039
# art 0.0039
# cafestagram 0.0039
# 모임 0.0039
# 회식 0.0039
# 한강진 0.0039
# 팔로미 0.0039
# 금속세공 0.0039
# 주얼리공방 0.0039
# 한강진카페 0.0039
# 멍스타그램 0.0039
# 카페씨스루 0.0038
# 페리로스터즈 0.0038
# 한강진역맛집 0.0038
# 감성 0.0038
# instagram 0.0038
# 맛집스타그램 0.0038
# 한남동슈퍼마켓 0.0038
# tap 0.0038
# 이태원맛집더앨리펍 0.0038
# 술 0.0038
# 맛있다 0.0037
# wine 0.0037
# 그릇 0.0037
# han0mdong 0.0037
# 오늘 0.0037
# lp 0.0037
# 퀸즈라떼커피 0.0037
# 챔프더치 0.0037
# 강남맛집 0.0037
# 수요미식회 0.0037
# 카페아이아이 0.0036
# cthrough 0.0036
# barista 0.0036
# 다운타우너 0.0036
# 花 0.0036
# 이태원공방 0.0036
# 취미생활 0.0036
# 로얄코펜하겐 0.0036
# 취미 0.0036
# 신흥시장 0.0036
# mmmrecords 0.0036
# 테스티로드 0.0036
# upp 0.0035
# flower 0.0035
# 감사합니다 0.0035
# 아베크펫 0.0035
# 커플링 0.0035
# 프로포즈 0.0035
# 줌스타그램 0.0034
# 선물 0.0034
# yummy 0.0034
# 내장파괴버거 0.0034
# 장진우거리 0.0034
# 해방촌데이트 0.0034
# 여행 0.0034
# mywonder 0.0034
# 꽁티드툴레아 0.0034
# love 0.0034
# 녹사평역 0.0033
# rooftop 0.0033
# creamart 0.0033
# 혼밥 0.0033
# 샐러드 0.0033
# 가로수길카페 0.0033
# 생일 0.0033
# 마카롱 0.0033
# 쇼룸 0.0033
# wanikim 0.0033
# 미수식당 0.0033
# 디자인 0.0033
# 회나무길 0.0032
# 소월길 0.0032
# 샌드위치 0.0032
# 그릇스타그램 0.0032
# カフェ 0.0032
# 직장인 0.0032
# 겨울 0.0032
# burger 0.0032
# flowers 0.0032
# 부산 0.0032
# 빵 0.0032
# 아이폰 0.0031
# 나들이 0.0031
# 테이블세팅 0.0031
# 아오이소라 0.0031
# 해크니 0.0031
# 카페추천 0.0031
# 해방촌길 0.0031
# 데이트코스 0.0031
# metalwork 0.0031
# 강남 0.003
# 탄탈라이즈 0.003
# 연남동카페 0.003
# 한남동브런치 0.003
# 컬러링북 0.003
# 푸드스타그램 0.003
# cake 0.003
# outfit 0.003
# 여유 0.003
# 레이블 0.003
# 수제버거맛집 0.003
# 보광동맛집 0.003
# photo 0.003
# design 0.003
# 저녁 0.0029
# 웨딩부케 0.0029
# 밀크티 0.0029
# 치킨 0.0029
# 셀기꾼 0.0029
# 찻잔 0.0029
# 명품그릇 0.0029
# 오픈 0.0029
# 바이닐 0.0029
# 첫줄 0.0029
# 이벤트 0.0029
# 소통해요 0.0029
# 배송가능 0.0029
# coreanosbrinks 0.0029
# 옥수동맛집 0.0029
# 그린그라피제이 0.0028
# seoulcafe 0.0028
# 플리마켓 0.0028
# 경리단길꽃집 0.0028
# 이태원애견동반 0.0028
# 용산구맛집 0.0028
# l4l 0.0027
# dailyart 0.0027
# 우사단길꽃집 0.0027
# 셀프웨딩 0.0027
# 스몰웨딩 0.0027
# 부케 0.0027
# 커플 0.0027
# cafelatte 0.0027
# pasta 0.0027
# 퀸 0.0027
# 다이어트 0.0027
# 햄버거 0.0027
# 파란상점 0.0026
# 이태원프리덤 0.0026
# 카페라떼 0.0026
# 쌀국수 0.0026
# 한남 0.0026
# 은공예 0.0026
# 인테리어소품 0.0026
# 피자맛집 0.0026
# ca0da 0.0026
# jordan 0.0026
# adidas 0.0026
# espresso 0.0026
# 해방촌군침 0.0026
# 수제맥주 0.0026
# 악세사리 0.0026
# 특이한케이스 0.0026
# 삼각지맛집 0.0026
# 정이예리룽지 0.0026
# 장진우 0.0026
# instasize 0.0025
# 하우스웨딩 0.0025
# 동대문맛집 0.0025
# 분짜라붐 0.0025
# 분위기좋은카페 0.0025
# 크리스마스 0.0025
# 친구 0.0025
# 7294court 0.0025
# 7294ct 0.0025
# 7294코트 0.0025
# asics 0.0025
# newbalance 0.0025
# puma 0.0025
# mitchellandness 0.0025
# diamondsupply 0.0025
# 7294 0.0025
# 사진스타그램 0.0025
# 홍대카페 0.0025
# 테라스 0.0025
# 취향저격 0.0025
# 이태원수제버거 0.0025
# 치맥 0.0025
# 인생템 0.0025
# 커플케이스 0.0025
# 줌마그램 0.0025
# 할로윈 0.0024
# 바리스타 0.0024
# weddingbouquet 0.0024
# 아보카도 0.0024
# 테라스카페 0.0024
# 민화그리기 0.0024
# 일상그램 0.0024
# followme 0.0024
# 우사단길dm 0.0024
# 한남동꽃집 0.0024
# 해방촌수제버거 0.0024
# 경리단카페 0.0024
# dailypic 0.0024
# 맘스타그램 0.0024
# 성수동카페 0.0024
# 깊잠 0.0024
# gippjam 0.0024
# 취저템 0.0024
# 나이키 0.0024
# 맞팔환영 0.0024
# 존맛탱 0.0024
# 26ontap 0.0023
# 잠실맛집 0.0023
# 아이스크림 0.0023
# 한남오거리 0.0023
# 이태원브런치 0.0023
# 론드리프로젝트 0.0023
# weekend 0.0023
# 음악감상 0.0023
# music 0.0023
# 이태원파스타 0.0023
# 산책 0.0023
# 케냐캔디 0.0023
# koreanfood 0.0023
# 심플케이스 0.0023
# 심플라이프 0.0023
# 미니멀라이프 0.0023
# 플라워케이스 0.0023
# 데일리케이스 0.0023
# 드로잉케이스 0.0023
# 커플폰 0.0023
# 커플아이폰 0.0023
# 클래식케이스 0.0023
# 빈티지케이스 0.0023
# 이태원만물상 0.0023
# 성수동맛집 0.0023
# 3dprinted 0.0023
# 녹사평역맛집 0.0022
# 바 0.0022
# blooming 0.0022
# 개스타그램 0.0022
# 떡볶이 0.0022
# 감성사진 0.0022
# 갤러리 0.0022
# 경리단네일 0.0022
# 와인스타그램 0.0022
# 하트케이스 0.0022
# 사유 0.0022
# 캔들 0.0022
# 아러바우트 0.0022
# 펍 0.0022
# 드도트 0.0021
# 압구정 0.0021
# 파스타맛집 0.0021
# 패션5 0.0021
# 아이스아메리카노 0.0021
# today 0.0021
# 이자카야 0.0021
# 주말데이트 0.0021
# followtrain 0.0021
# like4follow 0.0021
# 우사단데이 0.0021
# 경리단길에서 0.0021
# 경리단네일샵 0.0021
# 마릴린먼로 0.0021
# 하쿠나마타타 0.0021
# 원인어밀리언 0.0021
# 보니스피자펍 0.0021
# 가방참 0.0021
# 梨泰院 0.0021
# いいねした人全員フォロ 0.0021
# dog 0.0021
# 플로리스트 0.0021
# dedot 0.002
# ferryroasters 0.002
# 와인바 0.002
# 피쉬앤칩스 0.002
# 치맥라이프 0.002
# 식물 0.002
# 전시 0.002
# 한남동술집 0.002
# 약수맛집 0.002
# カフェ部 0.002
# 먹부림 0.002
# 이태원클럽 0.002
# 튜브라떼 0.0019
# follow4follow 0.0019
# 드라이플라워 0.0019
# laundryproject 0.0019
# 당근케이크 0.0019
# bnhr 0.0019
# 출근 0.0019
# wedding 0.0019
# 플라워클래스 0.0019
# 북카페 0.0019
# 대관 0.0019
# travel 0.0019
# 혼술집 0.0019
# 감자튀김 0.0019
# 전망좋은곳 0.0019
# cute 0.0019
# tumblr 0.0019
# littleforest 0.0019
# 리틀포레스트 0.0019
# 스페셜티커피 0.0018
# 팔로우미 0.0018
# jewelry 0.0018
# tantalize 0.0018
# 예쁜꽃집 0.0018
# 쿠촐로 0.0018
# 베트남 0.0018
# aun 0.0018
# 우사단10길 0.0018
# 부산맛집 0.0018
# 만화경 0.0018
# 오아시스 0.0018
# 해방촌바 0.0018
# 수다 0.0018
# s0p 0.0018
# 카페놀이 0.0018
# 식신 0.0018
# 봄 0.0018
# openrpg 0.0018
# 스냅 0.0018
# 연인 0.0018
# artist 0.0017
# 주말스타그램 0.0017
# 꽃다발 0.0017
# milktea 0.0017
# 치즈 0.0017
# 대구카페 0.0017
# flatwhite 0.0017
# 장난감 0.0017
# 음식스타그램 0.0017
# 인스타푸드 0.0017
# 아티팩스 0.0017
# 선데이스위츠 0.0017
# 은유다방 0.0017
# oriole 0.0017
# 올어바웃미 0.0017
# 술집 0.0017
# 분짜 0.0017
# 한강진역카페 0.0017
# 마이원더 0.0017
# 우니 0.0017
# 사랑 0.0017
# follow 0.0017
# 튀김 0.0017
# beautiful 0.0017
# greens 0.0017
# 프랭크 0.0017
# 카페인테리어 0.0017
# 폼폼이키링 0.0017
# 출근길 0.0017
# 화요일 0.0017
# photography 0.0017
# 술집추천 0.0017
# 헬요일 0.0017
# 수제초콜릿 0.0016
# 해운대 0.0016
# 소품샵 0.0016
# 레스토랑 0.0016
# 우사단로10길 0.0016
# 한강진역 0.0016
# artifexcraft 0.0016
# artifex 0.0016
# 왁스카빙 0.0016
# silvercraft 0.0016
# 은세공 0.0016
# 주얼리 0.0016
# 수제양갱 0.0016
# 케익 0.0016
# itaewoncafe 0.0016
# 이태원맥주 0.0016
# 블루스퀘어 0.0016
# 일산카페 0.0016
# seouleats 0.0016
# 선인장 0.0016
# 용산구 0.0016
# 후암동술집 0.0016
# 고로킹 0.0016
# 경리단길고로킹 0.0016
# 빵같은고로케아닌리얼고로케 0.0016
# 수제고로케집 0.0016
# 죽기전에고로킹 0.0016
# 멘치카츠 0.0016
# 오리지날감자고록헤 0.0016
# 지구최고고록헤 0.0016
# 잡스타그램 0.0016
# 막걸리 0.0016
# kyliejenner 0.0016
# likeback 0.0016
# 이태원슈퍼마켓 0.0016
# 소이연남 0.0016
# 한남오거리맛집 0.0016
# 173 0.0016
# 회나무로 0.0016
# 라이크선데이 0.0016
# 반미리 0.0016
# regrann 0.0016
# 펫스타그램 0.0016
# pub 0.0016
# painting 0.0016
# 투데이 0.0016
# 하늘 0.0016
# 소규모모임 0.0016
# 코스모스식당 0.0016
# 자연주의 0.0016
# 생일파티 0.0015
# metalcraft 0.0015
# 먹방불금 0.0015
# 추석 0.0015
# 해방촌펍 0.0015
# 음악 0.0015
# 군침 0.0015
# 타르트 0.0015
# 숙대 0.0015
# 은반지 0.0015
# foodpic 0.0015
# likeforlike 0.0015
# likeforfollow 0.0015
# 내사세 0.0015
# 부자피자 0.0015
# 강남역맛집 0.0015
# 강아지옷 0.0015
# 스타일지음 0.0015
# 망원동 0.0015
# dinner 0.0015
# 남자식당 0.0015
# 골든리트리버 0.0015
# puppy 0.0015
# 베이킹 0.0015
# 캠핑컴퍼니 0.0015
# makeup 0.0015
# manga 0.0015
# ulzzang 0.0015
# ulzzangmakeup 0.0015
# anime 0.0015
# kawaii 0.0015
# 아이스라떼 0.0015
# 라비앙코코 0.0014
# chocolate 0.0014
# 페퍼로니피자 0.0014
# 데이트맛집 0.0014
# 이태원메이드 0.0014
# 도넛 0.0014
# 런치 0.0014
# 신사동맛집 0.0014
# 신촌맛집 0.0014
# 금속공예 0.0014
# seoulfood 0.0014
# 상수맛집 0.0014
# 양갱 0.0014
# 키링 0.0014
# 책스타그램 0.0014
# cafeii 0.0014
# ソウルカフェ 0.0014
# 양갈비 0.0014
# 페인팅 0.0014
# 에그베네딕트 0.0014
# baristalife 0.0014
# 실버커스텀 0.0014
# 173내가사는세상 0.0014
# fave 0.0014
# 서울나들이 0.0014
# 맛집투어 0.0014
# loner 0.0014
# 로너 0.0014
# uglyfollowtrain 0.0014
# bondedaskoreia 0.0014
# 우사단길맛집 0.0014
# 커피타임 0.0014
# restaurant 0.0014
# canon 0.0014
# 삼겹살 0.0014
# 견스타그램 0.0014
# 독스타그램 0.0014
# 꾸까 0.0014
# kukka 0.0014
# 전통주 0.0014
# カフェ巡り 0.0014
# hotplace 0.0014
# cocktail 0.0014
# iteawon 0.0014
# 버거 0.0014
# goldenretriever 0.0014
# instadog 0.0014
# florist 0.0014
# han0m 0.0014
# harajuku 0.0014
# 올프리마 0.0014
# 티타임 0.0014
# sweets 0.0014
# 스카치노 0.0014
# 동성로맛집 0.0014
# 이태원밥집 0.0014
# 종로맛집 0.0014
# 광화문맛집 0.0014
# 여름 0.0014
# 푸들 0.0014
# 인스타데일리 0.0014
# 숙대입구 0.0014
# 극장판 0.0014
# 33apartment 0.0014
# 생맥주 0.0014
# 북스타그램 0.0014
# 오마일 0.0014
# 홍대술집 0.0014
# 다육이 0.0014
# 한남맛집 0.0014
# 마켓 0.0014
# baristadaily 0.0014
# 압구정수제버거 0.0014
# 173thepizza 0.0014
# 블로그마켓 0.0014
# 수요일 0.0014
# 합정맛집 0.0014
# 서울야경 0.0014
# 스텔라 0.0014
# same 0.0014
# 반포대교 0.0014
# 까페 0.0014
# 숙대맛집 0.0014
# 고양이옷 0.0014
# 정엽카페 0.0014
# 한식 0.0014
# 영화 0.0014
# 양주 0.0014
# 하와이안피자 0.0014
# 그바람에주식회사 0.0014
# coreanobrinks 0.0014
# 태슬 0.0014
# 가방장식 0.0014
# 경리단길루프탑 0.0014
# goldenpuppy 0.0014
# 합정카페 0.0014
# 키덜트 0.0014
# 조이의공간 0.0014
# 강아지 0.0014
# 브이 0.0014
# onthetable 0.0014
# 플랫아이언 0.0014
# dailyphoto 0.0014
# inspiration 0.0014
# 자연성애자 0.0014
# ソウル 0.0014
# 창화당 0.0013
# 0msan 0.0013
# 반지 0.0013
# 뒤에나비 0.0013
# 스콘 0.0013
# 가드닝 0.0013
# 명동맛집 0.0013
# 이대맛집 0.0013
# 옷스타그램 0.0013
# 바코 0.0013
# 카페그램 0.0013
# icecream 0.0013
# 부산카페 0.0013
# 연말 0.0013
# 플랜테리어 0.0013
# 독립서점 0.0013
# 루프탑바 0.0013
# 잠실카페 0.0013
# 디스플레이 0.0013
# instalike 0.0013
# 애스타그램 0.0013
# 핫플 0.0013
# 수요미식회맛집 0.0013
# 언더프레셔 0.0013
# 소품 0.0013
# 짱맛 0.0013
# 셀스타 0.0013
# 신상카페 0.0013
# 아렌델 0.0013
# arendelle 0.0013
# 프렌치토스트 0.0013
# chimaclife 0.0013
# 이색데이트 0.0013
# 데이트그램 0.0013
# 제주도맛집 0.0013
# 로우커피 0.0013
# hongdae 0.0013
# aria0grande 0.0013
# dotz 0.0013
# 키즈클래스 0.0013
# 부부스타그램 0.0013
# 재즈 0.0013
# 카페사루 0.0013
# 베이커리 0.0013
# tiramisu 0.0013
# 세렝게티 0.0013
# 108계단 0.0013
# 우산단로 0.0013
# 해방촌루프탑 0.0013
# 패션스타그램 0.0013
# 친구랑 0.0013
# 차돌박이 0.0013
# 편집샵 0.0013
# lunch 0.0013
# 망원동맛집 0.0013
# 모사부카 0.0013
# 딸기 0.0013
# 디뮤지엄맛집 0.0013
# 3d프린트 0.0013
# 맞팔해요 0.0013
# 강남카페 0.0013
# 혼자가는술집 0.0013
# 헬카페 0.0013
# 옷스타그램i 0.0013
# livingdoll 0.0013
# japanesefashion 0.0013
# 대구맛집 0.0013
# downtowner 0.0013
# 장진우식당 0.0013
# 아벡누 0.0013
# 초콜릿 0.0012
# 도넛라떼 0.0012
# 집밥 0.0012
# good 0.0012
# instapic 0.0012
# bonnyspizza 0.0012
# 좋아요반사 0.0012
# rockeat 0.0012
# 카페대관 0.0012
# hackney 0.0012
# 발렌타인데이 0.0012
# 스타벅스 0.0012
# 망고서림 0.0012
# 소월길카페 0.0012
# brandy 0.0012
# plants 0.0012
# 해방촌맥주 0.0012
# 달다구리 0.0012
# foodpics 0.0012
# 반미 0.0012
# 치킨맛집 0.0012
# 스냅사진 0.0012
# 주말나들이 0.0012
# cafeoye 0.0012
# 이태원해방촌 0.0012
# 그랜드뮤즈 0.0012
# 경리단수제버거 0.0012
# 제주식당 0.0012
# 이태원맛집추천 0.0012
# jazz 0.0012
# 이탈리안레스토랑 0.0012
# 더베이커스테이블 0.0012
# orangorang 0.0012
# 심야식당 0.0012
# 커피숍 0.0012
# 행복해 0.0012
# vinyl 0.0012
# 한남동바 0.0012
# 제일기획 0.0012
# 쿠키 0.0012
# 사루 0.0012
# onei0million 0.0012
# 멋스타그램 0.0012
# 영화관 0.0012
# 독립영화 0.0012
# 제주여행 0.0012
# selstagram 0.0012
# 더시리얼 0.0012
# 미주리 0.0012
# contedetulear 0.0012
# 공간 0.0012
# bracelet 0.0012
# 모어댄위스키 0.0012
# 증류펍 0.0012
# 소라사장 0.0012
# ㅅㅅ음식작업소 0.0012
# 샤워룸 0.0012
# 키에리 0.0012
# 애교 0.0012
# 스타일 0.0012
# 마렘마 0.0012
# 아인슈페너 0.0012
# party 0.0012
# 샴페인 0.0012
# 해방촌노아 0.0012
# harajukufasion 0.0012
# 방탄소년단 0.0012
# 인천맛집 0.0012
# 그랑블루 0.0012
# 와인파티 0.0012
# 샌드위치가게 0.0012
# sunday 0.0012
# 앤드하리한남 0.0012
# pink 0.0011
# chocolat 0.0011
# 오라라 0.0011
# 맛있어 0.0011
# 녹사평술집 0.0011
# 대전 0.0011
# 서면 0.0011
# 마크컬렉션 0.0011
# 반려견 0.0011
# 무화과 0.0011
# 인친해요 0.0011
# 한남카페 0.0011
# 애견동반카페 0.0011
# 안드로메다행 0.0011
# 토이 0.0011
# 빈티지인형 0.0011
# waxcarving 0.0011
# 하루 0.0011
# 수제아이스크림 0.0011
# 월요일 0.0011
# 패션파이브 0.0011
# 송도맛집 0.0011
# 상수카페 0.0011
# 고양이 0.0011
# jacoby 0.0011
# 조명 0.0011
# 정발산카페 0.0011
# 파주카페 0.0011
# 부리또 0.0011
# 부리토 0.0011
# 김치볶음밥부리또 0.0011
# 마카롱부띠끄 0.0011
# flowercafe 0.0011
# 바닐라라떼 0.0011
# 날씨 0.0011
# 해운대맛집 0.0011
# dmuseum 0.0011
# 일식 0.0011
# 우사단마을 0.0011
# 가양주 0.0011
# 테이스티로드 0.0011
# 카푸치노 0.0011
# 해방촌치맥라이프 0.0011
# 눈꽃치킨 0.0011
# 팻캣 0.0011
# 커피맛집 0.0011
# happyhappyday 0.0011
# yolo 0.0011
# 그냥갈수없잖아 0.0011
# cashgainingparty 0.0011
# khaosfollowtrain 0.0011
# demilovato 0.0011
# justinbieber 0.0011
# onedirection 0.0011
# 마틸다 0.0011
# 상수동카페 0.0011
# 꽁티드툴레아더맨션점 0.0011
# 앤트러사이트 0.0011
# 旅行 0.0011
# 석고방향제 0.0011
# 울산맛집 0.0011
# 빵순이 0.0011
# 치즈케이크 0.0011
# americano 0.0011
# 카페미주리 0.0011
# sayoo 0.0011
# 휴식 0.0011
# 핑크마가린 0.0011
# diet 0.0011
# 냥스타그램 0.0011
# 극장 0.0011
# 독립 0.0011
# 단편영화 0.0011
# 키노캔들 0.0011
# 한남동와인 0.0011
# delicious 0.0011
# 타이리셔스 0.0011
# 전신샷 0.0011
# 제주돼지 0.0011
# 도자기공방 0.0011
# 자몽에이드 0.0011
# rp 0.0011
# 한국 0.0011
# 스노잉카페 0.0011
# 패션아이템 0.0011
# 청담동 0.0011
# designsmithseoul 0.0011
# 훈남 0.0011
# 경리단루프탑 0.0011
# 추억 0.0011
# 시바견 0.0011
# yongsan 0.0011
# 라페름 0.0011
# 可愛い 0.0011
# 소고기 0.0011
# 紹介 0.0011
# snupyzel 0.0011
# 이태원라운지 0.0011
# 이태원타투 0.0011
# 꼼모아 0.0011
# 수제감자튀김 0.0011
# model 0.0011
# 핸드드립 0.0011
# 챔프커피2작업실 0.0011
# itawon 0.0011
# 감사 0.0011
# 5mile 0.0011
# autumn 0.0011
# 이태원초콜릿 0.001
# 휴가 0.001
# 청담 0.001
# hbd 0.001
# 운동 0.001
# 카페플랫 0.001
# 노량진맛집 0.001
# 공감 0.001
# 데이트룩 0.001
# 카페아운 0.001
# 아운 0.001
# 꽃길 0.001
# kimkardashian 0.001
# 코니크 0.001
# 애견동반 0.001
# 우사단장난감 0.001
# 우사단소품샵 0.001
# 우사단안로메다행 0.001
# 안드로메다 0.001
# 밤 0.001
# 플레이팅 0.001
# 숙대입구맛집 0.001
# eclair 0.001
# 제주도 0.001
# 연희동카페 0.001
# instacafe 0.001
# 팔로 0.001
# 부모님선물 0.001
# 플라워 0.001
# 이태원네일 0.001
# 카페모카 0.001
# 감바스 0.001
# 추석선물 0.001
# 답례품 0.001
# 런드리프로젝트 0.001
# 정발산맛집 0.001
# 라멘 0.001
# 파워플랜트 0.001
# flowershop 0.001
# 휴무 0.001
# 꽃주는카페 0.001
# 연말모임 0.001
# 해방촌나들이 0.001
# 베트남음식 0.001
# latteartporn 0.001
# interiordesign 0.001
# 선팔맞팔 0.001
# 삐깐떼치킨 0.001
# 크래프트비어 0.001
# 치킨맥주 0.001
# 해산물 0.001
# 육회 0.001
# 인친환영 0.001
# lowcoffee 0.001
# 程 0.001
# 뜨개 0.001
# taylorswift 0.001
# artspace 0.001
# 더치커피 0.001
# 다츠 0.001
# 럽스타 0.001
# 마피아디저트 0.001
# 빵집 0.001
# 맥코이 0.001
# fff 0.001
# 프랑스레스토랑 0.001
# 소반1988 0.001
# 매점뽕 0.001
# 한라산 0.001
# thecereal 0.001
# 시리얼카페 0.001
# 차삼집 0.001
# 서울역맛집 0.001
# 브라우니 0.001
# 옥수동 0.001
# 감성타코 0.001
# drawing 0.001
# 여자친구선물 0.001
# bartender 0.001
# saturday 0.001
# view 0.001
# life 0.001
# 소라 0.001
# 블루스퀘어맛집 0.001
# youth 0.001
# 카레 0.001
# rabout 0.001
# 한우 0.001
# 브랜디 0.001
# shapeways 0.001
# 경리단길샤워룸 0.001
# 한와담 0.0009
# 옹느세자매 0.0009
# 한강 0.0009
# 골목길 0.0009
# 푼토나인 0.0009
# 홍대미용실 0.0009
# 구슬모아당구장 0.0009
# 꽃다발주문 0.0009
# 한남동레스토랑 0.0009
# 메이크업 0.0009
# cafetour 0.0009
# 무사 0.0009
# 한남동무사 0.0009
# 야경깡패 0.0009
# tattoo 0.0009
# 고로케 0.0009
# 바베큐파티 0.0009
# style 0.0009
# dailylife 0.0009
# seoultrip 0.0009
# markcollection 0.0009
# 피트와인 0.0009
# 피트커피 0.0009
# 브레드피트 0.0009
# friday 0.0009
# 카페탐방 0.0009
# 화이팅 0.0009
# 갤러리대관 0.0009
# creative 0.0009
# 갤러리데이트 0.0009
# 프렌치레스토랑 0.0009
# 썬댄스플레이스 0.0009
# 작은숲 0.0009
# 아이폰케이스 0.0009
# 육아스타그램 0.0009
# 카사블랑카 0.0009
# 맛저 0.0009
# 후암동카페 0.0009
# 핫초코 0.0009
# chocolatier 0.0008
# 이중생활 0.0008
# 고마워 0.0008
# 신사 0.0008
# 점심시간 0.0008
# 보난자커피 0.0008
# 연휴 0.0008
# お 0.0008
# 추석연휴 0.0008
# cheese 0.0008
# 출장샵 0.0008
# 아도마니 0.0008
# 스티키리키아이스크림 0.0008
# 아쑤크림 0.0008
# 크래프트아이스크림 0.0008
# 갈월동 0.0008
# 갈월동맛집 0.0008
# seoulicecream 0.0008
# icecreamseoul 0.0008
# 구복만두 0.0008
# 창수린 0.0008
# 고추장초콜렛 0.0008
# 미트볼 0.0008
# salad 0.0008
# passion5 0.0008
# 도산공원맛집 0.0008
# 안주 0.0008
# 캐논 0.0008
# 수제초콜렛 0.0008
# 우정스타그램 0.0008
# 화정동카페 0.0008
# 나는그렇게처음으로나를바라보았다 0.0008
# 식물키우기 0.0008
# 할로윈데이 0.0008
# dongkucafe 0.0008
# 노아 0.0008
# 원테이블키친 0.0008
# 아이아이 0.0008
# 바리스타그램 0.0008
# 스시 0.0008
# ubereats 0.0008
# 다큐3일 0.0008
# 오아시스한남 0.0008
# 우니동 0.0008
# 카페오예 0.0008
# 수공예 0.0008
# 맛 0.0008
# 소월38 0.0008
# 푸드 0.0008
# 우사단맛집 0.0008
# 볶음밥 0.0008
# 세임카페 0.0008
# 하얏트 0.0008
# 느낌 0.0008
# 맥주스타그램 0.0008
# 용산수영장 0.0008
# ha0hzo 0.0008
# 스튜디오 0.0008
# showroom 0.0008
# 김포카페 0.0008
# 샵인샵 0.0008
# 대안공간 0.0008
# 앤틱 0.0008
# 한남동데이트 0.0008
# 스텝밀 0.0008
# 영업중 0.0008
# 분당맛집 0.0008
# 예물 0.0008
# tea 0.0008
# 드라이브 0.0008
# 디퓨저 0.0008
# 울산카페 0.0008
# film 0.0008
# 프리마켓 0.0008
# bigstepcoffee 0.0008
# 블랙 0.0008
# 라면 0.0008
# 연예인 0.0008
# 파티룸 0.0008
# 장신구 0.0008
# 말카 0.0008
# 이태원와인콜키지무료 0.0008
# dslr 0.0008
# 성게알 0.0008
# 바르바코아 0.0008
# 송년회 0.0008
# 젊줌마 0.0008
# 알프키친 0.0008
# 한남동파스타 0.0008
# 달달 0.0008
# southkorea 0.0008
# 아아 0.0008
# 휴일 0.0008
# 한남동집밥 0.0008
# 이태원점심 0.0008
# dj 0.0008
# 매덕스피자 0.0008
# 베이글 0.0008
# 비밀 0.0008
# 굿 0.0008
# alldaybrunch 0.0008
# 데일리푸드 0.0008
# sınglemaltwhiskey 0.0008
# 임산부 0.0008
# banhmilee 0.0008
# showerroom 0.0008
# 밥 0.0008
# 캐틀앤비 0.0008
# 배불러 0.0008
# 빨래방카페 0.0008
# ソウル旅行 0.0008
# 코스요리 0.0008
# blocpartyseoul 0.0008
# 숨은맛집 0.0008
# 크리에잇쿠키 0.0008
# 아르모니움 0.0008
# 핑크 0.0008
# bks 0.0008
# 더마고 0.0008
# 무사바 0.0008
# mousa 0.0008
# 뮤즈 0.0008
# 어버이날 0.0008
# 여행에미치다 0.0008
# 팔로잉 0.0008
# 우정 0.0008
# 리그램 0.0008
# 안주스타그램 0.0008
# 한남동와인바 0.0008
# 아웃핏 0.0008
# 꽃선물 0.0008
# 건대맛집 0.0008
# 대전맛집 0.0008
# 앤드하리 0.0008
# 잭슨피자 0.0008
# 서울숲 0.0008
# 망리단길 0.0008
# italian 0.0008
# lamarmiteseoul 0.0008
# 프랑스요리 0.0008
# 명동 0.0008
# 친구들 0.0008
# porcelain 0.0008
# 남양주카페 0.0008
# 한남684 0.0008
# 디너 0.0008
# 평일 0.0008
# 인생샷 0.0008
# 디자인갤러리 0.0008
# 약속장소 0.0008
# 소월로 0.0008
# pic 0.0008
# 오후 0.0008
# nikon 0.0008
# 더맨션 0.0008
# 모로코음식 0.0008
# 젠틀플라워 0.0008
# 오늘의커피 0.0008
# 비엔나커피 0.0008
# 이태원경리단길 0.0008
# 토요일밤 0.0008
# 옥상 0.0008
# ト 0.0007
# 보니스펍 0.0007
# 지니펍 0.0007
# 남산공원 0.0007
# hours 0.0007
# 가죽공예 0.0007
# 메이드 0.0007
# 서면맛집 0.0007
# 광안리 0.0007
# everythingbutthehero 0.0007
# 마요식당 0.0007
# 피자스타그램 0.0007
# 코레아노스 0.0007
# 우사단장난감가게 0.0007
# 우사단인형가게 0.0007
# 이태원장난감가게 0.0007
# 이태원인형가게 0.0007
# aoisora 0.0007
# 일미집 0.0007
# 서울로 0.0007
# 도산공원 0.0007
# sundaysweets 0.0007
# 매거진 0.0007
# 동네서점 0.0007
# 티 0.0007
# 최고 0.0007
# 라자냐 0.0007
# 5마일 0.0007
# 대화동카페 0.0007
# 경리단길펍 0.0007
# 돈까스 0.0007
# 이태원모임 0.0007
# 먹방투어 0.0007
# gimotti 0.0007
# 려인식당 0.0007
# 해방촌밥집 0.0007
# 웨이베터 0.0007
# 맞팔선팔 0.0007
# 블루문 0.0007
# 합정 0.0007
# 초밥 0.0007
# 퇴근후 0.0007
# 강추 0.0007
# 가을밤 0.0007
# 홍차 0.0007
# 용산카페 0.0007
# cat 0.0007
# 취저 0.0007
# 유색보석 0.0007
# turquoise 0.0007
# 촬영 0.0007
# ohlala 0.0007
# 팔찌 0.0007
# 커피고작 0.0007
# 진달래 0.0007
# 불리스 0.0007
# fleamarket 0.0007
# 한남동빵집 0.0007
# 굿모닝 0.0007
# 명이나물 0.0007
# 무화과토스트 0.0007
# 데이트장소 0.0007
# 남산데이트 0.0007
# jankuraartspace 0.0007
# 반포 0.0007
# 이촌동수영레슨 0.0007
# 세컨드키친 0.0007
# 이태원커피 0.0007
# 글라스아트 0.0007
# 한남동맥주 0.0007
# 신혼부부 0.0007
# 우버이츠 0.0007
# 쏘리맘암쏘하이 0.0007
# atelier 0.0007
# 빼빼로데이 0.0007
# 미스터페이튼 0.0007
# cafesaru 0.0007
# 데일리패션 0.0007
# 콜드브루 0.0007
# 춥다 0.0007
# 연탄고기 0.0007
# 사는게다고기서고기 0.0007
# 근고기 0.0007
# 혼고 0.0007
# 기분전환 0.0007
# 좋다 0.0007
# 빈티지샵 0.0007
# 금호동맛집 0.0007
# 블로그 0.0007
# 함께 0.0007
# coffeelover 0.0007
# goodafternoon 0.0007
# 디톡스 0.0007
# 묵은지닭찜 0.0007
# 기록 0.0007
# 오늘의아운 0.0007
# 프랑스 0.0007
# newrp 0.0007
# bbq 0.0007
# bmeal 0.0007
# 금호동 0.0007
# 칵테일바 0.0007
# studio 0.0007
# gallery 0.0007
# 이태원가정식 0.0007
# 이태원집밥 0.0007
# 남자팔찌 0.0007
# ordermade 0.0007
# jewelrydesign 0.0007
# 세공 0.0007
# 세공강습 0.0007
# 모우모우 0.0007
# blue 0.0007
# 나리식당 0.0007
# 증류소주 0.0007
# black 0.0007
# 촵촵 0.0007
# 멋짐 0.0007
# 타르틴 0.0007
# baco 0.0007
# sls 0.0007
# sla 0.0007
# 디자인소품 0.0007
# stylejieum 0.0007
# 이태원동321다시2 0.0007
# 핫도그 0.0007
# 아날로그키친 0.0007
# 유피피 0.0007
# 버블앤코클스 0.0007
# 필름카메라 0.0007
# 디자이너브랜드 0.0007
# 반미샌드위치 0.0007
# 뷰티 0.0007
# 화장품 0.0007
# chicken 0.0007
# leather 0.0007
# 시바이누 0.0007
# 건강식 0.0007
# 다이어터 0.0007
# 토이펍 0.0007
# 굿밤 0.0007
# 아티스트 0.0007
# 분식 0.0007
# 니트 0.0007
# 스테이크맛집 0.0007
# 이탈리안 0.0007
# bookstagram 0.0007
# lifestyle 0.0007
# 꽃집 0.0007
# 사랑의고기 0.0007
# bread 0.0007
# 출사 0.0007
# workinghours 0.0007
# 크로와상 0.0007
# 아리에코 0.0007
# 에이플랫 0.0007
# 수성구맛집 0.0007
# 피곤 0.0007
# 수바 0.0007
# 어제 0.0007
# 성광대도 0.0007
# 루경리단 0.0007
# 루나피아나 0.0007
# 라마밋서울 0.0007
# 쌀국수맛집 0.0007
# 압구정로데오맛집 0.0007
# 향수 0.0007
# teatime 0.0007
# 바베큐플래터 0.0007
# sky 0.0007
# 꽁띠드툴레아 0.0007
# 팔로워 0.0007
# 해장 0.0007
# 당근케익 0.0007
# イテウォン 0.0007
# 마이페이보릿 0.0007
# myfavorite 0.0007
# 미트볼라운지 0.0007
# 치즈케익 0.0007
# 홈베이킹 0.0007
# 야채가게 0.0007
# 코스트코 0.0007
# 새댁일상 0.0007
# coffeebeerwine 0.0007
# 네일 0.0007
# chanyeol 0.0007
# coffeestagram 0.0007
# ソウルグルメ 0.0007
# 양고기 0.0007
# 타투 0.0007
# punto9 0.0007
# gentleflower 0.0007
# gentleflo 0.0007
# 젠틀플라워바이지니초이 0.0007
# 젠틀플로 0.0007
# souva 0.0007
# 라이너스바베큐 0.0007
# 오블라디 0.0007
# 데일리커피 0.0007
# 인생맛집 0.0007
# 과카몰리 0.0007
# dogstagram 0.0007
# 육아소통 0.0007
# 대학생 0.0007
# 감동 0.0007
# 화이트데이 0.0006
# 임산부일상 0.0006
# 웨이팅 0.0006
# 하와이안 0.0006
# 청담동맛집 0.0006
# 잉글리쉬블랙퍼스트 0.0006
# 서울데이트 0.0006
# 베트남요리 0.0006
# 일오구 0.0006
# 루루디 0.0006
# leathercraft 0.0006
# 대구 0.0006
# 동성로 0.0006
# unisex 0.0006
# 아방뮤제 0.0006
# 모어댄레스 0.0006
# 수업 0.0006
# 치즈플로 0.0006
# 조건만남 0.0006
# 애인대행 0.0006
# 여름휴가 0.0006
# 스노우카메라 0.0006
# theroomcafe 0.0006
# 서촌카페 0.0006
# 서촌맛집 0.0006
# 바토스 0.0006
# 발렌타인데이선물 0.0006
# yokan 0.0006
# 리스 0.0006
# 모닝커피 0.0006
# 책방 0.0006
# 리플라이커피 0.0006
# 비오는날 0.0006
# 송파카페 0.0006
# 작품 0.0006
# breakfast 0.0006
# 가드닝카페 0.0006
# lfl 0.0006
# 가츠산도 0.0006
# 망년회 0.0006
# 저렴한와인바 0.0006
# 논현맛집 0.0006
# 이태원쌀국수 0.0006
# 놀러와용 0.0006
# 동대문 0.0006
# 광화문 0.0006
# 청담동수제버거 0.0006
# 이태원고기집 0.0006
# 나리의집 0.0006
# 직장인스타그램 0.0006
# underpressure 0.0006
# 방방곡곡 0.0006
# 다믄 0.0006
# 귀여워 0.0006
# hidden 0.0006
# face 0.0006
# 숙명여대 0.0006
# 자유부인 0.0006
# daliy 0.0006
# 귀걸이 0.0006
# 눈 0.0006
# grandmuse 0.0006
# 이태원가볼만한곳 0.0006
# 젤라또 0.0006
# 신세계백화점 0.0006
# deflore 0.0006
# 연어덮밥 0.0006
# lowcoffeehan0m 0.0006
# 얌얌 0.0006
# likeforlikes 0.0006
# 간식스타그램 0.0006
# 이태원디저트카페 0.0006
# 노량진 0.0006
# 반포한강공원 0.0006
# 승무원수영 0.0006
# 수영레슨 0.0006
# 수영개인레슨 0.0006
# 용산초등학교수영장 0.0006
# 밥집 0.0006
# spring 0.0006
# 에피세리꼴라주 0.0006
# 야스노야 0.0006
# 생와사비 0.0006
# 양갈비맛집 0.0006
# 양고기맛집 0.0006
# 코바늘 0.0006
# 중고 0.0006
# 액세서리 0.0006
# 뮤직라이브러리 0.0006
# unique 0.0004
# accessories 0.0004
# 주얼리샵 0.0004
# 수박 0.0004
# 테이스팅룸 0.0004
# 김치 0.0004
# 까눌레 0.0004
# chezflo 0.0004
# 수제햄 0.0004
# 쉐플로 0.0004
# handmadecheese 0.0004
# 수제치즈 0.0004
# 치즈가게 0.0004
# 치즈요리 0.0004
# 부라타치즈 0.0004
# 프로슈토햄 0.0004
# artisancheese 0.0004
# 화이트와인과치즈 0.0004
# 치즈와맥주 0.0004
# 패피 0.0004
# 레몬에이드 0.0004
# 애견 0.0004
# 삼각지 0.0004
# 쩍벌녀 0.0004
# 직딩스타그램 0.0004
# 제주빵집 0.0004
# 상남자 0.0004
# 만두잘하는집 0.0004
# 한량 0.0004
# ypot 0.0004
# ypotcoffee 0.0004
# ypotcoffeeroasters 0.0004
# 와이팟 0.0004
# 트라니아 0.0004
# 트라니아500 0.0004
# faemae61 0.0004
# faemalegend 0.0004
# e61 0.0004
# butfirstcoffee 0.0004
# 벗퍼스트커피 0.0004
# 메리고라운드 0.0004
# 라뜰리에 0.0004
# 몽블랑 0.0004
# 루이비통 0.0004
# 경주 0.0004
# 세종시 0.0004
# blog 0.0004
# posting 0.0004
# 이태원네일샵 0.0004
# 빙봉 0.0004
# 조각케익 0.0004
# itw 0.0004
# 예쁘다그램 0.0004
# 이태원동 0.0004
# 케이터링 0.0004
# desserts 0.0004
# 낙서 0.0004
# 자코비 0.0004
# 스테이지b 0.0004
# 스테이지비 0.0004
# 해방촌빨래방 0.0004
# leoshaebangcheon 0.0004
# 올데이브런치 0.0004
# 2차는 0.0004
# 송도 0.0004
# 홍대데이트 0.0004
# 실수투성이밤 0.0004
# 마음과마음 0.0004
# 톨릭스 0.0004
# yum 0.0004
# lovely 0.0004
# 새우벌집퐁듀 0.0004
# 머랭쿠키 0.0004
# 낮맥 0.0004
# 해방촌이자카야 0.0004
# 오늘도 0.0004
# 우동 0.0004
# 로즈베이커리 0.0004
# 말티즈 0.0004
# petstagram 0.0004
# pied 0.0004
# 빅웨이브 0.0004
# 냉동삼겹살 0.0004
# nightview 0.0004
# 전포동카페거리 0.0004
# 서면카페 0.0004
# cafehopping 0.0004
# 깐부치킨 0.0004
# 깐부치킨한남점 0.0004
# 선팔은맞팔 0.0004
# ndear 0.0004
# 카큐닷컴 0.0004
# home 0.0004
# summerlane 0.0004
# 크로아상 0.0004
# 런치메뉴 0.0004
# 레호이 0.0004
# 남산타워뷰 0.0004
# 케이크맛집 0.0004
# 현대카드뮤직라이브러리 0.0004
# 촬영대관 0.0004
# 선물추천 0.0004
# 연희동 0.0004
# happyhappyday월요일날씨 0.0004
# 내생일 0.0004
# einspanner 0.0004
# 특별한데이트 0.0004
# 서울커플데이트 0.0004
# 이태원야경 0.0004
# 어짜피 0.0004
# gelato 0.0004
# 그릴 0.0004
# grill 0.0004
# 코엑스 0.0004
# 스시맛집 0.0004
# jari 0.0004
# 더멘션 0.0004
# 로우커피한남 0.0004
# 한남동175번지 0.0004
# 돼지고기 0.0004
# 뉴스킨 0.0004
# knitting 0.0004
# crochet 0.0004
# 첫줄안녕 0.0004
# models 0.0004
# 하프앤하프 0.0004
# 페페로니 0.0004
# 보석길시장 0.0004
# 일본가정식 0.0004
# 엄마랑데이트 0.0004
# 173wanikim 0.0004
# 차 0.0004
# 뿌리와사비 0.0004
# 혼와사비 0.0004
# 生わさび 0.0004
# 징기스칸 0.0004
# 삿포로 0.0004
# 홋카이도 0.0004
# 스프카레맛집 0.0004
# 삼송카페 0.0004
# 디자이너 0.0004
# nybnb 0.0004
# nybnbco 0.0004
# 뉴욕버거엔베이글 0.0004
# 라페트카페 0.0004
# 역삼동맛집 0.0004
# 파인다이닝 0.0004
# 아이엠버거 0.0004
# 삼성동 0.0004
# 탱크솔로 0.0004
# 코코조이 0.0004
# 졸업 0.0004
# 에비뉴엘 0.0004
# 스타그램 0.0004
# コ 0.0004
# artclass 0.0004
# 아이스커피 0.0004
# 시나몬롤 0.0004
# 10월 0.0004
# 파올로데마리아 0.0004
# filmcamera 0.0004
# 한남아이파크맛집 0.0004
# 랍스터바 0.0004
# itewon 0.0004
# 통닭 0.0004
# 커리 0.0004
# 돈코츠라멘 0.0004
# 라멘맛집 0.0004
# 가지 0.0004
# 수제햄버거 0.0004
# 행사 0.0004
# 어니언링 0.0004
# 미국 0.0004
# sunshine 0.0004
# 첫눈 0.0004
# 우리집앞 0.0004
# 음라디오 0.0004
# mmmradio 0.0004
# skull 0.0004
# 드립커피 0.0004
# 감튀 0.0004
# 에클레어 0.0004
# 루틴 0.0004
# followforfollow 0.0004
# 사장님 0.0004
# hbccuisineweek 0.0004
# cuisineweek 0.0004
# 경리단길와인 0.0004
# 동네책방 0.0004
# 서점 0.0004
# 햇살 0.0004
# 여자옷가게 0.0004
# the100foodtruck 0.0004
# 화이트블라썸 0.0004
# 핸드메이드코트 0.0004
# 빨래를기다리는동안에 0.0004
# like 0.0004
# 바베큐플레터 0.0004
# 오믈렛 0.0004
# alpkitchen 0.0004
# 커트러리 0.0004
# 삼덕동카페 0.0004
# 아트101 0.0004
# 수채화 0.0004
# 수다삼매경 0.0004
# 원두납품 0.0004
# 비바베르데 0.0004
# 향초 0.0004
# 이태원거리 0.0004
# 굿애프터눈 0.0004
# 남쪽한국 0.0004
# 테마구분선 0.0004
# 웃음 0.0004
# plant 0.0004
# 꼼데가르송 0.0004
# 이태원야스 0.0004
# 서울도시주스 0.0004
# 수능선물 0.0004
# 핸드타이드 0.0004
# flowerlesson 0.0004
# picoftheday 0.0004
# 梨泰院カフェ 0.0004
# thetastemakerskorea 0.0004
# 꿀팁한국여행 0.0004
# 빅뱅 0.0004
# 대성fraumagazine 0.0004
# singlerp 0.0004
# 크리스마스트리 0.0004
# 초록 0.0004
# 인스타카페 0.0004
# 신사역맛집 0.0004
# 송악산 0.0004
# 라이프 0.0004
# 한남동커피 0.0004
# 플라워박스 0.0004
# 비어스타그램 0.0004
# craftbeer 0.0004
# 코디 0.0004
# hopegarden 0.0004
# bubbleandcockles 0.0004
# 몰트위스키 0.0004
# 세계맥주 0.0004
# 보글보글 0.0004
# 플라워석고방향제 0.0004
# 옥수역 0.0004
# 라잇비포 0.0004
# snow 0.0004
# 디저트오늘뭐먹지 0.0004
# 뷰티템 0.0004
# 코덕스타그램 0.0004
# weekendrestaurant 0.0004
# samso0ndaiden 0.0004
# 어서오세요 0.0004
# 꽁치파스타 0.0004
# 찬스브로스 0.0004
# 커피투어 0.0004
# hiphop 0.0004
# 압구정카페 0.0004
# 맨투맨 0.0004
# allstrong 0.0004
# 이태원까페 0.0004
# 柴犬 0.0004
# 패션타투 0.0004
# 패션화보 0.0004
# 너무덥다 0.0004
# 야동아님 0.0004
# 제주도웨딩스냅 0.0004
# 플라워디퓨저 0.0004
# 김밥 0.0004
# juice 0.0004
# 먹 0.0004
# 레몬 0.0004
# 남자플로리스트 0.0004
# brooklynbagel 0.0004
# brooklynbagelcafe 0.0004
# bagel 0.0004
# 브루클린베이글 0.0004
# 베이글맛집 0.0004
# 베이글카페 0.0004
# 브루클린베이글카페 0.0004
# bagelcafe 0.0004
# 오랜만에 0.0004
# cafetolix 0.0004
# 꽃피우리 0.0004
# flowerstagram 0.0004
# 화보 0.0004
# 빵한덩이 0.0004
# 옥수동빵집 0.0004
# 오레오 0.0004
# 화장실 0.0004
# 데일리백 0.0004
# 오만지아 0.0004
# 배우 0.0004
# 감기 0.0004
# 오늘은 0.0004
# 노을 0.0004
# 바나나블랙 0.0004
# dining 0.0004
# 베이커리카페 0.0004
# 이태원베이커리 0.0004
# 야채카레 0.0004
# histick 0.0004
# 목살 0.0004
# 연중무휴 0.0004
# 한남동카페거리 0.0004
# 예약제 0.0004
# 프라이빗식당 0.0004
# 프라이빗술집 0.0004
# 브라이덜샤워 0.0004
# 이태원공간대여 0.0004
# 6인석원테이블키친 0.0004
# 落 0.0004
# foodgram 0.0004
# 숙성한우 0.0004
# 로얄밀크티 0.0004
# 멘야산다이메 0.0004
# 블루밍부케부케 0.0004
# 풍경스타그램 0.0004
# 도코로 0.0004
# 라랄라 0.0004
# 로디네 0.0004
# 발효주 0.0004
# 포스터 0.0004
# illust 0.0004
# tomato 0.0004
# 마티니 0.0004
# 블라우스 0.0004
# 공사중 0.0004
# 카페안도 0.0004
# 인스타독 0.0004
# 어버이날선물 0.0004
# 구름 0.0004
# 마실 0.0004
# 하몽 0.0004
# 돼지 0.0004
# 튤립 0.0004
# 초밥맛집 0.0004
# 해방촌와인 0.0004
# 수르기 0.0004
# 맞팔해요우리 0.0004
# 相互フォロ 0.0004
# 저지오름 0.0004
# 노리매공원 0.0004
# 제주맛집 0.0004
# 서울투어 0.0004
# 서비스 0.0004
# 빠네파스타 0.0004
# 양꼬치 0.0004
# 단골집 0.0004
# 피치크러쉬 0.0004
# 반려견동반가능 0.0004
# 인생커피 0.0004
# 계절메뉴 0.0004
# 더네일바 0.0004
# 화로구이 0.0004
# 티그레세비체리아 0.0004
# tigrecevicheria 0.0004
# 엑소 0.0004
# 광주카페 0.0004
# 방범포차 0.0004
# 볼피노 0.0004
# vintageshop 0.0004
# 친친 0.0004
# 기쁨 0.0004
# joys 0.0004
# parlor 0.0004
# 조이의공간은기쁨으로향하는모든흐름을지지합니다 0.0004
# 복합문화공간 0.0004
# 갤러리카페 0.0004
# 와인스터디 0.0004
# 버클리커피소셜 0.0004
# 외식 0.0004
# 열두달 0.0004
# 파인애플식초 0.0004
# 장진우골목 0.0004
# 새우맛집 0.0004
# 인생 0.0004
# 흥해라 0.0004
# 그리다디저트컴퍼니 0.0004
# 프레지에 0.0004
# 리본 0.0004
# reborn 0.0004
# 송재림 0.0004
# 소주잔 0.0004
# themithree 0.0004
# 폴바셋 0.0004
# 좋아 0.0004
# 옷 0.0004
# 이태원해장 0.0004
# 맛스타램 0.0004
# 친구환영 0.0004
# 비빔밥 0.0004
# 한남684서울시 0.0004
# 맥주안주 0.0004
# 회식스타그램 0.0004
# 버거스타그램 0.0004
# tgif 0.0004
# 11월 0.0004
# 한와담블랙 0.0004
# 서울카페투어 0.0004
# gaintrick 0.0004
# bonefollowtrain 0.0004
# landenfollowtrain 0.0004
# 오랑오랑카페 0.0004
# イテウォンカフェ 0.0004
# 宮崎カフェ 0.0004
# ランチ 0.0004
# リンゴのタルト 0.0004
# カフェ好きな人と 0.0004
# 夜勤前 0.0004
# 드디어 0.0004
# 스타인살룬 0.0004
# 경리단길모우모우 0.0004
# 작가명 0.0004
# 전시기간 0.0004
# 블루 0.0004
# 청주카페 0.0004
# 아들바보 0.0004
# 딸바보 0.0004
# 팬디가방 0.0004
# 빨래방 0.0004
# color 0.0004
# 오빠랑 0.0004
# 안심 0.0004
# 앤트러사이트한남 0.0004
# 한남북엇국 0.0004
# 내사랑 0.0004
# 리조또 0.0004
# 아트스타그램 0.0004
# vegan 0.0004
# 대림미술관 0.0004
# 본식스냅 0.0004
# 웨딩촬영 0.0004
# 베이컨 0.0004
# sandwich 0.0004
# introrp 0.0004
# wheretogo 0.0004
# 알콜스타그램 0.0004
# 아스트 0.0004
# 세시셀라 0.0004
# 한남동맛집추천 0.0004
# 소주집 0.0004
# french 0.0004
# 월요병 0.0004
# badassstudio 0.0004
# oldeknives 0.0004
# 오늘은열었을거야 0.0004
# 우육면 0.0004
# vinchaud 0.0004
# 수제디져트 0.0004
# 돼지고기김치찜 0.0004
# eeeeeats 0.0004
# 한남동피자 0.0004
# 라구파스타 0.0004
# 엔젤리너스 0.0004
# 파스구찌 0.0004
# 데일리인스타 0.0004
# 토스트프랑세 0.0004
# 출강 0.0004
# 동래맛집 0.0004
# andhari 0.0004
# 고기스타그램 0.0004
# 불고기 0.0004
# christmas 0.0004
# 마쵸스헡 0.0004
# 카롱카롱 0.0004
# culturespace 0.0004
# 꾸띠자르당 0.0004
# 권선동 0.0004
# 이태원취향 0.0004
# 샥슈카 0.0004
# 모로코 0.0004
# 샌드위치맛집 0.0004
# pocelain 0.0004
# espressoparts 0.0004
# iirokongjak 0.0004
# space 0.0004
# method 0.0004
# 인테리어디자인 0.0004
# 클라우드 0.0004
# 플랫슈즈 0.0004
# 도너츠 0.0004
# 찹스테이크 0.0004
# 주부스타그램 0.0004
# 필라테스 0.0004
# dogs 0.0004
# 버거마인 0.0004
# burgermine 0.0004
# 마이스윗 0.0004
# farmacy 0.0004
# 迎 0.0004
# 相互フォ 0.0004
# 경리단길스노잉 0.0004
# 도미닉 0.0004
# 촉촉 0.0004
# adomani 0.0004
# 리차드카피캣 0.0004
# 아보카도명란비빔밥 0.0004
# tulip 0.0004
# 졸업작품전 0.0004
# 아이폰7케이스 0.0004
# 강남역 0.0004
# 탄현카페 0.0004
# 정원 0.0004
# 담금주 0.0004
# 자두주 0.0004
# 아오리라멘 0.0004
# 이태원계단장 0.0004
# 아디다스 0.0004
# 리빙 0.0004
# 달콤 0.0004
# 미술 0.0004
# 시옷시옷음식작업소 0.0004
# 크림파스타 0.0004
# 먹스타스램 0.0004
# 그램그램 0.0004
# 양말 0.0004
# 타짜도르커피 0.0004
# 반영구학원 0.0004
# mirror 0.0004
# 부첼리하우스 0.0004
# 전주카페 0.0004
# 바이닐스토리 0.0004
# vinylstory 0.0004
# cocktails 0.0004
# 가을날씨 0.0004
# 카라멜마끼아또 0.0004
# 마농트로포 0.0004
# 제주 0.0004
# 영국식펍 0.0004
# 런던프라이드 0.0004
# hope 0.0004
# 일상다반사 0.0004
# 카페뷔에이 0.0004
# poodle 0.0004
# 수마린 0.0004
# 함박스테이크 0.0004
# 이벤트참여 0.0004
# 카페충 0.0004
# 더테이블키친 0.0004
# green 0.0004
# 오리올루프탑 0.0004
# hellcafe 0.0004
# 콜키지프리 0.0004
# ragu 0.0004
# 클러치 0.0004
# 35mm 0.0004
# 토스트 0.0004
# coffeeshop 0.0004
# 경리단술집 0.0004
# 모닝글로리 0.0004
# 이태원혼술집 0.0004
# 뉴욕비앤비 0.0004
# birthday 0.0004
# 좋아하는 0.0004
# 레터링 0.0004
# d5300 0.0004
# 마카롱맛집 0.0004
# dessertcafe 0.0004
# 에브리띵벗더히어로 0.0004
# malcar 0.0004
# graddhyllan 0.0004
# 투데이스페셜 0.0004
# 기장카페 0.0004
# 쉬는날 0.0004
# 아포가토 0.0004
# 주말일상 0.0004
# jazzunit 0.0004
# bellozz 0.0004
# hardtoforget 0.0004
# 하드투포겟 0.0004
# 벨로즈 0.0004
# 맥앤치즈 0.0004
# 제주바다 0.0004
# ㅂㅗㅇ 0.0004
# 신세계 0.0004
# fall 0.0004
# 포토 0.0004
# 부기우기 0.0004
# 마블초콜릿 0.0003
# bonbon 0.0003
# 모델견 0.0003
# viet0mesefood 0.0003
# 꼬치 0.0003
# 사케 0.0003
# 좋음 0.0003
# 모듬만두 0.0003
# 중국집 0.0003
# 인정 0.0003
# 아이폰8 0.0003
# 안도카페 0.0003
# 잭크래프트 0.0003
# jackcraft 0.0003
# 클럽메이드 0.0003
# 클럽스타그램 0.0003
# 남포동 0.0003
# 전주꽃집 0.0003
# 무아애뚜아모든 0.0003
# 925silver 0.0003
# moiettoi 0.0003
# gemstone 0.0003
# review 0.0003
# 은제품 0.0003
# 트러플파스타 0.0003
# 핏불 0.0003
# 인포멀웨어 0.0003
# 수박케이크 0.0003
# 브로치 0.0003
# 맥도날드 0.0003
# 개강 0.0003
# 문어숙회 0.0003
# 김치칼국수 0.0003
# 일본 0.0003
# pet 0.0003
# 서울핫플 0.0003
# 아베크펫쇼룸 0.0003
# 까페스타그램 0.0003
# 한남살롱 0.0003
# diy 0.0003
# 한식술집 0.0003
# seaurchin 0.0003
# 네일아트 0.0003
# 젤네일 0.0003
# 네일스타그램 0.0003
# jele0 0.0003
# 스모키러버스 0.0003
# 경리단길추천 0.0003
# 경리단길존맛 0.0003
# 경리단길포토존 0.0003
# 아틱폭스 0.0003
# 발렌시아가 0.0003
# 라쿠치나 0.0003
# 지중해 0.0003
# 성북동 0.0003
# 사랑해요 0.0003
# 해방촌파스타 0.0003
# 레몬티 0.0003
# fuss 0.0003
# lafete 0.0003
# filmcafe 0.0003
# 아날로그 0.0003
# 즐거운 0.0003
# 기쁜하루 0.0003
# 해방촌라구 0.0003
# 아이돌 0.0003
# 구내식당 0.0003
# 사내식당 0.0003
# 막창 0.0003
# 33apt 0.0003
# 듁스커피 0.0003
# dukescoffee 0.0003
# 스케치 0.0003
# flatiron 0.0003
# sandwichshop 0.0003
# bourbon 0.0003
# 버뮤다 0.0003
# 솔티드카라멜 0.0003
# 이태원비원 0.0003
# 이태원오퓸 0.0003
# 이태원붐바 0.0003
# 이태원케익샵 0.0003
# ...
# 이태원베이글 0.0001
# 이태원맛집뉴욕베이글은 0.0001
# theflyingpan 0.0001
# 첫출근 0.0001
# 걱정이20000저10000이아님 0.0001
# ㅠㅠㅠ 0.0001
# 다문화공간 0.0001
# serengtea 0.0001
# 훈남사장님 0.0001
# holiday 0.0001
# 빗자루머리결 0.0001
# 탈색머리 0.0001
# happyhappyday케냐캔디 0.0001
# 한남동축제 0.0001
# 보광동축제 0.0001
# 댄스퍼포먼스 0.0001
# 라이브페인팅 0.0001
# 테라리움 0.0001
# 아참 0.0001
# 심신커플 0.0001
# 아트스뉴욕야경 0.0001
# 호수공원 0.0001
# 킨텍스 0.0001
# 망원동커피 0.0001
# 망고플레이스 0.0001
# 연남동브런치 0.0001
# 방배동카페골목 0.0001
# 경리단길맛집누리랑 0.0001
# 로젠택배 0.0001
# mas 0.0001
# fotokopi 0.0001
# 트러플타자린with블랙트러플 0.0001
# 인생파스타 0.0001
# 더블베이컨 0.0001
# 갈릭버터감자튀김 0.0001
# doublebacon 0.0001
# 분위기갑 0.0001
# 킬러의보디가드 0.0001
# 존잼 0.0001
# 마이원더남자친구는 0.0001
# 화보촬영 0.0001
# 룩북촬영 0.0001
# 마켓대관 0.0001
# 전시대관 0.0001
# 전시공간 0.0001
# 바캉스 0.0001
# vacances 0.0001
# 흰강남콩 0.0001
# 빼보자 0.0001
# 스테이크덮밥 0.0001
# 고기는 0.0001
# 언제나 0.0001
# 맛은최고 0.0001
# 행복한시간 0.0001
# 더맨션카페 0.0001
# 힐링힐링 0.0001
# 동아방송예술대학 0.0001
# 디마 0.0001
# 안성 0.0001
# sbs 0.0001
# 개그맨 0.0001
# 이영식 0.0001
# 아빠의삶 0.0001
# 딸과여행 0.0001
# 베트남여행 0.0001
# 다낭 0.0001
# 청라신도시 0.0001
# 영상제작 0.0001
# 바이럴영상 0.0001
# 도깨비픽쳐스 0.0001
# 프로필투어 0.0001
# 감기조심httpsyoutube 0.0001
# mfp4rfddyc 0.0001
# 홍어 0.0001
# 홍어삼합 0.0001
# 직원들과 0.0001
# 포차7080 0.0001
# 문어보쌈 0.0001
# 초코에몽 0.0001
# 솔로스키친 0.0001
# 한남동백반 0.0001
# 횡성한우 0.0001
# 화연당 0.0001
# 플라워영상 0.0001
# 날씨개꿀 0.0001
# 원두제일 0.0001
# 성찰 0.0001
# 20대 0.0001
# 사회 0.0001
# 사회적인 0.0001
# 로스팅 0.0001
# 샘플로스팅 0.0001
# 상처 0.0001
# 배려 0.0001
# 배려심 0.0001
# 소심 0.0001
# 소심함 0.0001
# 깊어가는가을밤 0.0001
# 브라우니맛집 0.0001
# 네이버 0.0001
# 이웃신청 0.0001
# 어떻게하는거죠 0.0001
# 글쓰는데만 0.0001
# 세시간 0.0001
# 나란바보 0.0001
# 호호 0.0001
# l4lf4f 0.0001
# 샐러드파스타 0.0001
# 현대아울렛 0.0001
# 엉클샘팬케이크 0.0001
# 호밀스콘키에리 0.0001
# 식사 0.0001
# 꼬수움 0.0001
# eatstagram 0.0001
# 왼손은거들뿐 0.0001
# 먹리어답터 0.0001
# fi0l 0.0001
# 0mjasikdang 0.0001
# dish 0.0001
# chillout 0.0001
# 방학식 0.0001
# 목금토영업 0.0001
# 늦은마감 0.0001
# 4시마감은피곤 0.0001
# 30분도안되서 0.0001
# 깨끗히클리어 0.0001
# 데일리브루차가운 0.0001
# 레드마운틴 0.0001
# tomo 0.0001
# aya 0.0001
# 미슐랭스타 0.0001
# happyhappyday방콕갔을때 0.0001
# 목화꽃다발 0.0001
# burgerpub 0.0001
# ㄷㅇㅌㅇㄴ 0.0001
# 호주식브런치 0.0001
# 물맛집 0.0001
# 분기마다방문 0.0001
# 일차 0.0001
# 야채곱창 0.0001
# 야곱 0.0001
# 블랙라멘 0.0001
# 언제나배고프다 0.0001
# 맛방 0.0001
# 파이브마일 0.0001
# 한남동5mile 0.0001
# 다음엔식사도전 0.0001
# 메론쥬스 0.0001
# 이터널선샤인 0.0001
# 동화책 0.0001
# xoxo 0.0001
# 가배도 0.0001
# 석촌호수카페 0.0001
# 석촌카페 0.0001
# aflat 0.0001
# 경리단길카페공연준비즁 0.0001
# 코젤 0.0001
# 이태원케이크 0.0001
# 그바람에주식회사그 0.0001
# 베이킹스타그램 0.0001
# 쿠키스타그램 0.0001
# bakingclass 0.0001
# walnut 0.0001
# cranberry 0.0001
# bagle 0.0001
# creamcheese 0.0001
# 약속이취소된날 0.0001
# 직원들과번개 0.0001
# 골목식당 0.0001
# 말발굽소세지 0.0001
# 생활맥주한남점 0.0001
# lp바 0.0001
# 경리단사루 0.0001
# 코다리정식 0.0001
# 외식스타그램 0.0001
# 마시멜로우 0.0001
# 핫쵸코 0.0001
# 선거날출근 0.0001
# 출퇴근4시간 0.0001
# 근무3시간 0.0001
# 화나네 0.0001
# 인생버거치즈 0.0001
# 해방촌오거리맛집 0.0001
# 감귤쥬스 0.0001
# 그림자놀이 0.0001
# folllow4follow 0.0001
# 소통후맞팔 0.0001
# 주말그타그램 0.0001
# 할머니케익 0.0001
# 현미케익 0.0001
# brownricecake 0.0001
# 레오니다스 0.0001
# 초코빙수 0.0001
# happyhappyday오늘은 0.0001
# 동기들최고최고 0.0001
# 다음타자는여 0.0001
# 경리단길맛집경리단길 0.0001
# 경리단와인 0.0001
# 말차후라이 0.0001
# 토네이도커피 0.0001
# 까페라떼 0.0001
# 연휴시작 0.0001
# 부부주말 0.0001
# 디프로젝트 0.0001
# 최랄라 0.0001
# 랄라쌀롱 0.0001
# plastic 0.0001
# 플라스틱전시회 0.0001
# 네그로니 0.0001
# 애주가 0.0001
# 술한잔 0.0001
# 알콜스타 0.0001
# 칵테일스타그램 0.0001
# dontpanic 0.0001
# 니술냉가이드 0.0001
# negroni 0.0001
# 입고알림 0.0001
# 시나몬도넛 0.0001
# 똥생 0.0001
# 당일발송 0.0001
# 브레이크타임 0.0001
# 한남바코 0.0001
# 넘나맛남 0.0001
# 오늘의술 0.0001
# 오늘의한잔 0.0001
# 이태원고우 0.0001
# 태원이자카야 0.0001
# 막차 0.0001
# vendredi 0.0001
# 패션5엄청나게 0.0001
# 디저트잉글리쉬블랙퍼스트 0.0001
# playseoul을 0.0001
# 몸매 0.0001
# 긍정 0.0001
# 종각맛집 0.0001
# 홈케어 0.0001
# 홈케어추천 0.0001
# 홈케어기기 0.0001
# 갈바닉 0.0001
# 예신 0.0001
# 신부관리 0.0001
# fashionstagram 0.0001
# 패팅 0.0001
# 신나는화장실 0.0001
# 너무좋다 0.0001
# 시간될때마다 0.0001
# 너도와볼래 0.0001
# 눈올때꼭올꺼다 0.0001
# 용산동2가451 0.0001
# 뭐 0.0001
# 건축인테리어 0.0001
# 한시간웨이팅 0.0001
# 청춘초밥초승달 0.0001
# 보름달모둠초밥 0.0001
# 단두야젤라또 0.0001
# 누텔라젤라또 0.0001
# 비법이뭘까 0.0001
# urbansketch 0.0001
# urbansketchers 0.0001
# landscape 0.0001
# 수체화 0.0001
# 인스타아트 0.0001
# 붓펜 0.0001
# 잉크 0.0001
# 야외스케치 0.0001
# 과일담금주 0.0001
# 떡갈나무 0.0001
# 건강이최고 0.0001
# 가슴통증 0.0001
# 심근경색 0.0001
# 예방 0.0001
# 조심 0.0001
# 그렇게닮았나요 0.0001
# happyhappydayjm 0.0001
# hasso 0.0001
# 뉴욕bnb 0.0001
# 쉑쉑버거 0.0001
# 버거엔맥주 0.0001
# kronenbourg1664 0.0001
# 캔비루 0.0001
# 닭갈비와와인 0.0001
# 티아라와인 0.0001
# 닭목살 0.0001
# 주주 0.0001
# 입고 0.0001
# neighbor 0.0001
# 여성의류편집샵 0.0001
# 악세서리 0.0001
# jewel 0.0001
# lifeenjoy 0.0001
# lehoi 0.0001
# 지브리스튜디오 0.0001
# 붉은돼지 0.0001
# 플로리아가든클래스룸은 0.0001
# 로코스비비큐 0.0001
# 슴여섯 0.0001
# 생신 0.0001
# 감동받는중 0.0001
# 광대승천 0.0001
# 심령사진아님 0.0001
# 아이다섯 0.0001
# 북유럽st 0.0001
# 짱야자 0.0001
# coffeedonuts 0.0001
# 라이치 0.0001
# 황금연휴 0.0001
# 막바지 0.0001
# girlsnight 0.0001
# 힙힙 0.0001
# sepku 0.0001
# ティラミスド 0.0001
# 가득채우지않아야아름답다 0.0001
# museumseries 0.0001
# 미술관느낌 0.0001
# 가리모쿠 0.0001
# 플랫그린 0.0001
# 브라운써클 0.0001
# 브릭쇼콜라 0.0001
# 멕시코소철 0.0001
# 소철 0.0001
# cycad 0.0001
# 물냉면 0.0001
# 완벽한조합 0.0001
# 냉면맛집 0.0001
# koreannoodles 0.0001
# 모로코가고싶다각 0.0001
# 추천각 0.0001
# 파나나 0.0001
# ba00 0.0001
# sweetb 0.0001
# winetasting 0.0001
# 아침까지 0.0001
# 술이안깸 0.0001
# newwinelist 0.0001
# 뉴와인리스트 0.0001
# upcomming 0.0001
# wineparty 0.0001
# 예쁜양말 0.0001
# 양말집 0.0001
# 나그네의하루 0.0001
# 캐롤엔넝3종세트 0.0001
# 할로윈핀 0.0001
# la 0.0001
# 아웃백이태원 0.0001
# 데스페라도스 0.0001
# 만물상 0.0001
# 사장님추천소주 0.0001
# 이강주 0.0001
# 사장님초미녀 0.0001
# 불고기전골 0.0001
# 맛있었어요 0.0001
# 감성충전 0.0001
# 칼로리충전 0.0001
# 비오는날해방촌 0.0001
# 토드셀비하우스즐거운나의집 0.0001
# 전시스타그램 0.0001
# 줄무늬친구 0.0001
# 만두잘하는창화당 0.0001
# 떡볶이맥주 0.0001
# 먹방샷 0.0001
# 함수모임 0.0001
# 쿠키선물 0.0001
# 답례품추천 0.0001
# 다먹지는 0.0001
# 않지만 0.0001
# 꽤 0.0001
# 먹음 0.0001
# 아내와불금의시작 0.0001
# 한남동와인앤모어지하 0.0001
# 현실은아내님체력고갈 0.0001
# 이것만먹고가요 0.0001
# 조금만참아줘 0.0001
# 빌리스 0.0001
# 매우조용한바 0.0001
# billys 0.0001
# 로우카페 0.0001
# 토요일이태원할로윈 0.0001
# 경리단길일본가정식 0.0001
# 로제우동파스타 0.0001
# 스테이크벤또 0.0001
# 아워커뮨 0.0001
# 이태원아워커뮨 0.0001
# 로제우동파스타추천 0.0001
# kykeat 0.0001
# 봉주르스고이 0.0001
# 명란파스타 0.0001
# 남푠이랑데이트 0.0001
# 말없이흡입 0.0001
# 중독성있는맛 0.0001
# 포크바오 0.0001
# 힐링런치 0.0001
# 안녕november 0.0001
# photoftheday 0.0001
# ソウルなう 0.0001
# 益善洞 0.0001
# マンドゥ 0.0001
# min 0.0001
# klunch 0.0001
# 카페코니크 0.0001
# kohnkcafe 0.0001
# 화창한날 0.0001
# 가을바람 0.0001
# 마스카포네크림크루아상 0.0001
# 안녕겨울 0.0001
# 천둥치고 0.0001
# 쏟아지는비 0.0001
# 티세트 0.0001
# 이태원스콘 0.0001
# 비타민 0.0001
# 애프터눈티세트 0.0001
# 융드립커피 0.0001
# 지옥의맛 0.0001
# 과일피자 0.0001
# 딸기샤베트 0.0001
# 딸기샤벳 0.0001
# instaseoul 0.0001
# greek 0.0001
# greekfood 0.0001
# dips 0.0001
# 취저카페 0.0001
# 코코뽀리 0.0001
# 사장님이좋은곳 0.0001
# saturdayvibes 0.0001
# 제법카페오랑오랑 0.0001
# 35mmfilm 0.0001
# on 0.0001
# eyeem 0.0001
# wearefilmfolks 0.0001
# 필름 0.0001
# 필름감성 0.0001
# 일상스냅 0.0001
# 서울스냅 0.0001
# seouls0p 0.0001
# see 0.0001
# hear 0.0001
# 사진한장노래한곡 0.0001
# yz 0.0001
# 커다란창문 0.0001
# 인디카 0.0001
# 이궁합추천 0.0001
# 씨릴로 0.0001
# asadatacos 0.0001
# 아보카드샐러드 0.0001
# 1363days 0.0001
# sweetheart 0.0001
# 이쁨 0.0001
# 포케샐러드 0.0001
# 수제돈까스 0.0001
# 듬직한서비 0.0001
# 일요일아침 0.0001
# 기분좋은아침 0.0001
# 날씨맑음 0.0001
# 예쁜하늘 0.0001
# 휴일아침 0.0001
# 주말일상행복한시간 0.0001
# 해피선데이 0.0001
# 즐주말 0.0001
# 레고 0.0001
# lego 0.0001
# 휴가스타그램 0.0001
# 서울여행중 0.0001
# 고갯길넘다내가넘어갈듯 0.0001
# 폭염주의보 0.0001
# 날씨실화니 0.0001
# 차가져올걸 0.0001
# 백만번후회중 0.0001
# 핫플레이스따위 0.0001
# 아무데나가자 0.0001
# 아디세트 0.0001
# 퍼방울캡까꼬룩 0.0001
# 송엘림 0.0001
# 머스타드 0.0001
# 노랑이 0.0001
# 잘어울리는 0.0001
# 그녀 0.0001
# 느낌있다 0.0001
# 평일연차 0.0001
# 이태원산책 0.0001
# 살롱드누이 0.0001
# verapizza 0.0001
# 하와이안꼬또피자 0.0001
# 깔라마리먹물파스타 0.0001
# 초코브라우니 0.0001
# 모던하니좋구먼 0.0001
# 라떼60 0.0001
# 꼭먹어봐야함 0.0001
# 비프스튜 0.0001
# beefstew 0.0001
# 만든거다드림 0.0001
# 그래서 0.0001
# 오늘없음 0.0001
# 따듯한설날2016020820150212쉽니다 0.0001
# 장전동 0.0001
# 조각케이크 0.0001
# 조각미남 0.0001
# 조각공원 0.0001
# 리빙소품 0.0001
# 비오는날엔 0.0001
# 비오는날은 0.0001
# 손글씨그램 0.0001
# 손글씨연습 0.0001
# 손글씨릴레이 0.0001
# ralphgibson 0.0001
# brazil 0.0001
# roastery 0.0001
# time 0.0001
# 하와이안카페 0.0001
# ㅇㅉㄹㄱ 0.0001
# 사이공그릴 0.0001
# 한남동사이공그릴 0.0001
# 3d프린트designsmith 0.0001
# 밤을걷는노비 0.0001
# 제꿈은한량입니다 0.0001
# 힝 0.0001
# 보노보노 0.0001
# 왔음 0.0001
# 신남 0.0001
# 근데이거더있을텐데 0.0001
# 왜10권까지밖에없지 0.0001
# 오세요 0.0001
# 보세요 0.0001
# 미놀타 0.0001
# enjoy 0.0001
# jiwoohime 0.0001
# hime 0.0001
# pictures 0.0001
# tourist 0.0001
# asc인증 0.0001
# 새우맥주 0.0001
# 건강한먹거리 0.0001
# 쿠에른 0.0001
# 이태원컨셉스토어 0.0001
# 녹사평대로40나길 0.0001
# 전통소주 0.0001
# 추석연휴내내영업합니다 0.0001
# 목금토일영업 0.0001
# 추석은사과지 0.0001
# 에일맥주 0.0001
# youonlyliveonce 0.0001
# 파이브 0.0001
# 5해방촌카페 0.0001
# 주인장맘에들어 0.0001
# dh88 0.0001
# 언더본 0.0001
# 흥아타이어 0.0001
# 사부작사부작 0.0001
# 재즈공연 0.0001
# 해방촌페스티벌 0.0001
# 할로윈재즈파티 0.0001
# hbcfestival2017 0.0001
# halloweenparty 0.0001
# jazzlive 0.0001
# blues 0.0001
# 블루스 0.0001
# 오미자레몬에이드 0.0001
# 청포도베리에이드 0.0001
# 시럽 0.0001
# 단맛 0.0001
# 상큼한 0.0001
# 청량감 0.0001
# 아이스음료 0.0001
# 헵시바극장 0.0001
# hepzibah 0.0001
# place 0.0001
# 마뫼 0.0001
# 후암동카페소월로카페 0.0001
# 민아레이더 0.0001
# 점심스타그램 0.0001
# 점심약속 0.0001
# 앙버터 0.0001
# 운동하는직장인 0.0001
# 애월 0.0001
# 닻 0.0001
# 딱새우회 0.0001
# 안경줄하트앤볼 0.0001
# 안경스트랩 0.0001
# 커플체험 0.0001
# 실내데이트 0.0001
# 이태원캔들 0.0001
# 섬유향수 0.0001
# 드레스퍼퓸 0.0001
# 패브릭미스트 0.0001
# 방향제 0.0001
# 캔들창업 0.0001
# 캔들원데이클래스 0.0001
# 캔들취미반 0.0001
# 캔들자격증 0.0001
# kabab 0.0001
# foreignrestaurant 0.0001
# shishkabobs 0.0001
# 먹고또먹고 0.0001
# 달콤커피 0.0001
# 정자동카페 0.0001
# 복고풍 0.0001
# 춘천카페 0.0001
# 애월카페 0.0001
# 광교카페거리 0.0001
# 봄날카페 0.0001
# 베이컨아보카도 0.0001
# 쿠쿠당 0.0001
# 씐나 0.0001
# 과다업로드주의 0.0001
# 犬 0.0001
# 에어비엔비서울 0.0001
# 서울숙소 0.0001
# 경리단길숙소 0.0001
# 경리단길먹방 0.0001
# 97 0.0001
# 프렌치후라이 0.0001
# 몽상클레르이태원 0.0001
# 점심뭐먹지 0.0001
# croissantsandwich 0.0001
# 나는요 0.0001
# 참 0.0001
# 글라스 0.0001
# 더로얄푸드앤드링크 0.0001
# 또띠아 0.0001
# yangpai 0.0001
# csbhbt 0.0001
# dirtycoffee 0.0001
# asmr 0.0001
# 샤샤샤 0.0001
# 슈슈슈 0.0001
# 쏴쏴쏴 0.0001
# 스핀들마켓 0.0001
# spindlemarket 0.0001
# 야홍이식당 0.0001
# 이태원우사단길계단장그리고 0.0001
# 이태원나잇 0.0001
# 어쩌냐내얼굴 0.0001
# 어쨋든내얼굴 0.0001
# 술주말 0.0001
# 난돼지얼굴초상화원츄 0.0001
# 추워서혀에마비옴 0.0001
# 빼꼼 0.0001
# 일찍일어나 0.0001
# 하루길다 0.0001
# 그릴드바나나프렌치토스트 0.0001
# winetatsing 0.0001
# 경리단길마카롱 0.0001
# allaboutme 0.0001
# 이태민 0.0001
# openrpp 0.0001
# 어 0.0001
# 커넉스 0.0001
# 쪽갈비제작소 0.0001
# 쪽갈비 0.0001
# 고기테리언 0.0001
# 아미르한국여행기 0.0001
# 전자답배 0.0001
# 더일리 0.0001
# 데일릴룩 0.0001
# 셀기 0.0001
# 카이 0.0001
# 음식작업소이집의 0.0001
# 초코마카롱해크니에서 0.0001
# afternoontea 0.0001
# 빨래돌리고여유있게차한잔하던이동네분들부럽다 0.0001
# 뒤에분죄송해요찍고보니너무웃겨서 0.0001
# 빨래카페 0.0001
# 예쁜빨래방 0.0001
# 도착 0.0001
# iberico 0.0001
# calcotada 0.0001
# 모래쿼텟 0.0001
# 브라이언신밴드 0.0001
# 밴드곤 0.0001
# brianshi0ndtheswingmakers 0.0001
# 재즈데이트 0.0001
# 한강다리 0.0001
# 군살정리 0.0001
# 상체비만 0.0001
# 강구경 0.0001
# seoulcoffeespot 0.0001
# 서울커피투어버스 0.0001
# 2017카페쇼 0.0001
# 초콜릿커피 0.0001
# 이름은몰라도 0.0001
# 시그니쳐메뉴 0.0001
# 달지도않고맛나다 0.0001
# 귀여운아무거나메뉴 0.0001
# seoulcafetour 0.0001
# 가매치노 0.0001
# 구경 0.0001
# 먹는거 0.0001
# 사악한가격하나에 0.0001
# 식신로드방영 0.0001
# 이태원즐기기 0.0001
# 난광주여자 0.0001
# 요리배워야지요 0.0001
# 귤먹방 0.0001
# 시금치크림파스타 0.0001
# 아보카도명란 0.0001
# 아보카도명란덮밥 0.0001
# happyhappyday비가 0.0001
# 무화과파티 0.0001
# 긍정파워 0.0001
# 빠샤 0.0001
# 무화과폭탄 0.0001
# 연휴의끝을잡고 0.0001
# 개꿀맛 0.0001
# 효비게이션 0.0001
# 핵꿀맛 0.0001
# 이전하고처음왔어 0.0001
# 줌마대열합류 0.0001
# 구스아일랜드 0.0001
# 먹스타그램촵촵촵 0.0001
# 트리니티파스타 0.0001
# 그라빠 0.0001
# 처음먹어보는맛 0.0001
# seoulsecret 0.0001
# thisisseoul 0.0001
# sooji 0.0001
# 냠냠냠 0.0001
# littlehappiness 0.0001
# 음식앞에서 0.0001
# 한없이 0.0001
# 그바람에주식회사아직 0.0001
# 빈티지백 0.0001
# 시스터마켓 0.0001
# 투모로우 0.0001
# reissue 0.0001
# your 0.0001
# 해피해피 0.0001
# 출근전 0.0001
# instaglam 0.0001
# berkeley 0.0001
# 409 0.0001
# 경리단길와인바 0.0001
# 니하이부츠 0.0001
# 스웨이드부츠 0.0001
# 예신예랑 0.0001
# 눈썹문신후기 0.0001
# 모찌피부 0.0001
# newyorkcity 0.0001
# 31개월 0.0001
# 한복스타그램 0.0001
# 출근스타그램 0.0001
# 손맛 0.0001
# 나미 0.0001
# 선곡 0.0001
# 사티 0.0001
# 바흐 0.0001
# 글렌굴드 0.0001
# 존케이지 0.0001
# 쇼팽 0.0001
# 시공소년 0.0001
# cd 0.0001
# 아기들 0.0001
# 웃어서 0.0001
# 사진중에 0.0001
# 강냉이가 0.0001
# 안나온 0.0001
# 이것뿐 0.0001
# 엔트리선크림 0.0001
# 발스타그램가을과 0.0001
# 가을메뉴 0.0001
# altdif 0.0001
# 에끌레어바이하루 0.0001
# 에클레어바이하루 0.0001
# 어반브리즈 0.0001
# 케일그레이프 0.0001
# watermelon 0.0001
# kalegrapejuice 0.0001
# 카카오메이커스 0.0001
# 워크스복권 0.0001
# 뽑기 0.0001
# 1000우사단길 0.0001
# 福 0.0001
# 연어베네딕트 0.0001
# msg 0.0001
# 마리텔에나온카페 0.0001
# 넌살쪄도예뻐 0.0001
# 수제티라미슈스카치노 0.0001
# 카라멜밀푀유 0.0001
# 포천진한옛날막걸리 0.0001
# 아이고좋아 0.0001
# pattern 0.0001
# korea0lcohol 0.0001
# 파란상점그에게 0.0001
# 플라워카드 0.0001
# 플라워청첩장 0.0001
# 하이비스커스티 0.0001
# 다육정원예약 0.0001
# 코코 0.0001
# 시식하면서 0.0001
# 추천해요요거요거넘이쁘다진짜진짜 0.0001
# 광주 0.0001
# 남산야외식물원 0.0001
# 뚜벅뚜벅 0.0001
# upp또가고싶은곳 0.0001
# 가게차리고싶닼ㅋㅋㅋㅋㅋ 0.0001
# 모발 0.0001
# 두피 0.0001
# 화분 0.0001
# 해리치샴푸 0.0001
# 샴푸 0.0001
# 해리치 0.0001
# hairich 0.0001
# 힐링생파 0.0001
# 생일파티3일차 0.0001
# 나나맨션 0.0001
# 새벽육아 0.0001
# 쇼미더마미 0.0001
# 독박육아 0.0001
# 전투육아 0.0001
# 00mansion 0.0001
# biflorekitchen 0.0001
# privatechef 0.0001
# publicbathhouse 0.0001
# interesting 0.0001
# scissors 0.0001
# 건축물 0.0001
# 얼리버드 0.0001
# 얼리버드홈아이템 0.0001
# homedecor 0.0001
# campagne 0.0001
# 깜빠뉴 0.0001
# greatview 0.0001
# greatvenue 0.0001
# gallerycafe 0.0001
# greenery 0.0001
# goodtoday 0.0001
# 광라사 0.0001
# 아늑 0.0001
# 조용 0.0001
# 감수성폭발 0.0001
# 소소한 0.0001
# 세상좋음 0.0001
# 좋은사람과 0.0001
# 국물이진국 0.0001
# 일단한번잡솨봐 0.0001
# 24시간 0.0001
# 흥콥스 0.0001
# 흥크루 0.0001
# 겨울에제맛 0.0001
# 백패커 0.0001
# 캠퍼 0.0001
# backpacking 0.0001
# camper 0.0001
# 홀리차우 0.0001
# 해밀턴호텔 0.0001
# 몽골리안비프 0.0001
# 사천후라이드라이스 0.0001
# 마요쉬림프 0.0001
# 스텔라맥주 0.0001
# 먹스타그램음식들이 0.0001
# 둘째 0.0001
# 7살 0.0001
# 둘째는사랑 0.0001
# 바람이분다당신이좋다 0.0001
# 경리단길회식 0.0001
# 경리단길대관 0.0001
# 장어 0.0001
# 네마리 0.0001
# 으라차차 0.0001
# 둘다싱글 0.0001
# 여친없는건 0.0001
# 흠 0.0001
# 몸보신 0.0001
# 봄시작 0.0001
# 기운아솟아라 0.0001
# 살안쪄그램 0.0001
# 다이어트꺼져 0.0001
# 번데기추가 0.0001
# 또지윤이건뺄까고민했어 0.0001
# 다음코스는 0.0001
# 신세한탄동시에 0.0001
# 술슬해깃원투 0.0001
# 롱아일랜드펍 0.0001
# 이태원소주펍 0.0001
# 칵테일맛집 0.0001
# gentleflowerbyjinie 0.0001
# 재미있게살아보자꾸아침부터 0.0001
# 한단이 0.0001
# 강아지모델 0.0001
# 예쁜강아지 0.0001
# 아이앤투헤어혜린 0.0001
# 미용인 0.0001
# 미용인의일상 0.0001
# ㅋㅋㅋㅋ 0.0001
# 세상의모든맛있는커피 0.0001
# 3초커피 0.0001
# 솔티드캬라멜라떼 0.0001
# 경리단길브런치카페 0.0001
# 거실 0.0001
# 서울골목 0.0001
# canon6d 0.0001
# canonphotography 0.0001
# corea 0.0001
# commonprojects 0.0001
# hm 0.0001
# excelsior 0.0001
# canon100d 0.0001
# 신비디움 0.0001
# 마리포사카네이션 0.0001
# 마리포사 0.0001
# 핑크레이스장미 0.0001
# 델피늄 0.0001
# 아네모네 0.0001
# 폴리유칼립투스 0.0001
# 유칼리툽스 0.0001
# 경리단꽃집 0.0001
# 페데스탈 0.0001
# 상세컷 0.0001
# 감독 0.0001
# 이성찬극장판독립단편영화 0.0001
# 한림제약 0.0001
# 호르반과함께불목 0.0001
# 교대 0.0001
# 노밀가루 0.0001
# 노버터 0.0001
# 일탈 0.0001
# 행복이별건가 0.0001
# 나발롱투어 0.0001
# 레몬마들렌 0.0001
# 다음목표는 0.0001
# 참치맛집 0.0001
# 다요트포기모드 0.0001
# 엥겔지수폭발 0.0001
# 소리가들리는듯 0.0001
# 씐난맛집러 0.0001
# 전갱이 0.0001
# 가리비 0.0001
# 식감최고 0.0001
# 앤드오더 0.0001
# 카페loner주소 0.0001
# 두에꼬제한남 0.0001
# 루꼴라샐러드 0.0001
# 피자도먹었지만 0.0001
# 파스타는다음에 0.0001
# 풀뜯어먹기 0.0001
# 건강해 0.0001
# 살안찐댔어 0.0001
# 맛있게먹으면안찐댔어 0.0001
# 정말이야 0.0001
# 날씨조타 0.0001
# nightinseoul 0.0001
# godbless 0.0001
# nomorestress 0.0001
# peaceful 0.0001
# deliciousdinner 0.0001
# withclosefriends 0.0001
# hadagoodday 0.0001
# 사워도우 0.0001
# 자꾸생각나 0.0001
# camelcafe 0.0001
# 굿나잇 0.0001
# 부산아재어묵부산아재어묵 0.0001
# 겨울엔오뎅 0.0001
# 당근케크왜케마시쪙 0.0001
# 이거실화임 0.0001
# 줄서먹은건안비밀 0.0001
# 발렛비깎은건비밀 0.0001
# 애견동반펍 0.0001
# 남산타워야경 0.0001
# 부모님과함께한저녁 0.0001
# 엄빠대만족 0.0001
# 더백푸드트럭짱 0.0001
# 다음번엔남동생도데리고 0.0001
# 건대카페 0.0001
# 영등포카페 0.0001
# 신도림카페 0.0001
# 혜화카페 0.0001
# 사당카페 0.0001
# 서초카페 0.0001
# 역삼카페 0.0001
# 고추장불백 0.0001
# 커피잔 0.0001
# handpainted 0.0001
# 친구야 0.0001
# 일본식주점 0.0001
# reahersal 0.0001
# tonight8pm 0.0001
# vocal 0.0001
# tonight 0.0001
# contrabass 0.0001
# drum 0.0001
# jazzpiano 0.0001
# saxophone 0.0001
# chuseok 0.0001
# 신나는공연 0.0001
# orientalcuisine 0.0001
# 슬쌤 0.0001
# 직업 0.0001
# 고객을 0.0001
# 팔도여행 0.0001
# 이마트 0.0001
# 등원 0.0001
# 문센룩 0.0001
# 줌바 0.0001
# 방송댄스 0.0001
# 홈쿡스타그램 0.0001
# 전신 0.0001
# henrimatisse 0.0001
# 고민하지마시고 0.0001
# 무조건사세요 0.0001
# 백번사세요 0.0001
# 그냥무조건강추강추 0.0001
# 야근중 0.0001
# 부티아나 0.0001
# 김연아원피스 0.0001
# 자체제작원피스 0.0001
# 상견례룩 0.0001
# 며느리룩 0.0001
# 데일리원피스 0.0001
# 맞춤제작 0.0001
# hello100 0.0001
# 헬로우100 0.0001
# 볼빵빵 0.0001
# 찰칵 0.0001
# 주름살 0.0001
# 펴져라 0.0001
# vip 0.0001
# lastdanceconcert 0.0001
# bigbangconcert 0.0001
# 909토요일 0.0001
# 밀린사진 0.0001
# 대방출 0.0001
# 바질토스트 0.0001
# 노맛 0.0001
# 기대이하 0.0001
# 원본 0.0001
# 동네커피숍 0.0001
# 경리단길조식 0.0001
# 코디youtube韓 0.0001
# 사첼백 0.0001
# 입생로랑체인백 0.0001
# 로렉스콤비 0.0001
# 포항 0.0001
# 조가비마켓 0.0001
# 스코프 0.0001
# 부암동 0.0001
# unity 0.0001
# 2017파이팅 0.0001
# 소갈비살 0.0001
# 오삼겹 0.0001
# タッカンマリ 0.0001
# ピョダギカムジャタン 0.0001
# 뼈다귀감자탕 0.0001
# 닭한마리 0.0001
# 새벽에 0.0001
# 24시간영업 0.0001
# 좋다그램 0.0001
# 짱맛있습니다 0.0001
# cotejardin 0.0001
# 수맛서 0.0001
# 수맛서추천맛집 0.0001
# 수맛서한남 0.0001
# 수맛서이태원 0.0001
# happyhappyday목요일 0.0001
# 스노우캠 0.0001
# together 0.0001
# 심형준 0.0001
# 중국음식 0.0001
# 비오는저녁 0.0001
# college 0.0001
# 인스타충 0.0001
# 좋은글귀 0.0001
# 드라이허브 0.0001
# samson 0.0001
# 다시다난 0.0001
# floristry 0.0001
# 잠 0.0001
# sleepy 0.0001
# 유유 0.0001
# 잠스타그램 0.0001
# 낼 0.0001
# 교육 0.0001
# 20170625밥통아 0.0001
# 밥통 0.0001
# 밥솥 0.0001
# 락커룸서울 0.0001
# 정석 0.0001
# 그냥 0.0001
# 꼴딱꼴딱 0.0001
# 고생해준 0.0001
# 진태몬 0.0001
# 백그라운드에서 0.0001
# 또봐도재밌숴 0.0001
# 참으로완벽했던하루 0.0001
# 지여니의생선 0.0001
# 런치타임 0.0001
# 한남도맛집경리단맛집 0.0001
# 꽈리타임 0.0001
# 꽈리피플 0.0001
# 탁상라디오 0.0001
# 1980음악 0.0001
# 체험 0.0001
# 사이즈 0.0001
# 살빼자 0.0001
# 카카오프렌즈 0.0001
# 하이리 0.0001
# haili 0.0001
# 한달째연휴 0.0001
# 하얏트맛집 0.0001
# portraitsession 0.0001
# seoulart 0.0001
# portraitdrawing 0.0001
# bnhrここも行ってきた 0.0001
# がりたい좋아요 0.0001
# 꽃꽂이 0.0001
# 킹스맨2 0.0001
# uppjt 0.0001
# universe 0.0001
# project 0.0001
# ale 0.0001
# 명란마요차슈덮밥 0.0001
# 한남동푸드코트 0.0001
# 한남오거리셀렉다이닝 0.0001
# 한남오거리푸드코트 0.0001
# 손사장이사장 0.0001
# 같이부자되자 0.0001
# longboarder 0.0001
# 롱보드 0.0001
# 레리 0.0001
# 댄싱 0.0001
# 할렘 0.0001
# 서타이거 0.0001
# 건강맛 0.0001
# greenday 0.0001
# 치읓카페 0.0001
# 잘생긴각 0.0001
# 멋짐각 0.0001
# 너무예쁜카페 0.0001
# 이태원몽상클레르 0.0001
# 케이크맛있다 0.0001
# 예쁜디저트 0.0001
# 예쁜케이크 0.0001
# 이쁘다그램 0.0001
# 작년가을 0.0001
# 잠수교분수 0.0001
# 하늘높은건매년가을똑같지만 0.0001
# 매번감탄스럽네요 0.0001
# 비쥬얼쇼크 0.0001
# 회나무로길 0.0001
# 92카페구이 0.0001
# 심방 0.0001
# 식탁교제 0.0001
# hogukitchen 0.0001
# 호구식당 0.0001
# 토마토치즈피자 0.0001
# 눈물나게맛있다 0.0001
# summerlatte 0.0001
# 감성펍 0.0001
# 모나리자 0.0001
# mo0lisa 0.0001
# 피맥오랜만에 0.0001
# 송림식당 0.0001
# 닭도리탕 0.0001
# 저녁에도 0.0001
# pancake 0.0001
# waffle 0.0001
# pancakestory 0.0001
# pancakestagram 0.0001
# 팬케익스토리 0.0001
# パンケ 0.0001
# ド 0.0001
# イテウォングルメ 0.0001
# 출근죽을맛 0.0001
# 도너츠라떼 0.0001
# 도너츠커피 0.0001
# 도넛음료 0.0001
# donutlatte 0.0001

# %%
vocab_size = len(word_to_index) + 1
print('단어 집합의 크기: {}'.format((vocab_size)))
# Out:
# 단어 집합의 크기: 20568

# %%
print('피드의 최대 길이 : %d' % max(len(sample) for sample in X_train_encoded))
print('피드의 평균 길이 : %f' % (sum(map(len, X_train_encoded))/len(X_train_encoded)))
# Out:
# 피드의 최대 길이 : 83
# 피드의 평균 길이 : 14.030182

# %%
max_len = 453
X_train_padded = pad_sequences(X_train_encoded, maxlen = max_len)
X_test_padded  = pad_sequences(X_test_encoded, maxlen=max_len)
print("훈련 데이터의 크기(shape):", X_train_padded.shape)
# Out:
# 훈련 데이터의 크기(shape): (7256, 453)

# %% [markdown]
# # RNN

# %%
from keras import backend as K

def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall


def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision


def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
from tensorflow.keras.layers import SimpleRNN, Embedding, Dense
from tensorflow.keras.models import Sequential

embedding_dim = 128
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(SimpleRNN(hidden_units))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy', precision, recall, f1score])
history = model.fit(X_train_padded, y_train, epochs=5 ,batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/5
# 80/80 [==============================] - 11s 129ms/step - loss: 0.6402 - accuracy: 0.6342 - precision: 0.7421 - recall: 0.7301 - f1score: 0.6608 - val_loss: 0.5510 - val_accuracy: 0.7042 - val_precision: 0.6907 - val_recall: 0.9887 - val_f1score: 0.8101
# Epoch 2/5
# 80/80 [==============================] - 10s 125ms/step - loss: 0.3783 - accuracy: 0.8454 - precision: 0.8349 - recall: 0.9576 - f1score: 0.8892 - val_loss: 0.3996 - val_accuracy: 0.8374 - val_precision: 0.8488 - val_recall: 0.9106 - val_f1score: 0.8771
# Epoch 3/5
# 80/80 [==============================] - 10s 122ms/step - loss: 0.2443 - accuracy: 0.9084 - precision: 0.9131 - recall: 0.9536 - f1score: 0.9306 - val_loss: 0.5199 - val_accuracy: 0.7717 - val_precision: 0.7427 - val_recall: 0.9911 - val_f1score: 0.8470
# Epoch 4/5
# 80/80 [==============================] - 10s 124ms/step - loss: 0.1662 - accuracy: 0.9407 - precision: 0.9404 - recall: 0.9699 - f1score: 0.9541 - val_loss: 0.4291 - val_accuracy: 0.8264 - val_precision: 0.8940 - val_recall: 0.8266 - val_f1score: 0.8576
# Epoch 5/5
# 80/80 [==============================] - 10s 123ms/step - loss: 0.1225 - accuracy: 0.9571 - precision: 0.9611 - recall: 0.9740 - f1score: 0.9667 - val_loss: 0.4413 - val_accuracy: 0.8199 - val_precision: 0.8412 - val_recall: 0.8882 - val_f1score: 0.8628

# %%
X_test_encoded = tokenizer.texts_to_sequences(X_test)
X_test_padded = pad_sequences(X_test_encoded, maxlen = max_len)
print("\n 테스트 정확도: %.4f" % (model.evaluate(X_test_padded, y_test)[1]))
# Out:
# 98/98 [==============================] - 2s 24ms/step - loss: 0.3996 - accuracy: 0.8537 - precision: 0.8595 - recall: 0.9207 - f1score: 0.8868
#
#  테스트 정확도: 0.8537

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Embedding

# 모델 구축
# 레이어들을 쌓을 모델을 생성
model = Sequential()
model.add(Embedding(45000, 160))
model.add(LSTM(160))
model.add(Dense(1, activation='sigmoid'))

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 테스트 데이터 손실함수값(val_loss)이 patience회 이상 연속 증가하면 학습을 조기 종료하는 콜백
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
# 훈련 도중 테스트 데이터 정확도(val_acc)가 높았던 순간을 체크포인트로 저장해 활용하는 콜백
model_check = ModelCheckpoint('the_best.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall, f1score])
model.fit(X_train_padded, y_train, validation_split=0.3  ,epochs=4, batch_size=64, callbacks=[early_stop, model_check])
# Out:
# Epoch 1/4
# 80/80 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7716 - precision: 0.7700 - recall: 0.9437 - f1score: 0.8365WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 130s 2s/step - loss: 0.4907 - accuracy: 0.7716 - precision: 0.7700 - recall: 0.9437 - f1score: 0.8365 - val_loss: 0.3817 - val_accuracy: 0.8484 - val_precision: 0.8696 - val_recall: 0.8982 - val_f1score: 0.8826
# Epoch 2/4
# 80/80 [==============================] - ETA: 0s - loss: 0.2207 - accuracy: 0.9205 - precision: 0.9239 - recall: 0.9580 - f1score: 0.9397WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 130s 2s/step - loss: 0.2207 - accuracy: 0.9205 - precision: 0.9239 - recall: 0.9580 - f1score: 0.9397 - val_loss: 0.3554 - val_accuracy: 0.8700 - val_precision: 0.8775 - val_recall: 0.9279 - val_f1score: 0.9011
# Epoch 3/4
# 80/80 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9646 - precision: 0.9699 - recall: 0.9758 - f1score: 0.9725WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 135s 2s/step - loss: 0.1037 - accuracy: 0.9646 - precision: 0.9699 - recall: 0.9758 - f1score: 0.9725 - val_loss: 0.3893 - val_accuracy: 0.8461 - val_precision: 0.8706 - val_recall: 0.8928 - val_f1score: 0.8807
# Epoch 4/4
# 80/80 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9805 - precision: 0.9834 - recall: 0.9868 - f1score: 0.9849WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 134s 2s/step - loss: 0.0621 - accuracy: 0.9805 - precision: 0.9834 - recall: 0.9868 - f1score: 0.9849 - val_loss: 0.4512 - val_accuracy: 0.8535 - val_precision: 0.8619 - val_recall: 0.9184 - val_f1score: 0.8885

# %%
print(model.evaluate(X_test_padded, y_test))
# Out:
# 98/98 [==============================] - 21s 216ms/step - loss: 0.4108 - accuracy: 0.8842 - precision: 0.8930 - recall: 0.9285 - f1score: 0.9086
# [0.4108043313026428, 0.8842443823814392, 0.8929822444915771, 0.9284731149673462, 0.9086498618125916]

# %%
model = Sequential()
model.add(Embedding(45000, 150))
model.add(LSTM(150))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(2, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy', precision, recall, f1score])
model.fit(X_train_padded, y_train, validation_split=0.3  ,epochs=5, batch_size=64, callbacks=[early_stop, model_check])
# Out:
# Epoch 1/5
# 80/80 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.7582 - precision: 0.6480 - recall: 1.0000 - f1score: 0.7851WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 63s 773ms/step - loss: 0.4968 - accuracy: 0.7582 - precision: 0.6480 - recall: 1.0000 - f1score: 0.7851 - val_loss: 0.3692 - val_accuracy: 0.8484 - val_precision: 0.6379 - val_recall: 1.0000 - val_f1score: 0.7748
# Epoch 2/5
# 80/80 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9273 - precision: 0.6483 - recall: 1.0000 - f1score: 0.7845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 64s 796ms/step - loss: 0.2013 - accuracy: 0.9273 - precision: 0.6483 - recall: 1.0000 - f1score: 0.7845 - val_loss: 0.3661 - val_accuracy: 0.8558 - val_precision: 0.6379 - val_recall: 1.0000 - val_f1score: 0.7748
# Epoch 3/5
# 80/80 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9720 - precision: 0.6476 - recall: 1.0000 - f1score: 0.7842WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 64s 798ms/step - loss: 0.0829 - accuracy: 0.9720 - precision: 0.6476 - recall: 1.0000 - f1score: 0.7842 - val_loss: 0.3966 - val_accuracy: 0.8535 - val_precision: 0.6379 - val_recall: 1.0000 - val_f1score: 0.7748
# Epoch 4/5
# 80/80 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9854 - precision: 0.6480 - recall: 1.0000 - f1score: 0.7843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 64s 806ms/step - loss: 0.0489 - accuracy: 0.9854 - precision: 0.6480 - recall: 1.0000 - f1score: 0.7843 - val_loss: 0.4412 - val_accuracy: 0.8443 - val_precision: 0.6379 - val_recall: 1.0000 - val_f1score: 0.7748
# Epoch 5/5
# 80/80 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9882 - precision: 0.6473 - recall: 1.0000 - f1score: 0.7843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 80/80 [==============================] - 65s 815ms/step - loss: 0.0351 - accuracy: 0.9882 - precision: 0.6473 - recall: 1.0000 - f1score: 0.7843 - val_loss: 0.5330 - val_accuracy: 0.8608 - val_precision: 0.6379 - val_recall: 1.0000 - val_f1score: 0.7748

# %%
print(model.evaluate(X_test_padded, y_test))
# Out:
# 98/98 [==============================] - 9s 92ms/step - loss: 0.5126 - accuracy: 0.8752 - precision: 0.6389 - recall: 1.0000 - f1score: 0.7757
# [0.5126271843910217, 0.8752411603927612, 0.6389243006706238, 1.0, 0.7757214903831482]

# %% [markdown]
# # 나이브베이즈

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB # 다항분포 나이브 베이즈 모델
from sklearn.metrics import accuracy_score #정확도 계산

# %%
dtmvector = CountVectorizer()
X_train_dtm = dtmvector.fit_transform(X_train)
print(X_train_dtm.shape)
# Out:
# (7256, 20363)

# %%
tfidf_transformer = TfidfTransformer()
tfidfv = tfidf_transformer.fit_transform(X_train_dtm)
print(tfidfv.shape)
# Out:
# (7256, 20363)

# %%
mod = MultinomialNB()
mod.fit(tfidfv, y_train)
# Out:
# MultinomialNB()

# %%
MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Out:
# MultinomialNB()

# %%
X_test_dtm = dtmvector.transform(X_test) #테스트 데이터를 DTM으로 변환
tfidfv_test = tfidf_transformer.transform(X_test_dtm) #DTM을 TF-IDF 행렬로 변환

predicted = mod.predict(tfidfv_test) #테스트 데이터에 대한 예측
print("정확도:", classification_report(y_test, predicted)) #예측값과 실제값 비교
# Out:
# 정확도:               precision    recall  f1-score   support
#
#            0       0.93      0.59      0.72      1115
#            1       0.81      0.97      0.88      1995
#
#     accuracy                           0.83      3110
#    macro avg       0.87      0.78      0.80      3110
# weighted avg       0.85      0.83      0.82      3110

# %% [markdown]
# # logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
lr.fit(X_train_dtm,y_train)
pred_Y = lr.predict(X_test_dtm)
print(classification_report(y_test, pred_Y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82      1115
#            1       0.89      0.92      0.90      1995
#
#     accuracy                           0.88      3110
#    macro avg       0.87      0.86      0.86      3110
# weighted avg       0.87      0.88      0.87      3110

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
RF_clf = clf.fit(X_train_padded, y_train)
RF_pred = RF_clf.predict(X_test_padded)
RF_pred
print(classification_report(y_test, RF_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.58      0.70      1115
#            1       0.80      0.95      0.87      1995
#
#     accuracy                           0.82      3110
#    macro avg       0.84      0.77      0.78      3110
# weighted avg       0.83      0.82      0.81      3110

# %% [markdown]
# # ELMo --> colab에서 실행

# %% [markdown]
# %tensorflow_version 1.x

# %% [markdown]
# pip install tensorflow-hub

# %% [markdown]
# import tensorflow_hub as hub
# import tensorflow as tf
# from keras import backend as K
# import urllib.request
# import pandas as pd
# import numpy as np

# %% [markdown]
# elmo = hub.Module("https://tfhub.dev/google/elmo/1", trainable=True)
#  텐서플로우 허브로부터 ELMo를 다운로드
#
# sess = tf.Session()
# K.set_session(sess)
# sess.run(tf.global_variables_initializer())
# sess.run(tf.tables_initializer())

# %% [markdown]
# from sklearn.model_selection import train_test_split
# X = data["word"]
# y = data["type"]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 123,stratify=y)

# %% [markdown]
# def ELMoEmbedding(x):
#     return elmo(tf.squeeze(tf.cast(x, tf.string)), as_dict=True, signature="default")["default"]

# %% [markdown]
# from keras.models import Model
# from keras.layers import Dense, Lambda, Input
#
# input_text = Input(shape=(1,), dtype=tf.string)
# embedding_layer = Lambda(ELMoEmbedding, output_shape=(1024, ))(input_text)
# hidden_layer = Dense(256, activation='relu')(embedding_layer)
# output_layer = Dense(1, activation='sigmoid')(hidden_layer)
# model = Model(inputs=[input_text], outputs=output_layer)
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# history = model.fit(X_train, y_train, epochs=4, batch_size=60)

# %% [markdown]
# print("\n 테스트 정확도: %.4f" % (model.evaluate(X_test, y_test)[1]))

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix


def SVM(X_train, X_test, y_train, y_test):
    svm = SVC()
    svm.fit(X_train, y_train)
    pred_y = svm.predict(X_test)
    return pred_y

pred_y = SVM(X_train_padded, X_test_padded, y_train, y_test)

# SVM 분류 결과값을 출력합니다.
print("\nConfusion matrix : \n", confusion_matrix(y_test, pred_y))
print("\nReport : \n", classification_report(y_test, pred_y))
# Out:
# Confusion matrix :
#  [[ 113 1002]
#  [  37 1958]]
#
# Report :
#                precision    recall  f1-score   support
#
#            0       0.75      0.10      0.18      1115
#            1       0.66      0.98      0.79      1995
#
#     accuracy                           0.67      3110
#    macro avg       0.71      0.54      0.48      3110
# weighted avg       0.69      0.67      0.57      3110

# %%
pred_y = SVM(tfidfv, tfidfv_test, y_train, y_test)

# SVM 분류 결과값을 출력합니다.
print("\nConfusion matrix : \n", confusion_matrix(y_test, pred_y))
print("\nReport : \n", classification_report(y_test, pred_y))
# Out:
# Confusion matrix :
#  [[ 829  286]
#  [  92 1903]]
#
# Report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81      1115
#            1       0.87      0.95      0.91      1995
#
#     accuracy                           0.88      3110
#    macro avg       0.88      0.85      0.86      3110
# weighted avg       0.88      0.88      0.88      3110

# %%
import sklearn.svm as svm
import sklearn.metrics as mt
from sklearn.model_selection import cross_val_score, cross_validate

# %%
from gensim.models import Word2Vec
# Skip-gram (sg=1)
w2v_skip_gram = Word2Vec(X_train, vector_size=100, window=10, min_count=10, workers=4, sg=1)
# CBOW (sg=0)
w2v_CBOW = Word2Vec(X_train, vector_size=100, window=10, min_count=10, workers=4, sg=0)

# size : 한 단어당 몇 차원의 벡터로 만들지
# window : 앞뒤 몇개의 단어를 사용할지
# min_count : 최소 등장 횟수(min_count이하인 단어는 제외)
# sg : CBOW(=0)로 할지 skip-gram(=1)으로 할지

# %%
w2v_skip_gram.wv.vectors.shape
# Out:
# (904, 100)

# %%
w2v_CBOW.wv.vectors.shape
# Out:
# (904, 100)

# %%
# Text embedding 하기
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
import numpy as np

# %%
# 문서 embedding
class TfidfEmbeddingVectorizer:
    def __init__(self, word2vec):
        self.word2vec = word2vec

    def transform(self, X):
        tfidf = TfidfVectorizer(analyzer = lambda x : x) 
        tfidf.fit(X)
        max_idf = max(tfidf.idf_) 
        word2weight = defaultdict(lambda : max_idf, [(w, tfidf.idf_[i]) for w, i in tfidf.vocabulary_.items()]) 

        array_list =[]
        for words in X:
            array_list.append(np.array(np.mean([self.word2vec[w]*word2weight[w] for w in words if w in self.word2vec] or [np.zeros(100)], axis = 0)))
        return(array_list)

vec_tf_skip_gram = TfidfEmbeddingVectorizer(w2v_skip_gram)
vec_tf_CBOW = TfidfEmbeddingVectorizer(w2v_CBOW)

# %%
# skip-gram
train_tf_s = vec_tf_skip_gram.transform(X_train)
test_tf_s = vec_tf_skip_gram.transform(X_test)
# CBOW
train_tf_c = vec_tf_CBOW.transform(X_train)
test_tf_c = vec_tf_CBOW.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24728/1921036367.py in <module>
#       1 # skip-gram
# ----> 2 train_tf_s = vec_tf_skip_gram.transform(X_train)
#       3 test_tf_s = vec_tf_skip_gram.transform(X_test)
#       4 # CBOW
#       5 train_tf_c = vec_tf_CBOW.transform(X_train)
#
# ~\AppData\Local\Temp/ipykernel_24728/4181938833.py in transform(self, X)
#      12         array_list =[]
#      13         for words in X:
# ---> 14             array_list.append(np.array(np.mean([self.word2vec[w]*word2weight[w] for w in words if w in self.word2vec] or [np.zeros(100)], axis = 0)))
#      15         return(array_list)
#      16
#
# ~\AppData\Local\Temp/ipykernel_24728/4181938833.py in <listcomp>(.0)
#      12         array_list =[]
#      13         for words in X:
# ---> 14             array_list.append(np.array(np.mean([self.word2vec[w]*word2weight[w] for w in words if w in self.word2vec] or [np.zeros(100)], axis = 0)))
#      15         return(array_list)
#      16
#
# TypeError: argument of type 'Word2Vec' is not iterable

# %%
# Support Vector Machine
from sklearn.svm import SVC
clf = SVC(decision_function_shape='ovo') # SVM 만들기
svc_clf_s = clf.fit(train_tf_s, label_train)  # skip-gram
svc_clf_c = clf.fit(train_tf_c, label_train)  # CBOW

# 예측값 뽑아내기
svc_pred_s = svc_clf.predict(test_tf_s) # skip-gram
svc_pred_c = svc_clf.predict(test_tf_c) # CBOW

# 정확도 확인
from sklearn import metrics
print(classification_report(label_test, svc_pred_s)) # skip-gram
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24728/3909310199.py in <module>
#       2 from sklearn.svm import SVC
#       3 clf = SVC(decision_function_shape='ovo') # SVM 만들기
# ----> 4 svc_clf_s = clf.fit(train_tf_s, label_train)  # skip-gram
#       5 svc_clf_c = clf.fit(train_tf_c, label_train)  # CBOW
#       6
#
# NameError: name 'train_tf_s' is not defined

# %%
#Load the word2vec model
word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)

word_index = tokenizer.word_index
nb_words = min(MAX_NB_WORDS, len(word_index))+1

embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
null_words = []
for word, i in word_index.items():
    if word in word2vec.wv.vocab:
        embedding_matrix[i] = word2vec.word_vec(word)
    else:
        null_words.append(word)

embedding_layer = Embedding(embedding_matrix.shape[0], # or len(word_index) + 1
                            embedding_matrix.shape[1], # or EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=701,
                            trainable=False)

model = Sequential()
model.add(embedding_layer)
model.add(LSTM(100))
model.add(Dropout(0.4))
model.add(Dense(2, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24728/3817169549.py in <module>
#       1 #Load the word2vec model
# ----> 2 word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)
#       3
#       4 word_index = tokenizer.word_index
#       5 nb_words = min(MAX_NB_WORDS, len(word_index))+1
#
# NameError: name 'KeyedVectors' is not defined
