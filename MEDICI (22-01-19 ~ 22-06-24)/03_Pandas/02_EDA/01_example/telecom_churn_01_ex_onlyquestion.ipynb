# %% [markdown]
# ### telecom_churn.csv 파일 분석

# %% [markdown]
# * 01) numpy / pandas 불러 들이기

# %% [markdown]
# * telecom_churn.csv 파일 불러오기

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * data의 모양 확인하기!

# %%
# Out:
# (3333, 20)

# %% [markdown]
# * data의 컬럼 이름들 확인하기

# %%
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# * data의 기본적인 정보 확인하기

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %% [markdown]
# * Churn의 컬럼의 타입을 int64로 변경하기!!

# %% [markdown]
# * data의 전반적인 사항을 describe 해보기!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
#       <th>Customer service calls</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# * 참고) describe의 경우에는 기본적인 수치 데이터로만 수행, 그 외에 타입에 대해서 할 때 아래와 같이..

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3333</td>
#       <td>3333</td>
#       <td>3333</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>51</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>WV</td>
#       <td>No</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>106</td>
#       <td>3010</td>
#       <td>2411</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * churn의 값의 종류 및 그 값들이 몇 개가 있는지 확인

# %%
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %% [markdown]
# churn의 값의 종류 및 그 값들이 몇 개가 있는지 확인(비율로 표시!)

# %%
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %% [markdown]
# * 정렬 : Total day charge 의 컬럼을 기준으로 정리!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * 정렬 : Churn, Total day Charge를 기준으로 정렬을 하는데, Churn의 경우에는 오름차순, taotal dat charge는 내림차순으로..

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * churn=1 사용자의 비율을 계산하시오!!

# %%
# Out:
# 0.14491449144914492

# %% [markdown]
# * churn=1 사용자 중에서 수치적인 데이터 값들 모두에 대한 평균값을 확인하시오!

# %%
df[]
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %% [markdown]
# * churn 사용자 중에서 하루 사용 시간에 대한 평균값은 얼마인가?

# %%
# Out:
# 206.91407867494814

# %% [markdown]
# * churn 사용하지 않는 사용자 중에서 가장 긴 국제통화시간은 얼마인가?

# %%
# Out:
# 18.9

# %% [markdown]
# * 아래와 같은 그래프를 생성하시오!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>OH</td>
#       <td>107</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NJ</td>
#       <td>137</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OH</td>
#       <td>84</td>
#       <td>408</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>OK</td>
#       <td>75</td>
#       <td>415</td>
# ...

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>OH</td>
#       <td>107</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NJ</td>
#       <td>137</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OH</td>
#       <td>84</td>
#       <td>408</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>OK</td>
#       <td>75</td>
#       <td>415</td>
# ...

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>OH</td>
#       <td>107</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NJ</td>
#       <td>137</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OH</td>
#       <td>84</td>
#       <td>408</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>OK</td>
#       <td>75</td>
#       <td>415</td>
# ...

# %% [markdown]
# * data의 맨 앞줄, 맨 뒤의 줄을 각기 나타내시오!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * 모든 컬럼에서 최고값을 찾아보시오!!!

# %%
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %% [markdown]
# * State의 값 중에서 처음 시작 문자가 W인 것들을 추려서 head로 앞의 데이터만 확인하기!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * International Plan의 값을 확인을 해보니 No/ Yes로 되어 있음. 이러한 것은 앞으로 데이터 처리하기에 불편한 부분이 있기에 No는 False, Yes는 True 인 불리언 값들로 변경!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * 위의 작업을 Voice Mail Plan 컬럼에도 적용해보자!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * 우선 보고 싶은 컬럼들을 추려서(Total data minutes, Total eve minutes, Total night minutes), 이것들을 Churn의 값을 기준으로 기본적인 정보들(describe)을 보자!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="6" halign="left">Total day minutes</th>
#       <th colspan="6" halign="left">Total eve minutes</th>
#       <th colspan="6" halign="left">Total night minutes</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>50%</th>
#       <th>max</th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>50%</th>
#       <th>max</th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
# ...

# %% [markdown]
# * 우선 보고 싶은 컬럼들을 추려서(Total data minutes, Total eve minutes, Total night minutes), 이것들을 Churn의 값을 기준으로 평균/표준편차/최소값/최대값만 보자!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">Total day minutes</th>
#       <th colspan="4" halign="left">Total eve minutes</th>
#       <th colspan="4" halign="left">Total night minutes</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>mean</th>
#       <th>std</th>
#       <th>amin</th>
#       <th>amax</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>amin</th>
#       <th>amax</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>amin</th>
#       <th>amax</th>
#     </tr>
#     <tr>
#       <th>Churn</th>
#       <th></th>
#       <th></th>
# ...

# %% [markdown]
# * 요약 테이블 생성 : churn의 사용여부와 international plan의 crosstab 생성

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>International plan</th>
#       <th>False</th>
#       <th>True</th>
#     </tr>
#     <tr>
#       <th>Churn</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2664</td>
#       <td>186</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>346</td>
#       <td>137</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 요약 테이블 생성 : churn의 사용여부와 international plan의 crosstab 생성( 수가 아니라 비율로 생성)

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Voice mail plan</th>
#       <th>False</th>
#       <th>True</th>
#     </tr>
#     <tr>
#       <th>Churn</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.602460</td>
#       <td>0.252625</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.120912</td>
#       <td>0.024002</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 아래와 같은 테이블을 pivot_table을 이용해서 생성하시오, 칸은 평균으로 채울 것!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total day calls</th>
#       <th>Total eve calls</th>
#       <th>Total night calls</th>
#     </tr>
#     <tr>
#       <th>Area code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>408</th>
#       <td>100.496420</td>
#       <td>99.788783</td>
#       <td>99.039379</td>
#     </tr>
#     <tr>
#       <th>415</th>
#       <td>100.576435</td>
#       <td>100.503927</td>
#       <td>100.398187</td>
#     </tr>
#     <tr>
#       <th>510</th>
#       <td>100.097619</td>
#       <td>99.671429</td>
#       <td>100.601190</td>
#     </tr>
# ...

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total day calls</th>
#       <th>Total eve calls</th>
#       <th>Total night calls</th>
#     </tr>
#     <tr>
#       <th>Area code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>408</th>
#       <td>100.496420</td>
#       <td>99.788783</td>
#       <td>99.039379</td>
#     </tr>
#     <tr>
#       <th>415</th>
#       <td>100.576435</td>
#       <td>100.503927</td>
#       <td>100.398187</td>
#     </tr>
#     <tr>
#       <th>510</th>
#       <td>100.097619</td>
#       <td>99.671429</td>
#       <td>100.601190</td>
#     </tr>
# ...

# %% [markdown]
# * total_calls 에는 total day/eve/noght/intl calls을 정리하고, 원본 데이터에다가 total_calls의 값을 추가하시오!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>...</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * 위와 비슷한 기능인데, 좀 더 단순하게 Total Charge라는 컬럼으로 생성하시오!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>...</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
#       <th>Customer service calls</th>
#       <th>Churn</th>
# ...

# %% [markdown]
# * 방금 위에서 생성한 2개의 컬름 total charge, total calls 의 컬럼을 제거하시오!!!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Account length</th>
#       <th>Area code</th>
#       <th>International plan</th>
#       <th>Voice mail plan</th>
#       <th>Number vmail messages</th>
#       <th>Total day minutes</th>
#       <th>Total day calls</th>
#       <th>Total day charge</th>
#       <th>Total eve minutes</th>
#       <th>Total eve calls</th>
#       <th>Total eve charge</th>
#       <th>Total night minutes</th>
#       <th>Total night calls</th>
#       <th>Total night charge</th>
#       <th>Total intl minutes</th>
#       <th>Total intl calls</th>
#       <th>Total intl charge</th>
# ...

# %% [markdown]
# * Churn의 사용여부와 International Plan 의 crosstab을 생성하고, 각 끝에 총합을 나타낼 수 있도록 하시오!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>International plan</th>
#       <th>False</th>
#       <th>True</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Churn</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2664</td>
#       <td>186</td>
#       <td>2850</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>346</td>
#       <td>137</td>
#       <td>483</td>
#     </tr>
#     <tr>
#       <th>All</th>
#       <td>3010</td>
#       <td>323</td>
#       <td>3333</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 그래프 그릴 준비 : matplotlib/ seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 아래와 같은 그래프를 그리시오. sns에서의 countplot 임!!!

# %% [markdown]
# * churn와 Customer service calls에 관련된 crsootab과 총합을 표로 나타내시오!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Customer service calls</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Churn</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>605</td>
#       <td>1059</td>
#       <td>672</td>
#       <td>385</td>
# ...

# %% [markdown]
# * 아래 그래프와 같은 것을 만드시오. sns의 countplot 활용ㅡ

# %% [markdown]
# * Many Service Calls 라는 컬럼을 만들고 나서, 이 컬럼에는 Customer service calls의 값이 3 초과인 값들을 가지고 처리.  그리고 Many Service calls 라는 값과 churn의 값을 비교하는 crosstab을 만들기!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Churn</th>
#       <th>0</th>
#       <th>1</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Many_service_calls</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2721</td>
#       <td>345</td>
#       <td>3066</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>129</td>
#       <td>138</td>
#       <td>267</td>
#     </tr>
#     <tr>
#       <th>All</th>
#       <td>2850</td>
#       <td>483</td>
#       <td>3333</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# * 위의 표를 그래프로 나타내시오!!

# %% [markdown]
# * many_service_calls와 internaional plan이 모두 만족하는 사람들에 대한 여부와 churn의 관게의 crosstab을 만드시오!!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Churn</th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#     <tr>
#       <th>row_0</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2841</td>
#       <td>464</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>9</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# </div>
