# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from matplotlib import rc

rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Password:
# sudo: a password is required
# Password:
# sudo: a password is required
# rm: /Users/yeonji/.cache/matplotlib: No such file or directory
# rm: -rf: No such file or directory

# %%
demo_df = pd.read_csv("LPOINT_BIG_COMP_01_DEMO.csv")
pdde_df = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv")
cop_df = pd.read_csv("LPOINT_BIG_COMP_03_COP_U.csv")
pd_df = pd.read_csv("LPOINT_BIG_COMP_04_PD_CLAC.csv")
br_df = pd.read_csv("LPOINT_BIG_COMP_05_BR.csv")
lpay_df = pd.read_csv("LPOINT_BIG_COMP_06_LPAY.csv")
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/4235936177.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   pdde_df = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv")

# %%
cus_join = pd.merge(demo_df,pdde_df, on="cust", how='inner')
cus_join
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000034966        여성  40대     Z07  A01016688590        1   A01
# 3        M000034966        여성  40대     Z07  A01016718167        1   A01
# 4        M000034966        여성  40대     Z07  A02357398521        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M999962961        여성  50대     Z17  A05001012161        1   A05
# 4381739  M999962961        여성  50대     Z17  E06002810292        2   A06
# 4381740  M999962961        여성  50대     Z17  E06004609359        2   A06
# 4381741  M999962961        여성  50대     Z17  E06025413888        2   A06
# 4381742  M999962961        여성  50대     Z17  E06035713248        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct
# ...

# %%
cus_merge = pd.merge(cus_join,pd_df, on ='pd_c', how='inner' )
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
cus_merge = pd.merge(cus_join,pd_df, on ='pd_c', how='inner' )
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
cus_304050 = cus_merge.loc[((cus_merge['ages'] == '30대') | (cus_merge['ages'] == '40대')| (cus_merge['ages'] == '50대')) & ((cus_merge['cop_c'] == 'A01') |  (cus_merge['cop_c'] == 'A06')) , : ]
cus_304050
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 6        M000508243        여성  50대     Z17  A01417352264        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381733  M762888764        여성  30대     Z11  E06033428238        2   A06
# 4381735  M897387507        남성  40대     Z07  E06015295559        2   A06
# 4381736  M802756595        남성  40대     Z17  E06006556124        2   A06
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
index1 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '냉장식품') | (cus_304050['clac_hlv_nm'] == '유제품') | (cus_304050['clac_hlv_nm'] == '테넌트/음식점'), : ].index
cus_304050.drop(index1, axis=0, inplace = True)
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/1102098678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_304050.drop(index1, axis=0, inplace = True)

# %%
index2 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '건해산물') & ((cus_304050['pd_nm'] != '김선물세트') | (cus_304050['pd_nm'] != '멸치선물세트') | (cus_304050['pd_nm'] != '굴비선물세트') | (cus_304050['pd_nm'] != '기타건해산물선물세트')) , : ].index
index3 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '채소') & ((cus_304050['pd_nm'] != '혼합채소선물세트') | (cus_304050['pd_nm'] != '버섯선물세트') | (cus_304050['pd_nm'] != '기타한방약재') | (cus_304050['pd_nm'] != '수삼선물세트') | (cus_304050['pd_nm'] != '약용버섯류') | (cus_304050['pd_nm'] != '인삼류')) , : ].index
index4 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '조미료') & ((cus_304050['pd_nm'] != '조미료세트') | (cus_304050['pd_nm'] != '조미혼합세트') | (cus_304050['pd_nm'] != '식용유세트')) , : ].index
index5 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '양곡') & (cus_304050['pd_nm'] != '곡물선물세트') , : ].index
index6 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '병통조림') & ((cus_304050['pd_nm'] != '통조림혼합세트') | (cus_304050['pd_nm'] != '참치통조림세트') ) , : ].index
index7 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '조리식품') & ((cus_304050['pd_nm'] != '케이크') | (cus_304050['pd_nm'] != '롤') | (cus_304050['pd_nm'] != '선물류') | (cus_304050['pd_nm'] != '일반떡') | (cus_304050['pd_nm'] != '치킨류') | (cus_304050['pd_nm'] != '도넛')| (cus_304050['pd_nm'] != '피자')) , : ].index
index8 = cus_304050.loc[(cus_304050['clac_hlv_nm'] == '수산물') & ((cus_304050['pd_nm'] != '생선선물세트') | (cus_304050['pd_nm'] != '해물선물세트') | (cus_304050['pd_nm'] != '혼합수산선물세트') ) , : ].index

# %%
cus_304050.drop(index2, axis=0, inplace=True)
cus_304050.drop(index3, axis=0, inplace=True)
cus_304050.drop(index4, axis=0, inplace=True)
cus_304050.drop(index5, axis=0, inplace=True)
cus_304050.drop(index6, axis=0, inplace=True)
cus_304050.drop(index7, axis=0, inplace=True)
cus_304050.drop(index8, axis=0, inplace=True)
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/2757362765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_304050.drop(index2, axis=0, inplace=True)
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/2757362765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_304050.drop(index3, axis=0, inplace=True)
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/2757362765.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from datetime import datetime, date
cus_304050['de_dt'] = pd.to_datetime(cus_304050['de_dt'],format='%Y%m%d')
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/16302932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_304050['de_dt'] = pd.to_datetime(cus_304050['de_dt'],format='%Y%m%d')

# %%
cus_304050['de_dt']
# Out:
# 0         2021-01-16
# 1         2021-01-16
# 2         2021-08-05
# 3         2021-04-03
# 6         2021-10-31
#              ...
# 4381733   2021-04-28
# 4381735   2021-03-07
# 4381736   2021-01-31
# 4381739   2021-07-12
# 4381740   2021-05-23
# Name: de_dt, Length: 479262, dtype: datetime64[ns]

# %%
cus_304050[cus_304050['de_dt'].dt.dayofweek == 5]
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 9        M000557840        남성  30대     Z11  A01078954018        1   A01
# 11       M001694463        남성  40대     Z14  A01139531032        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381721  M740326708        여성  40대     Z17  A01171190884        1   A01
# 4381722  M740326708        여성  40대     Z17  A01171192292        1   A01
# 4381723  M740326708        여성  40대     Z17  A01171195251        1   A01
# 4381724  M740326708        여성  40대     Z17  A01171199385        1   A01
# 4381726  M747738564        남성  40대     Z11  A01341536210        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %% [markdown]
# ## 직장동료

# %%
a = cus_304050.loc[((cus_304050['chnl_dv'] == 1) &( (cus_304050['de_hr'] >= 9) & (cus_304050['de_hr'] <= 12)) | ((cus_304050['de_hr'] >= 13) & (cus_304050['de_hr'] <= 18))) \
                   &((cus_304050['de_dt'].dt.dayofweek != 5) | (cus_304050['de_dt'].dt.dayofweek != 6)|(cus_304050['de_dt'] != '2021-01-01')|(cus_304050['de_dt'] != '2021-02-11')|(cus_304050['de_dt'] != '2021-02-12') \
                   |(cus_304050['de_dt'] != '2021-03-01')|(cus_304050['de_dt'] != '2021-05-05')|(cus_304050['de_dt'] != '2021-05-19')|(cus_304050['de_dt'] != '2021-09-20')|(cus_304050['de_dt'] != '2021-09-21')|(cus_304050['de_dt'] != '2021-09-22')), :]
a = cus_304050.groupby('cust').agg({'buy_ct': 'count'})
b = []
for i in range(len(a)):
    if a['buy_ct'][i] > 20: # 연차 수
           b.append(a.index[i])

# %%
b
# Out:
# ['M000136117',
#  'M000225114',
#  'M000261625',
#  'M000419293',
#  'M000494848',
#  'M000508243',
#  'M000621637',
#  'M001248380',
#  'M001444118',
#  'M001694463',
#  'M001714196',
#  'M001729158',
#  'M001808316',
#  'M001932188',
#  'M002009440',
#  'M002476170',
#  'M002900547',
#  'M002944916',
#  'M003423693',
#  'M003427143',
#  'M003531710',
#  'M003574741',
#  'M003641896',
#  'M003673750',
#  'M003803545',
#  'M003842970',
#  'M003948947',
#  'M003972434',
#  'M004292419',
#  'M004725109',
#  'M004743281',
#  'M004839058',
#  'M005190060',
#  'M005297673',
#  'M005360407',
#  'M005392126',
#  'M005448564',
#  'M005515605',
#  'M005701809',
#  'M005930833',
#  'M006103201',
#  'M006216667',
#  'M006272431',
#  'M006276409',
#  'M006429452',
#  'M006627098',
#  'M006658403',
#  'M006703537',
#  'M006826436',
#  'M006962764',
#  'M006997862',
#  'M007196501',
#  'M007319872',
#  'M007354680',
#  'M007463920',
#  'M007486863',
#  'M007490836',
#  'M008146645',
# ...

# %%
worker = cus_304050[~cus_304050['cust'].isin(b)]
worker
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 7        M000555652        남성  50대     Z10  A01100339077        1   A01
# 8        M000555652        남성  50대     Z10  A01355760494        1   A01
# 9        M000557840        남성  30대     Z11  A01078954018        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381730  M949264778        여성  50대     Z12  A01298342312        1   A01
# 4381732  M970932333        여성  30대     Z04  E06046994706        2   A06
# 4381733  M762888764        여성  30대     Z11  E06033428238        2   A06
# 4381735  M897387507        남성  40대     Z07  E06015295559        2   A06
# 4381736  M802756595        남성  40대     Z17  E06006556124        2   A06
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
for i in worker['clac_hlv_nm'].unique():
   print(worker[worker['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     184921710.0
# 남성트레이닝복        139339210.0
# 남성스포츠티셔츠        83897670.0
# 여성런닝/트레이닝화      53628920.0
# 남성골프티셔츠         52579950.0
# 남성등산티셔츠         52176850.0
# 남성등산/아웃도어세트     43970620.0
# 남성등산점퍼/재킷       36753390.0
# 남성일반스포츠바지       29397580.0
# 여성골프티셔츠/탑       28192110.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷    17370800.0
# 유아동내의      9066280.0
# 브래지어       9046250.0
# 여성속옷세트     7273910.0
# 남성팬티       3924610.0
# 남성일반양말     3096600.0
# 홈웨어세트      1331240.0
# 스타킹        1277730.0
# 여성팬티       1267690.0
# 여아실내복      1161300.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성티셔츠/탑      181810810.0
# 기타여성의류세트     144253590.0
# 기타여성의류아우터    121132630.0
# 여성재킷         114614930.0
# 여성원피스         77419150.0
# 여성코트          73148250.0
# 여성블라우스        62829680.0
# 여성패딩          52544960.0
# 여성정장세트        36268800.0
# 여성점퍼          29133760.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 냉동만두       2436270.0
# 기타냉동간편식    1413570.0
# ...

# %%
for i in worker['clac_hlv_nm'].unique():
   print(worker[worker['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     2155
# 남성트레이닝복        1659
# 남성스포츠티셔츠        953
# 여성런닝/트레이닝화      695
# 남성등산티셔츠         452
# 남성등산/아웃도어세트     385
# 남성일반스포츠바지       375
# 여성트레이닝복         355
# 남성등산점퍼/재킷       311
# 남성골프티셔츠         265
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 기타여성속옷    264
# 유아동내의     225
# 브래지어      167
# 여성속옷세트    162
# 남성일반양말     93
# 남성팬티       78
# 스타킹        65
# 여성팬티       58
# 여성일반양말     47
# 홈웨어세트      38
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성티셔츠/탑      2509
# 기타여성의류세트     1060
# 기타여성의류아우터    1049
# 여성재킷          606
# 여성원피스         597
# 여성블라우스        557
# 여성정장세트        452
# 여성바지          376
# 여성코트          248
# 여성청바지         235
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       180
# 기타냉동간편식    148
# 콘아이스크림     125
# 냉동떡볶이       70
# 컵아이스크림      64
# 냉동디저트       61
# 바아이스크림      59
# 냉동피자        21
# 홈아이스크림      20
# 냉동핫도그       19
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 커피음료       851
# 과일음료       307
# ...

# %%
keywords = cus_304050['pd_nm'].unique()
matching = [x for x in keywords if "정장" in x] 
print(matching)
# Out:
# ['남성정장셔츠', '남성정장화', '여성정장세트', '남성정장세트', '남성정장재킷', '남성정장바지']

# %%
display(worker.loc[(worker['pd_nm'] == '남성정장셔츠') | (worker['pd_nm'] == '남성정장화') | (worker['pd_nm'] == '여성정장세트')| (worker['pd_nm'] == '남성정장세트')| (worker['pd_nm'] == '남성정장재킷')| (worker['pd_nm'] == '남성정장바지'),:])
cust_woker = worker.loc[(worker['pd_nm'] == '남성정장셔츠') | (worker['pd_nm'] == '남성정장화') | (worker['pd_nm'] == '여성정장세트')| (worker['pd_nm'] == '남성정장세트')| (worker['pd_nm'] == '남성정장재킷')| (worker['pd_nm'] == '남성정장바지'),:]['cust'].unique()
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 1942028  M005978086        남성  40대     Z17  A01012495480        1   A01
# 1942029  M006201429        여성  40대     Z10  A01373701734        1   A01
# 1942032  M007207067        남성  50대     Z12  A01415625133        1   A01
# 1942042  M009092500        여성  40대     Z09  A01187452498        1   A01
# 1942076  M020155133        여성  30대     Z17  A01116536389        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4086585  M810526566        여성  30대     Z04  A01108189327        1   A01
# 4086589  M836287742        여성  30대     Z10  A01338066070        1   A01
# 4086590  M836287742        여성  30대     Z10  A01338066070        1   A01
# 4086592  M841223816        여성  40대     Z13  A01098632375        1   A01
# 4086607  M940071882        여성  30대     Z14  E06010487717        2   A06
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct   pd_nm  \
# ...

# %%
cus_304050.loc[(cus_304050['pd_nm'] == '남성정장셔츠') | (cus_304050['pd_nm'] == '남성정장화') | (cus_304050['pd_nm'] == '여성정장세트')| (cus_304050['pd_nm'] == '남성정장세트')| (cus_304050['pd_nm'] == '남성정장재킷')| (cus_304050['pd_nm'] == '남성정장바지'),:]
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 1942019  M000494848        여성  30대     Z10  A01235377234        1   A01
# 1942020  M000494848        여성  30대     Z10  A01440839579        1   A01
# 1942021  M000508243        여성  50대     Z17  A01108120047        1   A01
# 1942024  M004839058        남성  40대     Z13  A01187020373        1   A01
# 1942025  M005392126        남성  40대     Z17  A01149014106        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4086605  M923285900        여성  30대     Z17  A01396321610        1   A01
# 4086606  M938201564        여성  40대     Z11  A01253572117        1   A01
# 4086607  M940071882        여성  30대     Z14  E06010487717        2   A06
# 4086608  M965981972        여성  30대     Z04  A01394422904        1   A01
# 4086609  M971914997        여성  30대     Z04  A01319395738        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct   pd_nm  \
# ...

# %%
worker_suit = cus_304050[cus_304050['cust'].isin(cust_woker)]
worker_suit
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 95       M009092500        여성  40대     Z09  A01151450863        1   A01
# 96       M009092500        여성  40대     Z09  A01399111029        1   A01
# 156      M012312404        남성  30대     Z16  A01064160517        1   A01
# 219      M013700307        여성  40대     Z10  A01129047374        1   A01
# 276      M018155432        여성  30대     Z09  A01093428642        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4380977  M380432397        남성  50대     Z17  A01027872022        1   A01
# 4381208  M348833958        여성  40대     Z10  A01074362154        1   A01
# 4381228  M417573867        남성  40대     Z10  E06039377529        2   A06
# 4381545  M617975621        남성  40대     Z04  E06033399445        2   A06
# 4381680  M783432409        여성  40대     Z16  A01103639922        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
for i in worker_suit['clac_hlv_nm'].unique():
   print(worker_suit[worker_suit['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     25730540.0
# 남성트레이닝복        22670240.0
# 여성골프티셔츠/탑       9977900.0
# 남성스포츠티셔츠        9240600.0
# 남성골프티셔츠         7950500.0
# 남성골프의류세트        7713900.0
# 여성런닝/트레이닝화      7644100.0
# 남성등산티셔츠         5684850.0
# 남성등산/아웃도어세트     5534850.0
# 남성등산점퍼/재킷       4730300.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷    3732900.0
# 브래지어      1436600.0
# 여성속옷세트    1126310.0
# 유아동내의      824300.0
# 남성팬티       706700.0
# 여아실내복      434700.0
# 남성일반양말     253000.0
# 여성팬티       235400.0
# 스타킹        217600.0
# 유아동팬티      172400.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성정장세트       36268800.0
# 여성티셔츠/탑      31895590.0
# 기타여성의류세트     23268870.0
# 여성재킷         22337390.0
# 기타여성의류아우터    18896050.0
# 여성원피스        16096720.0
# 여성코트         14140650.0
# 여성패딩         12210500.0
# 여성블라우스        8608440.0
# 여성기타모피의류      5644000.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 냉동떡볶이      227630.0
# 냉동만두       165170.0
# 기타냉동간편식     91560.0
# ...

# %%
for i in worker_suit['clac_hlv_nm'].unique():
   print(worker_suit[worker_suit['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     304
# 남성트레이닝복        276
# 남성스포츠티셔츠       111
# 여성런닝/트레이닝화      89
# 여성골프티셔츠/탑       54
# 남성골프티셔츠         53
# 여성트레이닝복         50
# 남성등산티셔츠         49
# 남성등산/아웃도어세트     45
# 남성골프의류세트        40
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 기타여성속옷    57
# 브래지어      25
# 여성속옷세트    21
# 유아동내의     20
# 남성일반양말    12
# 남성팬티      10
# 스타킹        9
# 여성일반양말     8
# 여성팬티       8
# 여아실내복      5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성정장세트       452
# 여성티셔츠/탑      425
# 기타여성의류아우터    185
# 기타여성의류세트     180
# 여성재킷         121
# 여성블라우스       105
# 여성원피스         94
# 여성코트          70
# 여성바지          55
# 여성남방셔츠        33
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       16
# 냉동떡볶이      13
# 콘아이스크림     12
# 기타냉동간편식    11
# 컵아이스크림      8
# 바아이스크림      4
# 냉동피자        3
# 냉동핫도그       3
# 냉동디저트       2
# 냉동튀김        2
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 커피음료       98
# 과일음료       42
# 혼합탄산       22
# 생수         18
# 기타기능성음료    17
# ...

# %% [markdown]
# ## 클라이언트

# %%
cus_merge.sort_values(by ='buy_ct', ascending=False).head(60)
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 963706   M037911118        여성  40대     Z05  A02349418443        1   A02
# 913021   M035037103        남성  20대     Z04  A04004771811        1   A04
# 1117     M085041421        여성  50대     Z17  A02156839794        1   A02
# 4103877  M745864268        남성  60대     Z16  A02246841871        1   A02
# 1065932  M768874888        여성  40대     Z16  E06006797437        2   A06
# 89501    M245283859        남성  30대     Z11  A02254698310        1   A02
# 89503    M245283859        남성  30대     Z11  A02255408579        1   A02
# 4372277  M838622742        남성  40대     Z14  A01033672436        1   A01
# 2807930  M103897322        여성  60대     Z11  A04096728782        1   A04
# 928244   M927998831        남성  30대     Z10  E06047735952        2   A06
# 454384   M913531244        남성  40대     Z10  A04029022280        1   A04
# 4101291  M906226236        남성  60대     Z16  E06048834572        2   A06
# ...

# %%
cus_merge = cus_merge[~cus_merge['cust'].isin(['M103897322'])]
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
cus_merge[cus_merge['buy_ct']>55]['pd_nm'].unique()
# Out:
# array(['남성런닝/트레이닝화', '스포츠음료', '종량제봉투', '국산맥주', '감자스낵', '애견사료', '과일음료',
#        '스킨/토너', '냄비', '생리대', '칫솔', '생수', '일반소주', '참치통조림', '국물봉지라면',
#        '옥수수스낵', '젤리', '판초콜릿', '스킨케어세트', '홍삼근', '기타레토르트', '여성티셔츠/탑',
#        '기타영양제', '선물류', '커피음료', '남성정장세트', '믹스커피', '기타파티/팬시용품', '햄',
#        '기타여성화', '일반시리얼', '수입맥주', '생활잡화균일가', '남성용스킨케어류', '스툴/리빙의자', '옥수수',
#        '전복', '기타컴퓨터액세서리', '티백/드립원두커피', '목걸이', '이유식', '레고', '남성점퍼',
#        '남성양말선물세트', '안전상비의약품', '핸드워시/손세정제', '기타가구', '기타양주', '수입소고기선물세트',
#        '수입산소갈비', '꽁치고등어통조림', '팔찌', '즉석컵밥', '남성슬리퍼', '통조림혼합세트', '헤어케어선물세트',
#        '건반악기', '식용유세트', '햄통조림세트'], dtype=object)

# %%
cus_55 = cus_merge[cus_merge['buy_ct']>55]
c = cus_55.loc[(cus_55['pd_nm'] == '남성런닝/트레이닝화')|(cus_55['pd_nm'] == '스포츠음료')|(cus_55['pd_nm'] == '과일음료')|(cus_55['pd_nm'] == '스킨케어세트')\
          |(cus_55['pd_nm'] == '홍삼근')|(cus_55['pd_nm'] == '여성티셔츠/탑')|(cus_55['pd_nm'] == '기타영양제')|(cus_55['pd_nm'] == '선물류')\
          |(cus_55['pd_nm'] == '커피음료')|(cus_55['pd_nm'] == '남성정장세트')|(cus_55['pd_nm'] == '믹스커피')|(cus_55['pd_nm'] == '기타여성화')\
          |(cus_55['pd_nm'] == '남성용스킨케어류')|(cus_55['pd_nm'] == '스툴/리빙의자')|(cus_55['pd_nm'] == '티백/드립원두커피')|(cus_55['pd_nm'] == '목걸이')\
          |(cus_55['pd_nm'] == '남성점퍼')|(cus_55['pd_nm'] == '햄통조림세트')|(cus_55['pd_nm'] == '수입소고기선물세트')|(cus_55['pd_nm'] == '남성양말선물세트')|(cus_55['pd_nm'] == '핸드워시/손세정제')\
          |(cus_55['pd_nm'] == '기타양주')|(cus_55['pd_nm'] == '통조림혼합세트')|(cus_55['pd_nm'] == '수입산소갈비')|(cus_55['pd_nm'] == '헤어케어선물세트')|(cus_55['pd_nm'] == '식용유세트'),:]['cust'].unique()

# %%
client = cus_merge[cus_merge['cust'].isin(c)]
client
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 308      M019989627        여성  40대     Z16  A01341142242        1   A01
# 1081     M085041421        여성  50대     Z17  A02154660759        1   A02
# 1082     M085041421        여성  50대     Z17  A02154660759        1   A02
# 1083     M085041421        여성  50대     Z17  A02154708135        1   A02
# 1084     M085041421        여성  50대     Z17  A02154737828        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4379661  M342474894        남성  20대     Z05  A02326091758        1   A02
# 4379853  M390010790        남성  50대     Z17  E06010098155        2   A06
# 4379988  M428731067        여성  30대     Z17  A01044002023        1   A01
# 4380026  M412288994        남성  60대     Z17  A02076165968        1   A02
# 4380546  M203489906        여성  40대     Z10  A01308847411        1   A01
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct         pd_nm  \
# ...

# %%
for i in client['clac_hlv_nm'].unique():
   print(client[client['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 여성골프티셔츠/탑     12049400.0
# 남성런닝/트레이닝화     8115500.0
# 남성트레이닝복        2537800.0
# 남성골프티셔츠        1214000.0
# 여성골프바지          836000.0
# 남성스포츠티셔츠        709620.0
# 여성스포츠티셔츠/탑      705600.0
# 여성런닝/트레이닝화      448000.0
# 남성일반스포츠바지       440600.0
# 남성등산티셔츠         428900.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷        1895000.0
# 유아동내의         1498300.0
# 남성양말선물세트       799400.0
# 남성일반양말         400500.0
# 여성속옷세트         326440.0
# 여아잠옷           170000.0
# 스타킹             59200.0
# 남아실내복           54600.0
# 남성캐쥬얼스포츠양말      52500.0
# 브래지어            45900.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 조미도시락김       272865.0
# 굴비류          187760.0
# 김선물세트        164300.0
# 훈제/구이오징어     120140.0
# 건오징어         105640.0
# 볶음조림용건멸치      84740.0
# 마른김           78580.0
# 김자반/부각/튀각     75610.0
# 어포류           57920.0
# 국물용건멸치        56820.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성의류세트     18931970.0
# 여성티셔츠/탑      18051500.0
# ...

# %%
for i in client['clac_hlv_nm'].unique():
   print(client[client['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     89
# 여성골프티셔츠/탑      43
# 남성트레이닝복        24
# 남성스포츠티셔츠       16
# 여성스포츠티셔츠/탑     14
# 여성런닝/트레이닝화      6
# 남성일반스포츠바지       4
# 여성골프의류세트        3
# 스포츠모자           3
# 유아동런닝/트레이닝화     3
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 유아동내의         24
# 기타여성속옷        15
# 여성캐쥬얼스포츠양말    10
# 기타유아동양말류       5
# 남성일반양말         5
# 남성캐쥬얼스포츠양말     5
# 남아실내복          5
# 브래지어           3
# 남성양말선물세트       3
# 남성팬티           3
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 조미도시락김       35
# 김자반/부각/튀각    20
# 마른김          15
# 건미역          13
# 훈제/구이오징어     12
# 건오징어          9
# 볶음조림용건멸치      7
# 조미전장김         7
# 조미오징어         5
# 굴비류           5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성티셔츠/탑      219
# 기타여성의류세트      55
# 여성블라우스        28
# 여성재킷          26
# 기타여성의류아우터     25
# 여성원피스         11
# 여성바지           9
# 여성정장세트         6
# 여성스커트          5
# 여성청바지          5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       77
# 냉동튀김       40
# ...

# %%
for i in client['clac_hlv_nm'].unique():
   print(client[client['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화       438
# 여성골프티셔츠/탑         43
# 여성스포츠티셔츠/탑        24
# 남성트레이닝복           24
# 남성스포츠티셔츠          16
# 여성런닝/트레이닝화         6
# 스포츠두건/머플러/마스크      5
# 남성일반스포츠바지          5
# 여성골프의류세트           3
# 스포츠모자              3
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 남성양말선물세트      86
# 유아동내의         25
# 남성일반양말        20
# 기타여성속옷        17
# 브래지어          14
# 여성캐쥬얼스포츠양말    11
# 스타킹            7
# 여아잠옷           6
# 기타유아동양말류       5
# 남성캐쥬얼스포츠양말     5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 굴비류          81
# 조미도시락김       39
# 마른김          24
# 김자반/부각/튀각    21
# 훈제/구이오징어     14
# 건미역          13
# 건오징어         10
# 조미전장김         8
# 볶음조림용건멸치      7
# 국물용건멸치        5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성티셔츠/탑      2052
# 기타여성의류세트       56
# 여성블라우스         45
# 여성재킷           26
# 기타여성의류아우터      25
# 여성바지           16
# 여성원피스          11
# 여성스커트           8
# 여성정장세트          6
# 여성청바지           5
# Name: buy_ct, dtype: int64
# ----------
# ...

# %% [markdown]
# ## 은퇴하신분

# %%
cus_merge.loc[((cus_merge['ages'] == '70대') | (cus_merge['ages'] == '80대') ), :]
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 94       M009092385        여성  70대     Z11  A01467587862        1   A01
# 104      M009731870        여성  70대     Z17  A01000621072        1   A01
# 105      M009731870        여성  70대     Z17  A01000621072        1   A01
# 111      M010288392        여성  70대     Z10  A01455616801        1   A01
# 567      M036742669        여성  70대     Z04  A02119113563        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381364  M342394078        여성  70대     Z10  A01111536438        1   A01
# 4381365  M342394078        여성  70대     Z10  A01111536438        1   A01
# 4381366  M342394078        여성  70대     Z10  A01111536438        1   A01
# 4381436  M860309615        여성  70대     Z10  A02205244674        1   A02
# 4381469  M854163268        여성  70대     Z10  A03064128109        1   A03
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...
